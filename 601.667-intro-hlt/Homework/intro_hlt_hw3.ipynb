# %% [markdown]
# # Assignment 3
#
# You have now learnt about sequence-to-sequence models in the context of machine translation. In the upcoming lectures, you will see that these models are useful for a wide variety of tasks, wherever the source sequence and the target sequence have different lengths. You have also been introduced to phonemes, which are the building blocks of speech.
#
# In this assignment, you will build sequence-to-sequence models for pronunciation prediction of English words, which simply means that given a word (sequence of characters), the model should predict its pronunciation (sequence of phonemes). You should be able to see why this is a straightforward application of sequence-to-sequence models.
#
# The input is a sequence of characters making up an English word e.g. `a l g e b r a i c a l l y`. The output should be a sequence of phonemes that describe the pronunciation. For the example above, the desired output should be `AE2 L JH AH0 B R EY1 IH0 K L IY0`. The data for this task was obtained from the [CMU Pronunciation Dictionary](http://www.speech.cs.cmu.edu/cgi-bin/cmudict). We will use a small subset of the CMU dict data.
#
# # Setup
#
# For this assignment, as in the previous one, we will be using Google Colab, for both code as well as descriptive questions. Your task is to finish all the questions in the Colab notebook and then upload a PDF version of the notebook, and a viewable link on Gradescope.
#
# ### Google colaboratory
#
# Before getting started, get familiar with google colaboratory:
# https://colab.research.google.com/notebooks/welcome.ipynb
#
# This is a neat python environment that works in the cloud and does not require you to
# set up anything on your personal machine
# (it also has some built-in IDE features that make writing code easier).
# Moreover, it allows you to copy any existing collaboratory file, alter it and share
# with other people.
#
# ### Submission
#
# Before you start working on this homework do the following steps:
#
# 1. Press __File > Save a copy in Drive...__ tab. This will allow you to have your own copy and change it.
# 2. Follow all the steps in this collaboratory file and write / change / uncomment code as necessary.
# 3. Do not forget to occasionally press __File > Save__ tab to save your progress.
# 4. After all the changes are done and progress is saved press __Share__ button (top right corner of the page), press __get shareable link__ and make sure you have the option __Anyone with the link can view__ selected.
# 5. After completing the notebook, press __File > Download .ipynb__ to download a local copy on your computer, and then use `jupyter nbconvert --to pdf intro-hlt-hw3.ipynb` to convert the notebook into PDF format for uploading on Gradescope.

# %% [markdown]
# ```
# # Paste your Colab notebook link here
# https://colab.research.google.com/drive/1iY8kLGBpxmfc-BPYYQP7DrpQ_zJ5JUB0?usp=sharing
# ```

# %% [markdown]
# # Dataset
#
# For your convenience, we have preselected a subset of the CMU pronunciation dictionary (input-output pairs) and split the subset into training, validation (dev) and test sets.

# %%
# !wget https://raw.githubusercontent.com/jhu-intro-hlt/jhu-intro-hlt.github.io/master/data-seq2seq-hw/cmudict.{dev,train,test}.src -q -nc
# !wget https://raw.githubusercontent.com/jhu-intro-hlt/jhu-intro-hlt.github.io/master/data-seq2seq-hw/cmudict.{dev,train,test}.tgt -q -nc
# !wget https://raw.githubusercontent.com/jhu-intro-hlt/jhu-intro-hlt.github.io/master/data-seq2seq-hw/cmudict.small.train.src -q -nc
# !wget https://raw.githubusercontent.com/jhu-intro-hlt/jhu-intro-hlt.github.io/master/data-seq2seq-hw/cmudict.small.train.tgt -q -nc

# %%
# This is the raw contents of the .src and .tgt files
# The data for this assignment is a subset of cmudict https://github.com/cmusphinx/cmudict
# !pr -m -t cmudict.small.train.src cmudict.small.train.tgt | head
# Out:
# s t a g g e r i n g l y		    S T AE1 G ER0 IH2 NG L IY2
# p o c a h o n t a s		    P OW2 K AH0 HH AA1 N T AH0 S
# h y p e r b o r e a n		    HH AY2 P ER0 B AO1 R IY0 AH0 N
# s p a g n o l i			    S P AA0 G N OW1 L IY0
# m i n s t a r ' s		    M IH1 N S T AA2 R Z
# a n a l o g i c			    AE2 N AH0 L AA1 JH IH0 K
# p o i g n a n t l y		    P OY1 N Y AH0 N T L IY0
# m c l a u r i n			    M AH0 K L AO1 R AH0 N
# c o n v e r s a t i o n s	    K AA2 N V ER0 S EY1 SH AH0 N Z
# g r o s s e n b a c h e r	    G R AA1 S IH0 N B AA0 K ER0

# %%
import math
import random
import torch
import time
random.seed(1234)
torch.manual_seed(1234)
torch.cuda.set_device(0)

# %% [markdown]
# # Data Reader
#
# We will use the `ParallelCorpus` class below to load, process and iterate through the data. Since you worked quite a bit on data loading implementation in the previous assignment, we will provide you the loader for this one, so you can get on with the more interesting parts of this assignment.
#
# Note the use of special symbols `<BOS>`, `<EOS>` and `<UNK>`. All the sequences (both input and output) are made to begin with `<BOS>` (Begin of sequence) and end with `<EOS>` (End of sequence). The `<UNK>` symbol is used if we encouter any new symbol that we have not seen (unknown symbol).

# %%
SPL_SYMS = ['<BOS>', '<EOS>', '<UNK>']


class ParallelCorpus(object):
    def __init__(self,
                 src_file, tgt_file,
                 src_vocab=None, tgt_vocab=None):
        self.src_vocab = self.make_vocab(src_file, src_vocab)
        self.tgt_vocab = self.make_vocab(tgt_file, tgt_vocab)
        self.src_idx2vocab = self.make_idx2vocab(self.src_vocab)
        self.tgt_idx2vocab = self.make_idx2vocab(self.tgt_vocab)
        self.src_data = self.numberize(src_file, self.src_vocab)
        self.tgt_data = self.numberize(tgt_file, self.tgt_vocab) if tgt_file is not None else None
        assert len(self.src_data) == len(self.tgt_data), 'Source and Target have unequal lengths!'
        self.data_size = len(self.src_data)

    def numberize(self, txt, vocab):
        data = []
        with open(txt, 'r', encoding='utf8') as corpus:
            for l in corpus:
                d = [vocab['<BOS>']] + [vocab.get(tok, vocab['<UNK>']) for tok in l.strip().split()] + [vocab['<EOS>']]
                d = torch.Tensor(d).long()
                d = d.unsqueeze(0) # shape = (1, N)
                data.append((d, l.strip()))
        return data

    def make_idx2vocab(self, vocab):
        if vocab is not None:
            idx2vocab = {v: k for k, v in vocab.items()}
            return idx2vocab
        else:
            return None

    def make_vocab(self, txt, vocab):
        if vocab is None and txt is not None:
            v = {i: idx for idx, i in enumerate(SPL_SYMS)}
            with open(txt, 'r', encoding='utf8') as corpus:
                for line in corpus:
                    for token in line.strip().split():
                        v[token] = v.get(token, len(v))
            return v
        else:
            return vocab

    def get(self, idx):
        if self.tgt_data is not None:
            return self.src_data[idx], self.tgt_data[idx]
        else:
            return self.src_data[idx], (None, None)

# %%
train_corpus = ParallelCorpus('cmudict.small.train.src',
                              'cmudict.small.train.tgt')
dev_corpus = ParallelCorpus('cmudict.dev.src', 
                            'cmudict.dev.tgt',
                            train_corpus.src_vocab, 
                            train_corpus.tgt_vocab)
test_corpus = ParallelCorpus('cmudict.test.src',
                             'cmudict.test.tgt',
                             train_corpus.src_vocab, 
                             train_corpus.tgt_vocab)
print(train_corpus.data_size, dev_corpus.data_size, test_corpus.data_size)
# Out:
# 10000 2000 5000

# %% [markdown]
# ## Part 1: Seq2Seq with LSTM Language Models
#
# In the first part of the assignment we will build a simple seq2seq model that should learn to predict the pronunciation of English words. The `EncoderDecoder` model consists (as the name suggests) of an `Encoder` and a `Decoder`, both of which are instances of an LSTM Language Model. LSTMs (Long Short-Term Memory) are an extention of RNNs (that you used for Assignment 2) designed to capture long(er) term dependencies in any sequence. The key difference between an LSTM and an RNN is that LSTMs keep track of a `cell state` in addition to a `hidden state`. If you are unfamiliar with LSTMs [this](https://colah.github.io/posts/2015-08-Understanding-LSTMs/) is an excellent resource. Note: you don't have to memorize the internals of an LSTM, for this assignment just knowing that LSTMs expect three inputs 1. a representation of a word 2. previous hidden state and 3. the previous cell state is sufficient. In PyTorch LSTMs "wrap" the hidden state (lets call it `h`) and the cell state (lets call it `c`) into a tuple `(h,c)`.
#
# As mentioned before, the Encoder and Decoder are going to be instances of an LSTM LM. Complete the code block below to set up the `LSTMLM` class. _(15 points)_

# %%
class LSTMLM(torch.nn.Module):
  def __init__(self,
              vocab_size,
              embedding_size,
              hidden_size,
              num_layers=1,
              dropout=0.1):
    super().__init__()
    self.vocab_size = vocab_size
    self.embedding_size = embedding_size
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.dropout = torch.nn.Dropout(dropout)
    
    #TODO: create an embedding layer here
    #TODO: the embedding layer takes a sequence of ints and converts them into a sequence of real-valued vectors
    #TODO: see https://pytorch.org/docs/stable/nn.html?highlight=embedding#torch.nn.Embedding
    self.embedding = torch.nn.Embedding(self.vocab_size,self.embedding_size)

    #TODO: create a unidirectional RNN-LSTM here
    #TODO: Note: use the batch_first=True option, 
    #TODO: the rest of the code assumes the first dimension of any tensor is the batch_size (which is 1 for simplicity)
    #TODO: see https://pytorch.org/docs/stable/nn.html?highlight=lstm#torch.nn.LSTM
    self.rnn = torch.nn.LSTM(self.embedding_size,self.hidden_size,self.num_layers,batch_first=True,dropout=dropout)

    #TODO: create a Linear layer
    #TODO: https://pytorch.org/docs/stable/nn.html?highlight=linear#torch.nn.Linear
    self.output = torch.nn.Linear(self.hidden_size,self.vocab_size)
           

  def forward(self, x, init_hidden_state=None):
    # x should be of shape (1, N) where N is the length of the source
    assert x.shape[0] == 1 # only supporting batch size of 1 to keep the implementation simple
    x_len = len(x)
    x = x.cuda() if self.embedding.weight.is_cuda else x
    #TODO: use `self.embedding` to convert x into a sequence of vector representations
    #TODO: name the result `emb` it should have shape (1, N, embedding_size)
    emb = self.embedding(x)
    emb = self.dropout(emb) # keep this line here

    #TODO: supply the embeddings `emb` to the RNN-LSTM
    #TODO: the LSTM requires a tuple as it's initial state (h0, c0) 
    #TODO: where `h0` is the initial hidden state and `c0` is the cell_state
    #TODO: if the argument init_hidden_state is None, create a tuple (h0, c0) where h0=zeros and c0=zeros.
    #TODO: if init_hidden_state is not None, then supply it as the second argument to the RNN-LSTM

    if init_hidden_state is None:
      h = torch.zeros((self.num_layers, x_len, self.hidden_size))
      c = torch.zeros((self.num_layers, x_len, self.hidden_size))
      h = h.cuda() if self.embedding.weight.is_cuda else h
      c = c.cuda() if self.embedding.weight.is_cuda else c
    else:
      h, c = init_hidden_state

    #TODO: the LSTM will output 2 objects
    #TODO: the first is a tensor representing the hidden states of the encoder (name the first object `hidden_states`)
    #TODO: the second is a tuple representing (final hidden state, final cell state)
    #TODO: each item in the tuple is a tensor. 
    #TODO: name the tuple as `final_state`.
    #TODO: hidden_states should have size (1, N, hidden_size)
    #TODO: each tensor in the final_state should have size (1, 1, hidden_size)

    hidden_states, final_state = self.rnn(emb, (h, c))
  
    hidden_states = self.dropout(hidden_states) # keep this line here

    #TODO: supply the hidden_states (after dropout) to the ourput layer
    #TODO: the output layer will "project" from hidden_size to output_size
    #TODO: i.e. the result of the output layer will be of size (1, N, vocab_size)
    #TODO: https://pytorch.org/docs/stable/nn.html?highlight=linear#torch.nn.Linear
    #TODO: name the result of the output layer as "output_dist"
    #hidden_states = hidden_states.reshape(hidden_states.size(0)*hidden_states.size(1),hidden_states.size(2))
    output_dist = self.output(hidden_states)

    return output_dist, hidden_states, final_state # do not change this line
    
  def generate(self, start_idx, end_idx, init_hidden_state=None, idx2vocab=None, max_len=50):
    """ Performs the sequence generation process
    Args:
      start_idx: is the starting symbol (i.e. the integer corresponding to the <BOS> symbol)
      end_idx: is the end symbol (i.e. the integer corresponding to the <EOS> symbol)
      init_hidden_state: (optional) is the tuple (hidden_state, cell_state) at the starting step of generation
      If init_hidden_state is None, zero vectors are used for the hidden and cell states.
      idx2vocab: A dictionary to convert integer representation of symbols to human-readable symbols i.e. characters.
      max_len: The maximum length of the generated sequence.
    Returns:
      out: A List of generated characters
    """
    if init_hidden_state is None:
      h = torch.zeros((self.num_layers, 1, self.hidden_size))
      c = torch.zeros((self.num_layers, 1, self.hidden_size))
      h = h.cuda() if self.embedding.weight.is_cuda else h
      c = c.cuda() if self.embedding.weight.is_cuda else c
    else:
      h, c = init_hidden_state
    
    inp = torch.tensor([start_idx]).long().unsqueeze(0)
    inp = inp.cuda() if self.embedding.weight.is_cuda else inp

    out = []
    for _ in range(max_len):
      with torch.no_grad():
        emb = self.embedding(inp)
        o, (h, c) = self.rnn(emb, (h, c))
        o_dist = self.output(o)
        _, pred = o_dist.max(dim=2)
        if pred.item() == end_idx:
          break
        out.append(pred.item() if idx2vocab is None else idx2vocab[pred.item()])
        inp = pred
    return out

# %%
class EncoderDecoder(torch.nn.Module):
  def __init__(self,
              src_vocab_size,
              tgt_vocab_size,
              embedding_size,
              hidden_size,
              num_layers=1,
              dropout=0.1,
              max_grad_norm=5.0):
    super().__init__()
    self.hidden_size = hidden_size
    self.embedding_size = embedding_size
    self.num_layers = num_layers
    self.max_grad_norm = max_grad_norm
    self.encoder = LSTMLM(src_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.decoder = LSTMLM(tgt_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.log_smax = torch.nn.LogSoftmax(dim=-1)
    self.loss = torch.nn.NLLLoss(reduction='mean', ignore_index=-1)
    #We are going to package the optimizer inside this class
    self.optimizer = torch.optim.Adam(self.parameters())

  def train_step(self, x, y):
    """ Performs one step of SGD
    Args:
        x: the input sequence, its size should be: (1, src_length)
        y: the output sequence, its size should be (1, tgt_length)
    Returns:
        loss: the loss for this example (note this is just for logging it is not a pytorch tensor)
        accuracy: the accuracy for this example
    """
    self.optimizer.zero_grad()
    _loss, acc = self(x, y)
    _loss.backward()
    grad_norm = torch.nn.utils.clip_grad_norm_(self.parameters(),
                                                self.max_grad_norm)

    if math.isnan(grad_norm):
      print('skipping update grad_norm is nan!')
    else:
      self.optimizer.step()
    loss = _loss.item()
    return loss, acc

  def forward(self, x, y):
    out_src, hidden_src, final_src = self.encoder(x)
    
    y_input = y[:, :-1]
    y_output = y[:, 1:]

    out_tgt, hidden_tgt, final_tgt = self.decoder(y_input, final_src)
    out_tgt_lsm = self.log_smax(out_tgt)
    
    
    loss = self.loss(out_tgt_lsm.squeeze(0), y_output.squeeze(0))
    _, pred = out_tgt_lsm.max(dim=2)
    accuracy = float((pred == y_output).sum()) / y_output.numel()
    return loss, accuracy

  def generate(self, x, start_idx, end_idx, idx2vocab=None, max_len=50):
    """Generates and output sequence, i.e. predicts the output sequence.
    Args:
        x: sequence of input tokens. shape should be (1, src_length)
        start_idx: index of the <BOS> token
        end_idx: index of the <EOS> token
        idx2vocab: a dictionary that maps indexes to the output tokens
    Returns:
        out: list of strings
    """
    _, _, final_src = self.encoder(x)
    out = self.decoder.generate(start_idx, end_idx, final_src, idx2vocab)
    return out

# %% [markdown]
# __Question:__ Look at the forward function of the `EncoderDecoder` class. What is the purpose of the following lines: _(5 points)_
#
# ```
#     y_input = y[:, :-1]
#     y_output = y[:, 1:]
# ```
#
# __Answer__: In the training of LSTM, the last step in predictions will be the first future element. We make a loop where this element is the input. Because of stateful, the model will understand it's a new input step of the previous sequence instead of a new sequence.
#
# __Question__: In the last homework, the generation function of the RNN LM had a temperature parameter to control the randomness of the generated output. What implicit temperature are we using in the above model? _(5 points)_
#
# __Answer:__The dropout operation functions as temperature which is used to control the randomness of predictions. The logic of dropout is for adding noise to the neurons in order not to be dependent on any specific neuron. By adding drop out for LSTM cells, there is a chance for forgetting something that should not be forgotten.

# %% [markdown]
# We create an instance of our EncoderDecoder below.

# %%
model = EncoderDecoder(src_vocab_size=len(train_corpus.src_vocab),
                       tgt_vocab_size=len(train_corpus.tgt_vocab),
                       embedding_size=73,
                       hidden_size=73,
                       num_layers=1)
model = model.cuda()
print(model)
print('num parameters:', sum([p.numel() for p in model.parameters()]))
# Out:
# EncoderDecoder(
#   (encoder): LSTMLM(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (embedding): Embedding(31, 73)
#     (rnn): LSTM(73, 73, batch_first=True, dropout=0.1)
#     (output): Linear(in_features=73, out_features=31, bias=True)
#   )
#   (decoder): LSTMLM(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (embedding): Embedding(75, 73)
#     (rnn): LSTM(73, 73, batch_first=True, dropout=0.1)
#     (output): Linear(in_features=73, out_features=75, bias=True)
#   )
#   (log_smax): LogSoftmax(dim=-1)
#   (loss): NLLLoss()
# )
# num parameters: 102014
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %% [markdown]
# ## Training routine
#
# The `train` method defines our training routine. For the first seq2seq model `max_epochs` should be at least 15. For the second model, max_epochs can be reduced to 10.

# %%
def train(model, train_corpus, dev_corpus, max_epochs=15):
  sum_loss, sum_acc = 0., 0.
  train_instances_idxs = list(range(train_corpus.data_size))
  st = time.time()
  for epoch_i in range(max_epochs):
    sum_loss, sum_acc = 0., 0.
    random.shuffle(train_instances_idxs)
    model.train()
    for i in train_instances_idxs:
      (x, _), (y, _) = train_corpus.get(i)
      x, y = x.cuda(), y.cuda()
      l, a = model.train_step(x, y)
      sum_loss += l
      sum_acc += a
    print(f"epoch: {epoch_i} time elapsed: {time.time() - st:.2f}")
    print(f"train loss: {sum_loss/train_corpus.data_size:.4f} train acc: {sum_acc/train_corpus.data_size:.4f}")
    sum_loss, sum_acc = 0., 0.
    model.eval()
    for dev_i in range(dev_corpus.data_size):
      (x, x_str), (y, y_str) = dev_corpus.get(dev_i)
      x, y = x.cuda(), y.cuda()
      with torch.no_grad():
        l, a = model(x, y)
        sum_loss += l.item()
        sum_acc += a
    print(f"  dev loss: {sum_loss/dev_corpus.data_size:.4f}   dev acc: {sum_acc/dev_corpus.data_size:.4f}")
  return model

# %% [markdown]
# ## Evaluation Routine
# We are going to evaluate our model's predictions using Character Error Rate (CER). This measures the number of edits (insertions, deletions and substitutions) needed to convert our model's prediction to the correct output sequence. [Edit distance computation](https://nlp.stanford.edu/IR-book/html/htmledition/edit-distance-1.html) is one of the popular applications of dynamic programming, and is used for measuring character/phone/word error rates in speech recognition.
#
# Complete the following function which takes two sequences (list of characters) and computes the edit distance between them. Verify your implementation for a few pairs of sequences by comparing the output of your function with the output obtained from `ed.eval()` _(10 points)_

# %%
from typing import List

Sequence = List[str]

def compute_edit_distance(s: Sequence, t: Sequence) -> int:
  # TODO: Your implementation here
  if s == t: return 0
  elif len(s) == 0: return len(t)
  elif len(t) == 0: return len(s)
  v0 = [None] * (len(t) + 1)
  v1 = [None] * (len(t) + 1)
  for i in range(len(v0)):
      v0[i] = i
  for i in range(len(s)):
      v1[0] = i + 1
      for j in range(len(t)):
        cost = 0 if s[i] == t[j] else 1
        v1[j + 1] = min(v1[j] + 1, v0[j + 1] + 1, v0[j] + cost)
      for j in range(len(v0)):
        v0[j] = v1[j]
                
  return v1[len(t)]

# %%
import editdistance as ed

# Example 1
seq1 = ['H','E','L','L','O']
seq2 = ['H','E','L','P']
assert compute_edit_distance(seq1,seq2) == ed.eval(seq1,seq2)

# Example 2
# TODO
seq3 = ['A','P','P','L','E']
seq4= ['A','P','E','X'] 
assert compute_edit_distance(seq3,seq4) == ed.eval(seq3,seq4)
# Example 3
# TODO 
seq5 = ['P','L','A','Y']
seq6 = ['P','L','A','N','T']
assert compute_edit_distance(seq5,seq6) == ed.eval(seq5,seq6)

# %% [markdown]
# The below routine evaluates the trained model.

# %%
def evaluate(model, test_corpus):
  print('Evaluation:')
  sum_cer = 0.0
  model.eval()
  for test_i in range(test_corpus.data_size):
    (x, x_str), (y, y_str) = test_corpus.get(test_i)
    x, y = x.cuda(), y.cuda()
    pred_seq = model.generate(x,
                              test_corpus.tgt_vocab[SPL_SYMS[0]],
                              test_corpus.tgt_vocab[SPL_SYMS[1]],
                              test_corpus.tgt_idx2vocab)
    cer = float(ed.eval(y_str.split(), pred_seq)) / len(y_str.split())
    y_hat = ' '.join(pred_seq)
    x_str = ''.join(x_str.split())
    print(f"{test_i} {x_str} pred: {y_hat} ref: {y_str} cer: {cer:.4f}")
    sum_cer += cer
  print(f"Avg CER: {sum_cer/test_corpus.data_size:.4f}")

# %% [markdown]
# ## Training the EncoderDecoder

# %%
model = train(model, train_corpus, dev_corpus) #takes around 15-25 min
# Out:
# epoch: 0 time elapsed: 36.12
# train loss: 2.1759 train acc: 0.4222
#   dev loss: 1.5276   dev acc: 0.5830
# epoch: 1 time elapsed: 73.56
# train loss: 1.4335 train acc: 0.6000
#   dev loss: 1.2273   dev acc: 0.6552
# epoch: 2 time elapsed: 110.91
# train loss: 1.2218 train acc: 0.6512
#   dev loss: 1.0744   dev acc: 0.6919
# epoch: 3 time elapsed: 148.08
# train loss: 1.0973 train acc: 0.6823
#   dev loss: 0.9937   dev acc: 0.7124
# epoch: 4 time elapsed: 185.62
# train loss: 1.0153 train acc: 0.7036
#   dev loss: 0.9328   dev acc: 0.7322
# epoch: 5 time elapsed: 222.94
# train loss: 0.9598 train acc: 0.7185
#   dev loss: 0.8926   dev acc: 0.7424
# epoch: 6 time elapsed: 260.31
# train loss: 0.9141 train acc: 0.7302
#   dev loss: 0.8793   dev acc: 0.7434
# epoch: 7 time elapsed: 297.51
# train loss: 0.8747 train acc: 0.7407
#   dev loss: 0.8323   dev acc: 0.7560
# epoch: 8 time elapsed: 334.60
# train loss: 0.8427 train acc: 0.7488
#   dev loss: 0.8198   dev acc: 0.7601
# epoch: 9 time elapsed: 371.89
# train loss: 0.8163 train acc: 0.7550
#   dev loss: 0.8046   dev acc: 0.7649
# epoch: 10 time elapsed: 408.97
# train loss: 0.7960 train acc: 0.7613
#   dev loss: 0.7990   dev acc: 0.7673
# epoch: 11 time elapsed: 446.18
# train loss: 0.7784 train acc: 0.7660
#   dev loss: 0.7780   dev acc: 0.7727
# epoch: 12 time elapsed: 483.58
# train loss: 0.7581 train acc: 0.7709
#   dev loss: 0.7753   dev acc: 0.7730
# epoch: 13 time elapsed: 520.89
# train loss: 0.7438 train acc: 0.7749
#   dev loss: 0.7634   dev acc: 0.7756
# epoch: 14 time elapsed: 558.19
# train loss: 0.7265 train acc: 0.7798
#   dev loss: 0.7573   dev acc: 0.7790

# %%
evaluate(model, test_corpus)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1 utility's pred: Y UW0 T IH1 L AH0 T IY0 Z ref: Y UW0 T IH1 L AH0 T IY0 Z cer: 0.0000
# 2 rothenberg pred: R OW1 T HH EH2 N D ER0 ref: R AO1 TH AH0 N B ER0 G cer: 0.7500
# 3 kinesiology pred: K IH2 N AH0 S IH1 L AH0 JH IY0 ref: K IH2 N IH0 S IY2 AA1 L AH0 JH IY0 cer: 0.2727
# 4 reclassified pred: R IY0 K L IH1 S T IH0 D ref: R IY0 K L AE1 S AH0 F AY2 D cer: 0.4000
# 5 substantive pred: S AH1 B S T AH0 N T IH0 D ref: S AH1 B S T AH0 N T IH0 V cer: 0.1000
# 6 situations pred: S AY2 T UW0 EY1 SH AH0 N Z ref: S IH2 CH UW0 EY1 SH AH0 N Z cer: 0.2222
# 7 lobianco pred: L OW1 B AH0 N AA1 K ref: L OW0 B IY0 AA1 N K OW0 cer: 0.6250
# 8 participants' pred: P AA0 R T IH1 S AH0 P EY2 T S ref: P AA0 R T IH1 S AH0 P AH0 N T S cer: 0.1667
# 9 transportable pred: T R AE0 N S P EH1 R T AH0 B AH0 L ref: T R AE0 N S P AO1 R T AH0 B AH0 L cer: 0.0769
# 10 inscribes pred: IH2 N S K R AY1 B Z ref: IH2 N S K R AY1 B Z cer: 0.0000
# 11 grandbaby pred: G R AE1 N D B EH2 K IY0 ref: G R AE1 N D B EY2 B IY0 cer: 0.2222
# 12 costanzo pred: K AH0 S T OW1 N T OW0 ref: K OW0 S T AA1 N Z OW0 cer: 0.3750
# 13 novakovich pred: N AA1 V AH0 K AH0 V IH0 CH ref: N AH0 V AA1 K AH0 V IH0 CH cer: 0.2222
# 14 engulfing pred: EH1 NG G AH0 L F IH0 NG ref: IH0 N G AH1 L F IH0 NG cer: 0.3750
# 15 jorgenson pred: JH AO1 R G AH0 N S AH0 N ref: JH AO1 R G IH0 N S AH0 N cer: 0.1111
# 16 marketeers pred: M AA1 R K AH0 T ER0 Z ref: M AA2 R K AH0 T IH1 R Z cer: 0.3333
# 17 branagan pred: B R AE1 N G AH0 N ref: B R AE1 N AH0 G AE0 N cer: 0.2500
# 18 toshimitsu pred: TH AH0 S IH1 M AH0 T IY0 Z ref: T OW0 SH IY0 M IY1 T S UW0 cer: 0.7778
# 19 electrobiology pred: IH2 L EH2 K T R OW0 B AA1 G AH0 L ref: IH2 L EH2 K T R OW0 B AY0 AA1 L AH0 JH IY2 cer: 0.2857
# 20 flagships pred: F L AE1 G HH AH0 S T ref: F L AE1 G SH IH2 P S cer: 0.5000
# 21 downsizing pred: D AW1 S N IH0 S IH0 NG ref: D AW1 N S AY2 Z IH0 NG cer: 0.5000
# 22 biofeedback pred: B IH1 CH B AE2 D AH0 B ref: B AY0 OW0 F IY1 D B AE2 K cer: 0.7778
# 23 retrovir pred: R IY0 T R UW1 V IH0 N ref: R EH1 T R OW0 V IH2 R cer: 0.5000
# 24 jovanovic pred: JH OW0 V AE1 N IH0 K AH0 T ref: Y AH0 V AH0 N AA1 V IH0 K cer: 0.7778
# 25 conjugated pred: K AH0 N JH AH1 G T IH0 D ref: K AA2 N JH AH0 G EY1 T IH0 D cer: 0.3000
# 26 brooksville pred: B R AH1 K S V IH2 L ref: B R UH1 K S V IH0 L cer: 0.2500
# 27 nonperforming pred: N AA1 M P ER0 NG P IH0 NG ref: N AA0 N P ER0 F AO1 R M IH0 NG cer: 0.5455
# 28 fulfilling pred: F AH1 F L IH0 NG ref: F UH0 L F IH1 L IH0 NG cer: 0.3750
# 29 conjecture pred: K AH0 N JH EH1 CH ER0 T ref: K AH0 N JH EH1 K CH ER0 cer: 0.2500
# 30 adjustments pred: AE1 NG F AH0 S T AH0 V Z ref: AH0 JH AH1 S T M AH0 N T S cer: 0.8000
# 31 hoglund's pred: HH AA1 G L AH0 N D Z ref: HH AO1 G L AH0 N D Z cer: 0.1250
# 32 languished pred: L AE1 NG G W IH0 SH T ref: L AE1 NG G W IH0 SH T cer: 0.0000
# 33 obscenity pred: AH0 B S IH1 N IH0 T IY0 ref: AH0 B S EH1 N IH0 T IY0 cer: 0.1250
# 34 kingsport pred: K IH1 N S T ER0 F ref: K IH1 NG S P AO2 R T cer: 0.6250
# 35 premonitory pred: P R AH0 M EH1 N IH0 T IY0 ref: P R AH0 M AH1 N AH0 T ER0 IY0 cer: 0.3000
# 36 slowinski pred: S L AH0 V IH1 N S K IY0 ref: S L OW0 IH1 N S K IY0 cer: 0.2500
# 37 schiltknecht pred: S K IH1 L T AH0 N K T ref: SH IH1 L T N EH2 K T cer: 0.5000
# 38 stolichnaya pred: S T AH0 L IH1 D AH0 N ref: S T OW2 L IH0 K N AY1 AH0 cer: 0.6667
# 39 subfamily pred: S AH1 B SH AH0 M IH0 T ref: S AH1 B F AE2 M AH0 L IY0 cer: 0.5556
# 40 peterbilt pred: P EH1 T ER0 B IH2 L ref: P IY1 T ER0 B IH2 L T cer: 0.2500
# 41 mcdermid pred: M AH0 K D R IY1 M D ref: M AH0 K D ER1 M AH0 D cer: 0.3750
# 42 simulcast pred: S IH1 M Y AH0 L K AE2 S T ref: S AY1 M Y AH0 L K AE2 S T cer: 0.1000
# 43 reemergence pred: R IY0 EH1 M ER0 D AH0 N S ref: R IY0 IH0 M ER1 JH AH0 N S cer: 0.3333
# 44 papadopoulos pred: P AH0 P AH0 D EH1 L AH0 P OW2 Z ref: P AE2 P AH0 D AA1 P AH0 L AH0 S cer: 0.5455
# 45 factually pred: F AE1 K T UW0 L IY0 ref: F AE1 K CH UW0 AH0 L IY0 cer: 0.2500
# 46 hildegarde pred: HH IH1 L D AH0 G AE2 R D ref: HH IH1 L D IH0 G AA2 R D cer: 0.2222
# 47 gingerbread pred: G IH1 NG G ER0 B EH2 R D ref: JH IH1 N JH ER0 B R EH2 D cer: 0.5556
# 48 rosenman pred: R OW1 Z AH0 N M AH0 N ref: R OW1 Z AH0 N M AH0 N cer: 0.0000
# 49 unabated pred: AH2 N AH0 B EH1 T IH0 D ref: AH2 N AH0 B EY1 T IH0 D cer: 0.1250
# 50 batignolles pred: B AE1 T IH0 NG B AH0 L Z ref: B AE2 T IH0 N Y OW1 L AH0 S cer: 0.6000
# 51 frazzini pred: F R AH0 S IH1 N IY0 ref: F R AA0 T S IY1 N IY0 cer: 0.3750
# 52 disapproving pred: D IH0 S P AA1 R N IH0 JH ref: D IH0 S AH0 P R UW1 V IH0 NG cer: 0.5000
# 53 ventilating pred: V EH1 N T AH0 L EY2 T IH0 NG ref: V EH1 N T AH0 L EY2 T IH0 NG cer: 0.0000
# 54 believability pred: B EH2 L IY0 V AE1 B IH0 T L IY0 ref: B AH0 L IY2 V AH0 B IH1 L IH0 T IY0 cer: 0.5000
# 55 punctuating pred: P AH1 N K T AH0 CH IH0 V ref: P AH1 NG K CH UW0 EY2 D IH0 NG cer: 0.6000
# 56 countdowns pred: K AW1 N T AH0 N D Z ref: K AW1 N T D AW2 N Z cer: 0.3750
# 57 legalities pred: L EH1 G AH0 L AY2 T S ref: L IY0 G AE1 L IH0 T IY0 Z cer: 0.5556
# 58 intercellular pred: IH2 N T ER0 K L EH1 L ER0 ref: IH2 N T ER0 S EH1 L Y AH0 L ER0 cer: 0.3636
# 59 extravaganza pred: EH2 K S T R AH0 V AA1 G AH0 S AH0 M ref: EH0 K S T R AE2 V AH0 G AE1 N Z AH0 cer: 0.5385
# 60 entombment pred: AH0 N T EH1 M P AH0 N AH0 B ref: IH0 N T UW1 M M AH0 N T cer: 0.5556
# 61 suspensions pred: S AH1 S P AH0 N S AH0 N Z ref: S AH0 S P EH1 N SH AH0 N Z cer: 0.3000
# 62 recognition's pred: R IH0 K W AA1 N T AH0 N AH0 S ref: R EH2 K IH0 G N IH1 SH AH0 N Z cer: 0.6364
# 63 compartments pred: K AA1 M P ER0 T M AH0 N T S ref: K AH0 M P AA1 R T M AH0 N T S cer: 0.2500
# 64 triumphantly pred: T R IH1 M S T AH0 N IY0 ref: T R AY0 AH1 M F AH0 N T L IY0 cer: 0.5455
# 65 unreliable pred: AH0 N R EH1 L IY0 B AH0 L ref: AH2 N R IH0 L AY1 AH0 B AH0 L cer: 0.4000
# 66 northwestern's pred: N AO1 R T W ER2 S T AH0 N Z ref: N AO2 R TH W EH1 S T ER0 N Z cer: 0.3636
# 67 hempfling pred: HH EH1 M F AH0 N T IH0 D ref: HH EH1 M P F AH0 L IH0 NG cer: 0.4444
# 68 renegotiate pred: R IY0 N EH1 G IH0 T AH0 T ref: R IY2 N IH0 G OW1 SH IY0 EY2 T cer: 0.6000
# 69 mandalit pred: M AE1 N D AH0 L IH0 T ref: M AE1 N D AH0 L IH2 T cer: 0.1250
# 70 criscione pred: K R IH1 S IY0 AH0 N ref: K R IY0 S CH OW1 N IY0 cer: 0.5000
# 71 gilchrest pred: G IH1 L K R AH0 S T ref: G IH1 L K ER0 IH0 S T cer: 0.2500
# 72 interiors pred: IH2 N T EH1 R IY0 ER0 Z ref: IH2 N T IH1 R IY0 ER0 Z cer: 0.1250
# 73 misdiagnosis pred: M IH0 S D IH1 T IH0 NG Z AH0 Z ref: M IH0 S D AY2 IH0 G N OW1 S AH0 S cer: 0.5833
# 74 repositories pred: R EH2 P AH0 S IH1 T ER0 IY0 Z ref: R IY0 P AA1 Z AH0 T AO2 R IY0 Z cer: 0.5455
# 75 lithuanian pred: L AY2 T HH AA1 N IY0 AH0 N ref: L IH2 TH AH0 W EY1 N IY0 AH0 N cer: 0.5000
# 76 transcanada's pred: T R AE0 N S K AE1 N D AH0 Z ref: T R AE2 N Z K AE1 N AH0 D AH0 Z cer: 0.2500
# 77 badalamenti pred: B AE2 D AH0 L M EY1 N IY0 ref: B AA0 D AA0 L AA0 M EH1 N T IY0 cer: 0.4545
# 78 verifiable pred: V EH1 R IY0 F AH0 B AH0 L ref: V EH1 R AH0 F AY2 AH0 B AH0 L cer: 0.2000
# 79 hempstead pred: HH EH1 M P T S W AH0 D ref: HH EH1 M P S T EH0 D cer: 0.3750
# 80 prerecorded pred: P R IY0 P ER0 D EH1 S ref: P R IY2 R IY0 K AO1 R D IH0 D cer: 0.6364
# 81 clipboard pred: K L IH1 B AO2 R D ref: K L IH1 P B AO2 R D cer: 0.1250
# 82 paganism pred: P AE1 G N AH0 S IH2 Z ref: P EY1 G AH0 N IH2 Z AH0 M cer: 0.5556
# 83 fabricate pred: F AE1 B R AH0 K EY2 T ref: F AE1 B R AH0 K EY2 T cer: 0.0000
# 84 teleprobe pred: T EH1 L AH0 P R OW2 B ref: T EH1 L AH0 P R OW1 B cer: 0.1250
# 85 cryogenic pred: K R IY0 IY0 AA1 T IH0 NG ref: K R AY1 AH0 JH EH2 N IH0 K cer: 0.6667
# 86 unmanaged pred: AH0 N M AE1 N IH0 JH ref: AH0 N M AE1 N IH0 JH D cer: 0.1250
# 87 intricate pred: IH2 N T R IH1 K T AH0 ref: IH1 N T R AH0 K AH0 T cer: 0.5000
# 88 familiarize pred: F AH0 M IH1 L IY0 ER0 AY2 Z ref: F AH0 M IH1 L Y ER0 AY2 Z cer: 0.1111
# 89 st-thomas pred: S T AE1 TH M AH0 S ref: S EY1 N T AA1 M AH0 S cer: 0.5000
# 90 kredietbank pred: K R EH1 D AH0 B AH0 N T ref: K R EH0 D IY0 T B AE1 NG K cer: 0.6000
# 91 santa-fe's pred: S AE1 N T AH0 F AY2 Z ref: S AE1 N T AH0 F EY1 Z cer: 0.1250
# 92 distillate pred: D IH0 S T IH1 L AH0 T ref: D IH1 S T AH0 L EY2 T cer: 0.3750
# 93 palkovic pred: P AH0 L AA1 D IH0 K S ref: P AH0 L K AA1 V IH0 K cer: 0.3750
# 94 calculate pred: K AH0 L K AE1 L AH0 T ref: K AE1 L K Y AH0 L EY2 T cer: 0.4444
# 95 plebeians pred: P EH1 L AH0 B AH0 N Z ref: P L AH0 B IY1 AH0 N Z cer: 0.2500
# 96 insubordination pred: IH2 N S B AO2 R D IY0 OW1 N AH0 M AH0 N ref: IH2 N S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.3571
# 97 recommendations pred: R IY0 K AH0 M N AH0 M EY1 D AH0 N Z ref: R EH2 K AH0 M AH0 N D EY1 SH AH0 N Z cer: 0.3846
# 98 galentine pred: G AH0 L EH1 N T IY0 N ref: G AA0 L EH0 N T IY1 N IY0 cer: 0.4444
# 99 comedienne pred: K AH0 M EH1 D IY0 AH0 N ref: K AH0 M IY2 D IY0 EH1 N cer: 0.2500
# 100 stolarski pred: S T AH0 L AO1 R S K IY0 ref: S T AH0 L AA1 R S K IY2 cer: 0.2222
# 101 reprocessed pred: R IH0 P R OW1 S IH0 S T ref: R IY0 P R AO1 S EH0 S T cer: 0.3333
# 102 d'artagnan pred: D AA1 R T AH0 N AH0 G ref: D AH0 R T AE1 NG Y AH0 N # foreign french cer: 0.5833
# 103 radiators pred: R AE1 D IY0 EY2 T ER0 Z ref: R EY1 D IY0 EY2 T ER0 Z cer: 0.1250
# 104 rollerblading pred: R AA1 L B ER0 B IH0 NG L IY0 ref: R OW1 L ER0 B L EY2 D IH0 NG cer: 0.7000
# 105 depended pred: D IH0 P EH1 N D IH0 D ref: D IH0 P EH1 N D AH0 D cer: 0.1250
# 106 sardinia pred: S AA0 R D IY1 N IY0 AH0 ref: S AA0 R D IY1 N IY0 AH0 cer: 0.0000
# 107 intending pred: IH2 N T EH1 N D IH0 NG ref: IH2 N T EH1 N D IH0 NG cer: 0.0000
# 108 homogenization pred: HH OW2 M AH0 JH AH0 N EY1 SH AH0 N AH0 L ref: HH OW0 M AA1 JH AH0 N IH0 Z EY2 SH AH0 N cer: 0.5385
# 109 telecasts pred: T EH1 L AH0 K AE2 S T S ref: T EH1 L AH0 K AE2 S T S cer: 0.0000
# 110 matriculating pred: M AH0 T R IH1 K Y AH0 L EY2 T IH0 NG ref: M AH0 T R IH1 K Y AH0 L EY0 T IH0 NG cer: 0.0769
# 111 conception pred: K AH0 N S EH1 P SH AH0 N ref: K AH0 N S EH1 P SH AH0 N cer: 0.0000
# 112 simonson pred: S AH0 M EH1 N S AH0 N ref: S IH1 M AH0 N S AH0 N cer: 0.2500
# 113 inoffensive pred: IH2 N AH0 F IH1 N S T IH0 D ref: IH2 N AH0 F EH1 N S IH0 V cer: 0.3333
# 114 nationalistic pred: N AE2 SH AH0 N AH0 L IH1 T IH0 K S ref: N AE2 SH AH0 N AH0 L IH1 S T IH0 K cer: 0.1667
# 115 fantastically pred: F AE1 N T AH0 S T IH0 K L IY0 ref: F AE0 N T AE1 S T IH0 K L IY0 cer: 0.1818
# 116 istituto pred: IH2 S T IH1 T AH0 F OW2 ref: IH2 S T IH0 T UW1 T OW0 cer: 0.5000
# 117 florentino pred: F L AO0 R N EH1 N T IY0 ref: F L AO0 R EH0 N T IY1 N OW0 cer: 0.5000
# 118 microcircuit pred: M IH0 K R AH0 S EH1 K T IH0 K ref: M AY1 K R OW0 S ER2 K AH0 T cer: 0.6000
# 119 imperfectly pred: IH2 M P ER1 F IH0 K L IY0 ref: IH2 M P ER1 F IH0 K T L IY0 cer: 0.1000
# 120 desegregation pred: D IH0 S EH2 G R AH0 G EY1 SH AH0 N ref: D IH0 S EH2 G R AH0 G EY1 SH AH0 N cer: 0.0000
# 121 fleischhacker pred: F L IH1 K HH AE2 S K ER0 ref: F L AY1 SH HH AH0 K ER0 cer: 0.5000
# 122 dupriest pred: D Y UW1 P R AH0 S T ref: D AH1 P ER0 IY0 IH0 S T cer: 0.6250
# 123 unattractive pred: AH0 N T AO1 R T AH0 K EY2 T ref: AH2 N AH0 T R AE1 K T IH0 V cer: 0.8000
# 124 sanhedrin pred: S AE1 N D HH EH2 R IY0 ref: S AE2 N HH IY1 D R IH0 N cer: 0.6667
# 125 callousness pred: K AE1 L AH0 N S IH0 Z ref: K AE1 L AH0 S N AH0 S cer: 0.5000
# 126 dermatologist pred: D ER0 M AH0 T AA1 L AH0 JH IH0 S T ref: D ER2 M AH0 T AA1 L AH0 JH IH0 S T cer: 0.0833
# 127 harmonics pred: HH AA0 R M AA1 N IH0 K S ref: HH AA0 R M AA1 N IH0 K S cer: 0.0000
# 128 deployable pred: D IH0 P L AE1 B AH0 L ref: D IH0 P L OY1 AH0 B AH0 L cer: 0.2222
# 129 approximately pred: AH0 P R AA1 K AH0 P AH0 S L IY0 ref: AH0 P R AA1 K S AH0 M AH0 T L IY0 cer: 0.2500
# 130 remerchandise pred: R IY0 M EH1 K R AH0 N D Z ref: R IY0 M ER1 CH AH0 N D AY2 Z cer: 0.4000
# 131 bianchini pred: B AY0 N AE1 K AH0 N ref: B IY0 AA0 N CH IY1 N IY0 cer: 0.7500
# 132 invigorating pred: IH2 N V IH1 G ER0 EY2 T IH0 NG ref: IH2 N V IH1 G ER0 EY2 T IH0 NG cer: 0.0000
# 133 castellanos pred: K AH0 S T EH1 L N AH0 S ref: K AA0 S T EY0 L AA1 N OW0 Z cer: 0.5000
# 134 hippopotamus pred: HH IH1 P AH0 P AH0 T M AH0 S ref: HH IH2 P AH0 P AA1 T AH0 M AH0 S cer: 0.2727
# 135 vanorden pred: V AE1 N D R AH0 N ref: V AE0 N AO1 R D AH0 N cer: 0.3750
# 136 biographical pred: B Y UW0 G R EY1 F IH0 K AH0 L ref: B AY2 AH0 G R AE1 F IH0 K AH0 L cer: 0.2727
# 137 tartikoff pred: T AA1 R T IH0 K OW2 F ref: T AA1 R T IH0 K AO2 F cer: 0.1250
# 138 transcontinental pred: T R AE2 N S K AH0 N T EH1 N AH0 L AH0 S ref: T R AE2 N Z K AA2 N T IH0 N EH1 N T AH0 L cer: 0.4375
# 139 mongosutu's pred: M AH0 G N UW1 Z AH0 W AH0 L Z ref: M AA2 NG G OW0 S UW1 T UW0 Z cer: 0.9000
# 140 parametric pred: P ER0 AE1 M ER0 T IH0 K ref: P EH2 R AH0 M EH1 T R IH0 K cer: 0.5000
# 141 linguistically pred: L IH2 NG G AH0 L IH1 S T IH0 K AH0 L ref: L IH0 NG G W IH1 S T IH0 K L IY0 cer: 0.4167
# 142 crotonville pred: K R AA1 N T AH0 V IH2 L ref: K R OW1 T AH0 N V IH2 L cer: 0.3333
# 143 recriminations pred: R IY0 K R IH2 M AH0 N EY1 SH AH0 N Z ref: R IH0 K R IH2 M IH0 N EY1 SH AH0 N Z cer: 0.1538
# 144 toxicologists pred: T AE2 K S AH0 K AA1 L AH0 JH IH0 S T S ref: T AA2 K S IH0 K AA1 L AH0 JH IH0 S T S cer: 0.1429
# 145 holtzapple pred: HH AO1 L T S P AH0 L ref: HH OW1 L T Z AH0 P AH0 L cer: 0.3333
# 146 toriente pred: T AO1 R IY0 N T EH2 ref: T AO2 R IY0 EH1 N T EY0 cer: 0.3750
# 147 utility pred: Y UW0 T IH1 L AH0 T IY0 ref: Y UW0 T IH1 L AH0 T IY0 cer: 0.0000
# 148 norberta pred: N AO1 R B ER0 T ref: N AO0 R B EH1 R T AH0 cer: 0.5000
# 149 amputated pred: AH0 M P AH1 T IH0 T ref: AE1 M P Y AH0 T EY2 T IH0 D cer: 0.6000
# 150 pleasanton pred: P L EH1 Z AH0 N T AH0 N ref: P L EH1 Z AH0 N T AH0 N cer: 0.0000
# 151 mollycoddle pred: M AH0 L IH1 D AH0 L OW2 ref: M AA1 L IY0 K AA2 D AH0 L cer: 0.5556
# 152 lexical pred: L EH1 K S AH0 K AH0 L ref: L EH1 K S IH0 K AH0 L cer: 0.1250
# 153 omnipotent pred: AH0 M N EH1 P AH0 N T AH0 L ref: AA0 M N IH1 P AH0 T AH0 N T cer: 0.5000
# 154 repudiating pred: R IH0 P AH1 D IH0 T IH0 NG ref: R IY0 P Y UW1 D IY0 EY2 T IH0 NG cer: 0.4545
# 155 avant-garde pred: AH0 V AE1 N T IH0 JH ER0 ref: AH0 V AA1 N T G AA1 R D cer: 0.5556
# 156 toldrian pred: T AO1 L D R IY0 AH0 N ref: T OW1 L D R IY0 AH0 N cer: 0.1250
# 157 transformers pred: T R AE1 N S F ER0 M Z ref: T R AE0 N S F AO1 R M ER0 Z cer: 0.3636
# 158 eurobond pred: Y UW1 R AH0 B AO2 N D ref: Y UW1 R OW0 B AA2 N D cer: 0.2500
# 159 redistributing pred: R IY0 D IH0 S T R IH1 B IH0 T IH0 NG ref: R IY2 D IH0 S T R IH1 B Y UW0 T IH0 NG cer: 0.2143
# 160 osmundson pred: AH0 S M AH1 N D AH0 N ref: AA1 Z M AH0 N D S AH0 N cer: 0.4444
# 161 basements pred: B AE1 S AH0 M AH0 N T S ref: B EY1 S M AH0 N T S cer: 0.2500
# 162 securely pred: S EH1 K Y ER0 L IY0 ref: S IH0 K Y UH1 R L IY0 cer: 0.3750
# 163 unremarked pred: AH0 N R EH1 M ER0 D EY2 K ref: AH0 N R IH0 M AA1 R K T cer: 0.5556
# 164 comparing pred: K AH0 M P AA1 R IH0 NG ref: K AH0 M P EH1 R IH0 NG cer: 0.1250
# 165 lillibridge pred: L IH1 L IH0 B ER0 G ref: L IH1 L IH0 B R IH2 JH cer: 0.3750
# 166 afterimages pred: AE1 F T ER0 M IH0 JH IH0 Z ref: AE1 F T ER0 IH2 M IH0 JH AH0 Z cer: 0.2000
# 167 supergiant pred: S AH1 B ER0 SH AH0 N T ref: S UW1 P ER0 JH AY1 AH0 N T cer: 0.4444
# 168 opponent's pred: AA1 P AH0 N EY2 T IH0 D Z ref: AH0 P OW1 N AH0 N T S cer: 0.8750
# 169 microwaved pred: M IH0 K R OW1 V IY0 AH0 B ref: M AY1 K R OW0 W EY2 V D cer: 0.6667
# 170 corinthian pred: K ER0 IH1 N SH AH0 N T ref: K ER0 IH1 N TH IY0 AH0 N cer: 0.3750
# 171 lipoprotein pred: L IY2 P AH0 P R EY1 SH AH0 N ref: L IH2 P AH0 P R OW1 T IY0 N cer: 0.4000
# 172 repositioning pred: R EH2 P AH0 Z IH1 SH AH0 N IH0 NG ref: R IY2 P AH0 Z IH1 SH AH0 N IH0 NG cer: 0.0909
# 173 mutilation pred: M Y UW0 T IH1 L AH0 T IY0 ref: M Y UW2 T AH0 L EY1 SH AH0 N cer: 0.6000
# 174 meteorologists pred: M EH2 T ER0 AA1 L AH0 JH IH0 S T S ref: M IY2 T IY0 ER0 AA1 L AH0 JH IH0 S T S cer: 0.1538
# 175 pierrepont pred: P AY1 ER0 P AH0 N T ref: P IH0 R EY1 P OW0 N T cer: 0.5000
# 176 ecstatic pred: IH0 K S T AE1 T IH0 K ref: EH0 K S T AE1 T IH0 K cer: 0.1250
# 177 branaman pred: B R AE1 N AH0 M AH0 N ref: B R AE1 N AH0 M AH0 N cer: 0.0000
# 178 suffocated pred: S AH1 F AH0 K EY2 T IH0 D ref: S AH1 F AH0 K EY2 T IH0 D cer: 0.0000
# 179 hovnanian pred: HH OW1 N V IY0 AH0 N ref: HH AA2 V N EY1 N IY0 AH0 N cer: 0.4444
# 180 criss-cross pred: K R IH1 S K R OW2 Z ref: K R IH1 S K R AO1 S cer: 0.2500
# 181 northeast's pred: N AO1 R TH IH0 T AH0 S ref: N AO2 R TH IY1 S T S cer: 0.5000
# 182 disfigurement pred: D IH2 S F IH1 G ER0 M AH0 N T ref: D IH0 S F IH1 G Y ER0 M EH0 N T cer: 0.2500
# 183 stapling pred: S T AE1 P L IH0 NG ref: S T EY1 P AH0 L IH0 NG cer: 0.2500
# 184 buttressing pred: B AO1 R T IH0 S IH0 NG ref: B AH1 T R AH0 S IH0 NG cer: 0.5000
# 185 telefonos pred: T EH2 L AH0 F OW1 N AH0 Z ref: T EH2 L EH0 F OW1 N OW0 S cer: 0.3333
# 186 reflexivity pred: R IH0 F L IH1 S T IH0 K L IY0 ref: R IY2 F L EH2 K S IH1 V IH0 T IY0 cer: 0.5833
# 187 profitably pred: P R AH0 F IH1 T IH0 B L IY0 ref: P R AA1 F AH0 T AH0 B L IY0 cer: 0.3000
# 188 grudzinski pred: G R AH0 D IH1 S T IH0 N ref: G R AH0 JH IH1 N S K IY0 cer: 0.5556
# 189 non-poisonous pred: N AA2 N P AH0 Z IY1 N AH0 Z ref: N AA0 N P OY1 Z AH0 N AH0 S cer: 0.4000
# 190 tallahassee's pred: T AA1 L AH0 SH AH0 S ref: T AE2 L AH0 HH AE1 S IY0 Z cer: 0.5556
# 191 trombones pred: T R OW1 M AH0 B AH0 N Z ref: T R AA0 M B OW1 N Z cer: 0.3750
# 192 rosengrant pred: R OW1 Z AH0 N G R AE2 N T ref: R OW1 Z AH0 N G R AE2 N T cer: 0.0000
# 193 laceration pred: L AE2 S ER0 EY1 SH AH0 N ref: L AE2 S ER0 EY1 SH AH0 N cer: 0.0000
# 194 ricketson pred: R IH0 K EH1 S T AH0 N ref: R IH1 K IH0 T S AH0 N cer: 0.5000
# 195 bankworcester pred: B AE1 NG K W ER2 M AH0 N T ER0 Z ref: B AE1 NG K W ER1 CH EH2 S T ER0 cer: 0.4545
# 196 operations pred: OW2 P ER0 EY1 SH AH0 N Z ref: AA2 P ER0 EY1 SH AH0 N Z cer: 0.1250
# 197 subunits pred: S AH1 B Y AH0 N T S ref: S AH2 B Y UW1 N IH0 T S cer: 0.3333
# 198 yogiisms pred: Y UW1 CH IH0 S T S ref: Y OW0 G IY1 S AH0 M Z cer: 0.7500
# 199 mazziotti pred: M AH0 Z IH1 T IY0 ref: M AA0 T S IY0 OW1 T IY0 cer: 0.6250
# 200 dornhens pred: D AO1 R N HH EH2 N Z ref: D AO1 R N HH EH0 N Z cer: 0.1250
# 201 crustaceous pred: K R AH1 S T AH0 K AH0 N T S ref: K R AH0 S T EY1 SH AH0 S cer: 0.5556
# 202 dilenschneider pred: D IH0 L EH1 N S AH0 N HH EH2 R ref: D AY1 L AH0 N SH N AY2 D ER0 cer: 0.7000
# 203 innovated pred: IH2 N AA1 V AH0 T IH0 D ref: IH1 N AH0 V EY2 T IH0 D cer: 0.3750
# 204 disseminated pred: D IH0 S IH1 M AH0 N T IH0 D ref: D IH0 S EH1 M AH0 N EY2 T AH0 D cer: 0.2727
# 205 auxiliary pred: AH0 K Y UW1 Z AH0 L AY2 R ref: AA0 G Z IH1 L Y ER0 IY0 cer: 1.0000
# 206 mississippi's pred: M IH0 S S IH1 P IH0 S ref: M IH2 S IH0 S IH1 P IY0 Z cer: 0.4444
# 207 noranda's pred: N AA0 R D AA1 N AH0 Z ref: N AO0 R AE1 N D AH0 Z cer: 0.5000
# 208 altercations pred: AH0 L T EH1 R K AH0 SH AH0 N Z ref: AA2 L T ER0 K EY1 SH AH0 N Z cer: 0.4000
# 209 overwhelming pred: HH EH1 R W AH0 L IH0 NG ref: OW2 V ER0 W EH1 L M IH0 NG cer: 0.5556
# 210 enforces pred: AH0 N F AO1 R S IH0 Z ref: EH0 N F AO1 R S IH0 Z cer: 0.1250
# 211 reportedly pred: R IH0 P AO1 R T AH0 L D ref: R IH0 P AO1 R T AH0 D L IY0 cer: 0.2000
# 212 tricentrol pred: T R IH1 S T AH0 N AO0 R L ref: T R AY2 S EH1 N T R AA0 L cer: 0.5000
# 213 pontifical pred: P AA2 N T IH0 F IH1 K AH0 L ref: P AA0 N T IH1 F AH0 K AH0 L cer: 0.3000
# 214 intermittent pred: IH2 N T ER0 M AE1 T AH0 N T ref: IH2 N T ER0 M IH1 T AH0 N T cer: 0.1000
# 215 reacquired pred: R IY0 K AA1 W ER0 D ref: R IY0 AH0 K W AY1 R D cer: 0.5000
# 216 expropriated pred: IH0 K S P R AA1 P IH0 T ER0 D ref: EH0 K S P R OW1 P R IY0 EY2 T IH0 D cer: 0.4615
# 217 autenrieth pred: AO1 T ER0 N AY2 T IH0 K ref: AW1 T IH0 N R IY0 IH0 TH cer: 0.6250
# 218 donaldson's pred: D AA1 N AH0 L D AH0 N S ref: D AA1 N AH0 L D S AH0 N Z cer: 0.2000
# 219 amputate pred: AH0 M P AH1 T AH0 T ref: AE1 M P Y AH0 T EY2 T cer: 0.5000
# 220 bankcards pred: D AE1 K AH0 N B ER0 Z ref: B AE1 NG K AA2 R D Z cer: 0.7500
# 221 taliban's pred: T AE1 L AH0 B AH0 N Z ref: T AE1 L IH0 B AE2 N Z cer: 0.2500
# 222 overreacts pred: OW1 V ER0 R IH0 K AH0 T S ref: OW1 V ER0 R IY0 AE1 K T S cer: 0.3333
# 223 neutralizing pred: N UW1 T R AH0 L AY2 Z IH0 NG ref: N UW1 T R AH0 L AY2 Z IH0 NG cer: 0.0000
# 224 bighorns pred: B IH1 G ER0 N Z ref: B IH1 G HH AO2 R N Z cer: 0.3750
# 225 marianas pred: M AA0 R IY0 AA1 N AH0 Z ref: M EH2 R IY0 AE1 N AH0 S cer: 0.3750
# 226 obsessions pred: AH0 B Z IH1 SH AH0 N Z ref: AH0 B S EH1 SH AH0 N Z cer: 0.2500
# 227 chujitsuya pred: CH UW0 Y UW0 IH1 T AH0 S ref: CH UW2 JH IY0 T S UW2 Y AA0 cer: 0.8889
# 228 astronautical pred: AH0 S T R AH0 N EY1 T IH0 K AH0 L ref: AE2 S T R AH0 N AA1 T IH0 K AH0 L cer: 0.1667
# 229 wranglings pred: R AA1 G L IH0 NG Z IH0 Z ref: R AE1 NG G AH0 L IH0 NG Z cer: 0.5556
# 230 catacosinos pred: K AE2 T AH0 K OW0 S IY1 N AH0 S ref: K AH0 T AE2 K AH0 S IY1 N OW0 S cer: 0.3636
# 231 counteroffers pred: K AW1 N T ER0 F AO2 R D Z ref: K AW1 N T ER0 AO2 F ER0 Z cer: 0.3333
# 232 indigenous pred: IH2 N D IH1 G N AH0 S ref: IH2 N D IH1 JH AH0 N AH0 S cer: 0.2222
# 233 muhabara pred: M UW0 B AA0 Y AA1 R AH0 ref: M UW2 HH AH0 B AA1 R AH0 cer: 0.5000
# 234 disinfection pred: D IH0 S IH2 N F AH0 K EY1 SH AH0 N ref: D IH0 S IH0 N F EH1 K SH AH0 N cer: 0.2727
# 235 interlinked pred: IH2 N T ER0 L IH1 N S T ref: IH2 N T ER0 L IH1 NG K T cer: 0.2222
# 236 extensions pred: IH0 K S T EH1 N SH AH0 N Z ref: IH0 K S T EH1 N SH AH0 N Z cer: 0.0000
# 237 adjectives pred: AE1 D AH0 G EY2 T IH0 D Z ref: AE1 JH IH0 K T IH0 V Z cer: 0.6250
# 238 yoshimoto pred: Y AH0 SH IY0 AA1 M T OW0 ref: Y OW0 SH IY0 M OW1 T OW0 cer: 0.3750
# 239 instructions pred: IH2 N S T R AH1 K SH AH0 N Z ref: IH2 N S T R AH1 K SH AH0 N Z cer: 0.0000
# 240 kaffenberger pred: K AE1 F AH0 N B ER0 G ER0 ref: K AE1 F AH0 N B ER0 G ER0 cer: 0.0000
# 241 superheroes pred: S UW1 P ER0 HH AW2 R AH0 Z ref: S UW2 P ER0 HH IY1 R OW0 Z cer: 0.3333
# 242 wenceslaus pred: W EH1 N S AH0 L AH0 S AH0 Z ref: W EH1 N S AH0 S L AO2 S cer: 0.4444
# 243 harmoniously pred: HH AA1 R M AH0 N IY0 AH0 L IY0 Z ref: HH AA0 R M OW1 N IY0 AH0 S L IY0 cer: 0.3636
# 244 one-sided pred: AH0 N EH1 S AH0 D IH0 D ref: W AH2 N S AY1 D AH0 D cer: 0.6250
# 245 submarine's pred: S AH1 B M ER0 IY0 AH0 N Z ref: S AH1 B M ER0 IY2 N Z cer: 0.2500
# 246 gantenbein pred: G AE1 N T AH0 N D AY2 N ref: G AE1 N T IH0 N B AY0 N cer: 0.3333
# 247 diagnostics pred: D AY2 AH0 G N AA1 T IH0 K S ref: D AY2 AH0 G N AA1 S T IH0 K S cer: 0.0909
# 248 resembles pred: R EH1 Z AH0 B AH0 L Z ref: R IH0 Z EH1 M B AH0 L Z cer: 0.3333
# 249 kafelnikov pred: K AH0 D EH1 L T AH0 N ref: K AH0 F EH1 L N IH0 K AO2 F cer: 0.6000
# 250 infirmity pred: IH2 N F IH1 R M AH0 T IY0 ref: IH0 N F ER1 M IH0 T IY0 cer: 0.5000
# 251 mouthparts pred: M UW1 T AH0 T ER0 Z ref: M AW1 TH P AA2 R T S cer: 0.8750
# 252 manderscheid pred: M AE1 N D ER0 W IH0 K S ref: M AE1 N D ER0 SH AY2 D cer: 0.5000
# 253 conference pred: K AH0 N F EH1 R AH0 N S ref: K AA1 N F ER0 AH0 N S cer: 0.3750
# 254 grunewald pred: G R UW1 N W AH0 L D ref: G R AH1 N IH0 W AO0 L D cer: 0.3333
# 255 albritton pred: AE1 L T ER0 B AH0 S T ref: AE1 L B R IH0 T AA0 N cer: 0.7500
# 256 delafuente pred: D IH0 L AE1 F AH0 N T IY0 ref: D EY0 L AA0 F W EH1 N T EY0 cer: 0.5000
# 257 contadora pred: K AH0 N T AA1 D ER0 AH0 ref: K AA2 N T AH0 D AO1 R AH0 cer: 0.4444
# 258 rekindle pred: R IH0 K IH1 N D AH0 L ref: R IY0 K IH1 N D AH0 L cer: 0.1250
# 259 unglamorous pred: AH2 N G L AH0 M EH1 R AH0 Z ref: AH0 N G L AE1 M ER0 AH0 S cer: 0.5556
# 260 augustinians pred: AH0 G AH1 S T AH0 N IY0 Z ref: AA2 G AH0 S T IH1 N IY0 AH0 N Z cer: 0.4545
# 261 electricals pred: IH0 L EH1 K T R AH0 S IH0 S T ref: IH0 L EH1 K T R IH0 K AH0 L Z cer: 0.4545
# 262 hamtramck pred: HH AE1 M P R AE2 K AH0 M ref: HH AE0 M T R AE1 M IH0 K cer: 0.6667
# 263 detoxification pred: D EH2 T AH0 K AH0 S P EY1 SH AH0 N ref: D IH0 T AA2 K S IH0 F IH0 K EY1 SH AH0 N cer: 0.5000
# 264 misprints pred: M IH0 S P R EH1 N T S ref: M IH1 S P R IH1 N T S cer: 0.2222
# 265 expansive pred: IH0 K S P AE1 N V IH0 S ref: IH0 K S P AE1 N S IH0 V cer: 0.2222
# 266 lithuania pred: L AY2 T HH AA1 N IY0 AH0 ref: L IH2 TH AH0 W EY1 N IY0 AH0 cer: 0.5556
# 267 arianism pred: AA1 R IY0 AH0 N IH0 S ref: AE1 R IY0 AH0 N IH2 Z AH0 M cer: 0.5556
# 268 dusenbery pred: D UW1 Z AH0 N B EH2 R IY0 ref: D AH0 S EH1 N B ER0 IY0 cer: 0.6250
# 269 lekachman pred: L AH0 K AH1 M T AH0 N ref: L EH1 K AA2 K M AH0 N cer: 0.5000
# 270 militarists pred: M IH1 L AH0 T ER0 AH0 S T S ref: M IH1 L AH0 T ER0 IH0 S T S cer: 0.1000
# 271 mothershead pred: M UW1 T ER0 HH AW2 S IH0 D ref: M AH1 DH ER0 Z HH EH2 D cer: 0.7500
# 272 nonfiction pred: N AA2 N F IH0 K EY1 SH AH0 N ref: N AA0 N F IH1 K SH AH0 N cer: 0.3333
# 273 irrational pred: IH2 R AH0 T IH1 N AH0 L ref: IH2 R AE1 SH AH0 N AH0 L cer: 0.3750
# 274 parachuting pred: P AA1 R K AH0 T IH0 NG ref: P EH1 R AH0 SH UW2 T IH0 NG cer: 0.4444
# 275 somaliland pred: S AH0 M AA1 L AH0 N EY2 T ref: S AH0 M AA1 L IY0 L AE2 N D cer: 0.5000
# 276 graphically pred: G R AE1 F IH0 K AH0 L IY0 ref: G R AE1 F IH0 K L IY0 cer: 0.1250
# 277 pendergast pred: P EH1 N D ER0 G AE2 S T ref: P EH1 N D ER0 G AE2 S T cer: 0.0000
# 278 tousignant pred: T AW1 S T AH0 N AH0 N ref: T UW1 S IH0 G N AH0 N T cer: 0.4444
# 279 himmelberger pred: HH IH1 M B AH0 L ER0 G ER0 ref: HH IH1 M AH0 L B ER0 G ER0 cer: 0.2222
# 280 analyzing pred: AE1 N AH0 L AY2 Z IH0 NG ref: AE1 N AH0 L AY2 Z IH0 NG cer: 0.0000
# 281 unashamedly pred: AH0 N HH AE1 S AH0 M AH0 L IY0 ref: AH2 N AH0 SH EY1 M AH0 D L IY0 cer: 0.6000
# 282 cyclamen pred: S IH1 K AH0 L M AH0 N ref: S AY1 K L AH0 M EH2 N cer: 0.5000
# 283 demodulates pred: D IH0 M AA1 D AH0 L EY2 T S ref: D IY2 M AA2 JH AH0 L EY1 T S cer: 0.4000
# 284 interoperates pred: IH2 N T ER0 P AE1 R AH0 T S ref: IH2 N T ER0 AO1 P ER0 AH0 T S cer: 0.3000
# 285 handicapper pred: HH AE1 N D AH0 P EY2 K ER0 ref: HH AE1 N D IY0 K AE2 P ER0 cer: 0.4444
# 286 stuyvesant pred: S T AY1 V AH0 N S AH0 B ref: S T AY1 V AH0 S AH0 N T cer: 0.3333
# 287 mccleary's pred: M AH0 K L EH1 R AH0 Z ref: M AH0 K L IH1 R IY0 Z cer: 0.2500
# 288 proficiency pred: P R AH0 F IH1 SH AH0 N S IY0 ref: P R AH0 F IH1 SH AH0 N S IY0 cer: 0.0000
# 289 gift-horse pred: F IH1 G AH0 S T ER0 Z ref: G IH1 F T HH AO1 R S cer: 0.8750
# 290 horsemanship pred: HH AO1 R S M AH0 N SH IH2 P ref: HH AO1 R S M AH0 N SH IH0 P cer: 0.1000
# 291 protocols pred: P R AA1 T AH0 K OW2 L Z ref: P R OW1 T AH0 K AO2 L Z cer: 0.2222
# 292 templeton's pred: T EH1 M P L AH0 T AH0 N Z ref: T EH1 M P AH0 L T AH0 N Z cer: 0.2000
# 293 jonbenet's pred: JH AA1 N B AH0 N T S ref: JH AO1 N B AH0 N EY1 S cer: 0.2500
# 294 harbinger pred: HH AA1 R B IH0 NG ER0 ref: HH AA1 R B IH0 N JH ER0 cer: 0.2500
# 295 edification pred: EH2 D IH0 F AH0 K EY1 SH AH0 N ref: EH2 D AH0 F AH0 K EY1 SH AH0 N cer: 0.1000
# 296 cherrystones pred: CH EH1 R S T AW2 N Z ref: CH EH1 R IY0 S T OW2 N Z cer: 0.2222
# 297 overemphasizes pred: OW2 V ER0 EH1 M P IH0 S IH0 Z IY0 ref: OW1 V ER0 EH1 M F AH0 S AY2 Z IH0 Z cer: 0.5000
# 298 clydesdale pred: K L IH1 D AH0 S B AH0 L ref: K L AY1 D Z D EY2 L cer: 0.6250
# 299 goldmark pred: G OW1 L D M ER0 K ref: G OW1 L D M AA2 R K cer: 0.2500
# 300 drinkwater pred: D R IH1 NG K W ER2 TH ref: D R IH1 NG K W AO2 T ER0 cer: 0.3333
# 301 destructed pred: D IH0 S T R AH1 K T IH0 D ref: D IH0 S T R AH1 K T IH0 D cer: 0.0000
# 302 stockholdings pred: S T OW1 K HH OW2 L D IH0 NG Z ref: S T AA1 K HH OW2 L D IH0 NG Z cer: 0.0909
# 303 friendship pred: F R IH1 N D IH0 F S K ref: F R EH1 N D SH IH0 P cer: 0.6250
# 304 isolated pred: IH2 S AE1 L AH0 T IH0 D ref: AY1 S AH0 L EY2 T AH0 D cer: 0.5000
# 305 konishiroku pred: K AH0 N IH0 SH EH1 R AH0 ref: K AA2 N IH2 SH IH0 R OW1 K UW2 cer: 0.6000
# 306 arcement pred: AA1 R K AH0 N M AH0 N T ref: AA0 R S EY1 M AH0 N T cer: 0.5000
# 307 crackpots pred: K R AE1 K T P OW2 S ref: K R AE1 K P AA2 T S cer: 0.3750
# 308 tapestry pred: T AH0 P EH1 S T R IY0 ref: T AE1 P AH0 S T R IY0 cer: 0.2500
# 309 krogstad pred: K R AA1 G S T AE2 D ref: K R AA1 G S T AH0 D cer: 0.1250
# 310 peterson's pred: P EH1 T ER0 S AH0 N Z ref: P IY1 T ER0 S AH0 N Z cer: 0.1250
# 311 experimentally pred: EH2 K S P EH2 R AH0 M EH1 N T AH0 L IY0 ref: IH0 K S P EH2 R AH0 M EH1 N T AH0 L IY0 cer: 0.0714
# 312 humbarger pred: HH AH1 B ER0 K AH0 M ref: HH AH1 M B AA2 R G ER0 cer: 0.6250
# 313 ragavan's pred: R AE1 G AH0 V N AH0 Z ref: R AA1 G AH0 V AA2 N Z cer: 0.3750
# 314 dedicating pred: D IH0 D IH1 K T IH0 NG ref: D EH1 D IH0 K EY2 T IH0 NG cer: 0.3333
# 315 legislating pred: L EH1 G AH0 S T AY2 L IH0 NG ref: L EH1 JH IH0 S L EY2 T IH0 NG cer: 0.5000
# 316 participated pred: P AA1 R T IH0 S P EY2 T IH0 NG ref: P AA0 R T IH1 S AH0 P EY2 T IH0 D cer: 0.3333
# 317 cassandras pred: K AH0 S AE1 N D ER0 Z ref: K AH0 S AE1 N D R AH0 S cer: 0.3333
# 318 mcmillon pred: M AH0 K M IH1 L AH0 N ref: M AH0 K M IH1 L AH0 N cer: 0.0000
# 319 ustrust pred: AH0 S T R UW1 S T ref: Y UW1 EH1 S T R AH1 S T cer: 0.4444
# 320 transnational pred: T R AE0 N Z AE1 N SH AH0 N L IY0 ref: T R AE0 N S N AE1 SH AH0 N AH0 L cer: 0.4167
# 321 mcingvale pred: M AH0 K IH1 V N AH0 L ref: M AE1 K IH0 NG V EY2 L cer: 0.6250
# 322 hornstein pred: HH AO1 R N S T AY2 N ref: HH AO1 R N S T AY2 N cer: 0.0000
# 323 rebounded pred: R IH0 B AW1 N D IH0 D ref: R IY0 B AW1 N D IH0 D cer: 0.1250
# 324 prosecuting pred: P R AA1 S AH0 K AH0 T IH0 NG ref: P R AA1 S IH0 K Y UW2 T IH0 NG cer: 0.2727
# 325 richmond's pred: R IY0 AO1 M D M AH0 N Z ref: R IH1 CH M AH0 N D Z cer: 0.6250
# 326 pentagons pred: P EH1 N T AH0 G AH0 N Z ref: P EH1 N T IH0 G AA2 N Z cer: 0.2222
# 327 cywinski pred: CH IH0 V IH1 N S K IY0 ref: K IH0 V IH1 N S K IY0 cer: 0.1250
# 328 waldheim's pred: W AO1 L D HH AY2 M Z ref: W AO1 L D HH AY2 M Z cer: 0.0000
# 329 forfeiting pred: F AO1 R F IH0 T IH0 NG ref: F AO1 R F AH0 T IH0 NG cer: 0.1250
# 330 forgettable pred: F AO1 R G AH0 T AH0 B AH0 L ref: F AO0 R G EH1 T AH0 B AH0 L cer: 0.2000
# 331 interpreted pred: IH2 N T ER0 P R EH1 T IH0 D ref: IH2 N T ER1 P R AH0 T AH0 D cer: 0.3000
# 332 advisedly pred: AE1 D V IH0 S T IY2 ref: AE0 D V AY1 Z AH0 D L IY0 cer: 0.7778
# 333 ukrainians pred: Y UW2 K R AH0 N EY1 SH AH0 N ref: Y UW0 K R EY1 N IY0 AH0 N Z cer: 0.5000
# 334 pornographic pred: P ER0 N AA1 G R IH0 F IH0 K ref: P AO2 R N AH0 G R AE1 F IH0 K cer: 0.3636
# 335 cardiologist pred: K AA0 R D IH1 G AH0 L IH0 S T ref: K AA2 R D IY0 AA1 L AH0 JH IH0 S T cer: 0.4167
# 336 mcelravy pred: M AH0 K EH1 R AH0 L IY0 ref: M AE1 K AH0 L R EY2 V IY0 cer: 0.5556
# 337 bottenfield pred: B AO1 T AH0 F IY2 N D ref: B AH0 T EH1 N F IY0 L D cer: 0.5556
# 338 allegis's pred: AE1 L IH0 JH IH0 S IH0 Z ref: AE2 L EY1 JH IH0 S IH0 Z cer: 0.2500
# 339 omnibank pred: AH0 M N EH1 B AH0 K AH0 N ref: AA1 M N IH0 B AE2 NG K cer: 0.7500
# 340 uncovering pred: AH0 N K AA1 V ER0 IH0 NG ref: AH0 N K AH1 V ER0 IH0 NG cer: 0.1250
# 341 humidity pred: HH Y UW0 M IH1 D IH0 T IY0 ref: HH Y UW0 M IH1 D AH0 T IY0 cer: 0.1111
# 342 newslink's pred: N EH1 N S L AY2 K S ref: N UW1 Z L IH0 NG K S cer: 0.6250
# 343 littlest pred: L IH1 T AH0 L S T S ref: L IH1 T AH0 L AH0 S T cer: 0.2500
# 344 quantifying pred: K W AA1 N T IH0 F AY2 IH0 NG ref: K W AA1 N T IH0 F AY2 IH0 NG cer: 0.0000
# 345 thorniest pred: TH AO1 R N AH0 S T ref: TH AO1 R N IY0 AH0 S T cer: 0.1250
# 346 lomonaco pred: L OW0 M AA1 N AH0 K OW0 ref: L OW0 M OW0 N AA1 K OW0 cer: 0.2500
# 347 spectrograph pred: S P EH1 K T R AH0 G R AE2 F ref: S P EH1 K T R AH0 G R AE2 F cer: 0.0000
# 348 nonvolatile pred: N AA1 N V AH0 L IH0 T IH0 L ref: N AA0 N V AA1 L AH0 T AH0 L cer: 0.4000
# 349 ljubljana pred: L UW0 B AH0 G L AA1 N AH0 ref: L Y UW1 B L Y AA0 N AH0 cer: 0.6667
# 350 likeliest pred: L IH1 K AH0 L AY2 T S ref: L AY1 K L IY0 AH0 S T cer: 0.6250
# 351 angleton pred: AE1 NG G L IH0 T AH0 N ref: AE1 NG G AH0 L T AH0 N cer: 0.2500
# 352 polakowski pred: P AH0 L AA1 F S K IY0 ref: P AH0 L AH0 K AO1 F S K IY0 cer: 0.3000
# 353 entomologist pred: EH2 N T AH0 M AA1 L AH0 JH IH0 S T ref: EH2 N T AH0 M AA1 L AH0 JH AH0 S T cer: 0.0833
# 354 longstreth pred: L AO1 NG G S T R IY0 ref: L AA1 NG S T R EH0 TH cer: 0.5000
# 355 steinbrink pred: S T IH1 N B R IH2 NG K ref: S T AY1 N B R IH2 NG K cer: 0.1111
# 356 mormonism pred: M AO1 R M AH0 N IH2 Z AH0 M ref: M AO1 R M AH0 N IH0 Z M cer: 0.2222
# 357 assailants pred: AH0 S AE1 S AH0 L T S ref: AH0 S EY1 L AH0 N T S cer: 0.3750
# 358 attributable pred: AH0 T R AE1 B AH0 T B AH0 L ref: AH0 T R IH1 B Y AH0 T AH0 B AH0 L cer: 0.2500
# 359 rotational pred: R OW2 T AH0 T OW1 N AH0 L ref: R OW0 T EY1 SH AH0 N AH0 L cer: 0.4444
# 360 repetitious pred: R EH2 P AH0 T IH1 SH AH0 N Z ref: R EH2 P AH0 T IH1 SH AH0 S cer: 0.2222
# 361 hawkinson pred: HH AA1 K W IH0 N S AH0 N ref: HH AO1 K IH0 N S AH0 N cer: 0.2500
# 362 subordination pred: S UW2 B ER0 D EY1 SH AH0 N IH0 NG ref: S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.5833
# 363 transitory pred: T R AE1 N Z AH0 T AO2 R IY0 ref: T R AE1 N Z AH0 T AO2 R IY0 cer: 0.0000
# 364 incomparable pred: IH2 N K AA1 M P ER0 AH0 B AH0 L ref: IH2 N K AA1 M P ER0 AH0 B AH0 L cer: 0.0000
# 365 ferguson's pred: F ER1 G Y UW0 AH0 N Z AH0 Z ref: F ER1 G AH0 S AH0 N Z cer: 0.5000
# 366 sandhogs pred: S AE1 N D HH OW2 S ref: S AE1 N D HH AO2 G Z cer: 0.3750
# 367 schoolgirls pred: SH AO1 L AH0 F ER0 Z ref: S K UW1 L G ER2 L Z cer: 0.7500
# 368 metrically pred: M EH1 T R AH0 K AH0 L IY0 ref: M EH1 T R IH0 K AH0 L IY0 cer: 0.1111
# 369 castration pred: K AE1 S T R AH0 SH AH0 N ref: K AE2 S T R EY1 SH AH0 N cer: 0.2222
# 370 liberalism's pred: L IH1 B ER0 AH0 L IH2 Z AH0 M ref: L IH1 B ER2 AH0 L IH2 Z AH0 M Z cer: 0.1818
# 371 introduce pred: IH2 N T R AE1 D AH0 K ref: IH2 N T R AH0 D UW1 S cer: 0.3750
# 372 alleviating pred: AE1 L IY0 V EY2 T IH0 NG ref: AH0 L IY1 V IY0 EY2 T IH0 NG cer: 0.3333
# 373 refurbishment pred: R IH0 F AO1 R B IH0 M AH0 N D ref: R IY0 F ER1 B IH0 SH M AH0 N T cer: 0.4545
# 374 closeted pred: K L EH1 S T AH0 D ref: K L AA1 Z AH0 T IH0 D cer: 0.5000
# 375 linguists pred: L IH1 NG G AH0 S T S ref: L IH1 NG G W IH0 S T S cer: 0.2222
# 376 adoptions pred: AE1 D P AH0 SH AH0 N Z ref: AH0 D AA1 P SH AH0 N Z cer: 0.3750
# 377 unadorned pred: AH0 N AE1 D ER0 N AH0 D ref: AH2 N AH0 D AO1 R N D cer: 0.6250
# 378 snowboards pred: S N OW1 B AO2 R D Z ref: S N OW1 B AO2 R D Z cer: 0.0000
# 379 perquisite pred: P ER0 K W IH1 S T IH0 K ref: P ER1 K W AH0 Z IH0 T cer: 0.6250
# 380 transparently pred: T R AE0 N S P EH1 N T R IY0 ref: T R AE0 N S P EH1 R AH0 N T L IY0 cer: 0.2308
# 381 cross-pollinate pred: K R AH0 S P EH1 N CH AH0 L IY2 N ref: K R AO1 S P AA2 L AH0 N EY2 T cer: 0.6364
# 382 children's pred: CH IH1 L D ER0 N Z ref: CH IH1 L D R AH0 N Z cer: 0.2500
# 383 semolina pred: S EH2 M AH0 L IY1 N IY0 ref: S EH2 M AH0 L IY1 N AH0 cer: 0.1250
# 384 buthelezi pred: B Y UW0 T EH1 L AH0 S IY0 ref: B UW2 T AH0 L EY1 Z IY0 cer: 0.6250
# 385 sympathized pred: S IH1 M P AH0 T AY2 Z D ref: S IH1 M P AH0 TH AY2 Z D cer: 0.1111
# 386 morganti pred: M AO0 R G AE1 N T IY0 ref: M AO0 R G AA1 N T IY0 cer: 0.1250
# 387 amalgams pred: AE1 M L AH0 G AE2 M Z ref: AH0 M AE1 L G AH0 M Z cer: 0.5000
# 388 loeffelholz pred: L UW1 F AH0 L T S ref: L OW1 F IH0 L HH OW0 L Z cer: 0.6667
# 389 hallenbeck pred: HH AE1 L AH0 N B AE2 K ref: HH AO1 L AH0 N B EH2 K cer: 0.2500
# 390 agrivisor pred: AE1 G R IY0 V IH2 S ER0 ref: AE1 G R AH0 V AY2 Z ER0 cer: 0.3750
# 391 montezuma pred: M AA2 N T AH0 Z EH1 M AH0 ref: M AA2 N T IH0 Z UW1 M AH0 cer: 0.2222
# 392 convention's pred: K AH0 N V EH1 N SH AH0 N Z ref: K AH0 N V EH1 N SH AH0 N Z cer: 0.0000
# 393 unjustified pred: AH2 N JH AH0 S T IH1 F IY0 ref: AH0 N JH AH1 S T AH0 F AY2 D cer: 0.5000
# 394 marketscope pred: M AA1 R K AH0 T S K AO2 P ref: M AA1 R K AH0 T S K OW2 P cer: 0.1000
# 395 interdigital pred: IH2 N T ER0 D IH1 JH AH0 K AH0 L ref: IH2 N T ER0 D IH1 JH AH0 T AH0 L cer: 0.0909
# 396 swartzentruber pred: S W AO1 R T S T ER0 N B EH2 R ref: S W AO1 R T S AH0 N T R UW0 B ER0 cer: 0.4615
# 397 incidents pred: IH2 N S IH1 JH AH0 N T S ref: IH1 N S AH0 D AH0 N T S cer: 0.3333
# 398 non-proliferation pred: N AA2 N P R AH0 P L EY1 SH AH0 V IH0 NG ref: N AA0 N P R AO0 L IH2 F ER0 EY1 SH AH0 N cer: 0.6429
# 399 gorczynski pred: G ER0 N S K AY1 V S IY0 ref: G ER0 CH IH1 N S K IY0 cer: 0.6250
# 400 directorships pred: D ER0 EH1 K T ER0 SH IH2 P S ref: D ER0 EH1 K T ER0 SH IH2 P S cer: 0.0000
# 401 homeland's pred: HH OW1 M AH0 L N AH0 S ref: HH OW1 M L AE2 N D Z cer: 0.5000
# 402 mantione pred: M AE1 N T IY0 AH0 N ref: M AA0 N T IY0 OW1 N IY0 cer: 0.3750
# 403 companies's pred: K AH0 M P AE1 N IY0 AH0 N Z ref: K AH1 M P AH0 N IY0 Z IH0 Z cer: 0.4000
# 404 quietness pred: K W IH1 N T AH0 S ref: K W AY1 AH0 T N AH0 S cer: 0.3750
# 405 distinctiveness pred: D IH0 S T IH1 NG K AH0 N D AH0 N T S ref: D IH0 S T IH1 NG K T IH0 V N AH0 S cer: 0.3846
# 406 solidarity pred: S AH0 L AY1 D ER0 AH0 T L IY0 ref: S AA2 L AH0 D EH1 R AH0 T IY0 cer: 0.5000
# 407 stellmacher pred: S T IH1 L M AH0 B ER0 K ref: S T EH1 L M AH0 K ER0 cer: 0.3750
# 408 milliseconds pred: M IH1 L AH0 S K OW2 Z IH0 NG ref: M IH1 L IH0 S EH2 K AH0 N D Z cer: 0.5455
# 409 parchment pred: P AA1 R M AH0 N T ref: P AA1 R CH M AH0 N T cer: 0.1250
# 410 schulenberg pred: SH AO1 L AH0 N B ER0 G ref: SH UW1 L AH0 N B ER0 G cer: 0.1250
# 411 facility pred: F AH0 S IH1 L AH0 T IY0 ref: F AH0 S IH1 L IH0 T IY0 cer: 0.1250
# 412 dyslexic pred: D IH0 S L IH1 S K AH0 ref: D IH0 S L EH1 K S IH0 K cer: 0.4444
# 413 stadium's pred: S T AE1 D IY0 AH0 M Z ref: S T EY1 D IY0 AH0 M Z cer: 0.1250
# 414 beleaguering pred: B EH1 L AH0 G EY2 IH0 NG ref: B IH0 L IY1 G ER0 IH0 NG cer: 0.3750
# 415 investigation pred: IH2 N V EH2 S T IH0 G EY1 SH AH0 N ref: IH2 N V EH2 S T AH0 G EY1 SH AH0 N cer: 0.0833
# 416 granada's pred: G R AE1 N D AH0 Z ref: G R AH0 N AA1 D AH0 Z cer: 0.2500
# 417 permeating pred: P ER0 M EH1 N IH0 T IH0 NG ref: P ER1 M IY0 EY2 T IH0 NG cer: 0.5000
# 418 discounters pred: D IH0 S K AH1 N T ER0 Z ref: D IH0 S K AW1 N T ER0 Z cer: 0.1111
# 419 whimsical pred: W IH1 M AH0 K AH0 L IH0 K ref: W IH1 M Z IH0 K AH0 L cer: 0.5000
# 420 portraying pred: P AO1 R T R AH0 N IH0 NG ref: P AO0 R T R EY1 IH0 NG cer: 0.3750
# 421 religione pred: R IH0 L IH1 SH AH0 N ref: R IH0 L IH2 JH IY0 OW1 N IY0 cer: 0.5556
# 422 verizons pred: V EH1 R AH0 S AH0 N Z ref: V EH2 R AY1 Z AH0 N Z cer: 0.3750
# 423 macedonian pred: M AH0 K IH1 D AH0 N IY0 AH0 N ref: M AE2 S AH0 D OW1 N Y AH0 N cer: 0.5000
# 424 afrocentric pred: AH0 F R AH0 K EH1 N T R IY0 ref: AE1 F R OW0 S EH1 N T R IH0 K cer: 0.4545
# 425 self-governing pred: S EH1 B L AH0 G N IH0 NG ref: S EH1 L F G AH1 V ER0 N IH0 NG cer: 0.4545
# 426 red-herrings pred: R IY0 D EH1 R IH0 NG Z ref: R EH1 D HH EH1 R IH0 NG Z cer: 0.2222
# 427 underscoring pred: AH2 N D ER0 S K AO1 R IH0 NG ref: AH2 N D ER0 S K AO1 R IH0 NG cer: 0.0000
# 428 mcgarrigle pred: M AH0 G AA1 R IH0 G L IY0 ref: M AH0 G AE1 R AH0 G AH0 L cer: 0.4444
# 429 globetrotter pred: G L AE1 B AH0 T ER0 T ER0 ref: G L OW1 B T R AO0 T ER0 cer: 0.4444
# 430 melodious pred: M EH2 L AH0 D IY1 Z AH0 ref: M AH0 L OW1 D IY0 AH0 S cer: 0.6250
# 431 westwards pred: W EH1 S T ER0 D Z ref: W EH1 S T W ER0 D Z cer: 0.1250
# 432 mutagens pred: M Y UW1 T AH0 G AH0 N Z ref: M Y UW1 T AH0 JH EH0 N Z cer: 0.2222
# 433 shipbuilder pred: SH IH1 P B AH0 L V ER0 ref: SH IH1 P B IH2 L D ER0 cer: 0.2500
# 434 religiously pred: R IY0 IH1 L IH0 JH AH0 S L IY0 ref: R IH0 L IH1 JH AH0 S L IY0 cer: 0.3333
# 435 exhaustive pred: IH0 G Z AE1 S T IH0 V ref: IH0 G Z AO1 S T IH0 V cer: 0.1250
# 436 accompanying pred: AH0 K AA1 M P AH0 N IH0 NG ref: AH0 K AH1 M P AH0 N IY0 IH0 NG cer: 0.2000
# 437 aramaic pred: AO0 R AE1 M AH0 K IY0 ref: AA2 R AA0 M EH1 Y IH0 K cer: 0.7500
# 438 collinson pred: K AH0 L EH1 N S AH0 N ref: K AA1 L IH0 N S AH0 N cer: 0.2500
# 439 disorders pred: D IH0 S AO1 R D ER0 Z ref: D IH0 S AO1 R D ER0 Z cer: 0.0000
# 440 seminoles pred: S IH0 M EH1 N AH0 L Z ref: S EH1 M IH0 N OW2 L Z cer: 0.3750
# 441 standalone pred: S T AE1 N D AH0 L AH0 N ref: S T AE1 N D AH0 L OW2 N cer: 0.1111
# 442 negligence pred: N EH1 G L IH0 K AH0 N S ref: N EH1 G L AH0 JH AH0 N S cer: 0.2222
# 443 fresenius pred: F R EH1 S AH0 N IY0 Z ref: F R AH0 S IY1 N IY0 AH0 S cer: 0.4444
# 444 speechwriters pred: S P EH1 F ER0 CH ER0 Z ref: S P IY1 CH R AY2 T ER0 Z cer: 0.5556
# 445 persevering pred: P ER0 S AY1 V ER0 IH0 NG ref: P ER0 S AH0 V IH1 R IH0 NG cer: 0.3333
# 446 inflexibility pred: IH2 N F L IH1 K T IH0 B L IY0 ref: IH2 N F L EH2 K S IH0 B IH1 L IH0 T IY0 cer: 0.3571
# 447 guantanamo pred: G W AA2 N T AH0 N AA1 M OW0 ref: G W AA2 N T AA1 N AH0 M OW2 cer: 0.3000
# 448 hardison pred: HH AA1 R D IH0 S AH0 N ref: HH AA1 R D IH0 S AH0 N cer: 0.0000
# 449 podcaster pred: P AA1 D K AH0 T ER0 Z ref: P AO1 D K AE2 S T ER0 cer: 0.5000
# 450 dissipation pred: D IH2 S IY0 AH0 P L EY1 SH AH0 N ref: D IH2 S IH0 P EY1 SH AH0 N cer: 0.3333
# 451 josephine's pred: JH OW1 Z AH0 F AY2 N Z ref: JH OW1 S AH0 F IY2 N Z cer: 0.2500
# 452 contemporaneous pred: K AA2 N T AH0 M P ER1 N IY0 AH0 Z ref: K AH0 N T EH2 M P ER0 EY1 N IY0 AH0 S cer: 0.3846
# 453 desensitize pred: D IH0 S EH1 N S AY2 T IH0 Z ref: D IH0 S EH1 N S AH0 T AY2 Z cer: 0.2000
# 454 presumptuous pred: P R IH0 Z M AH1 SH M AH0 T ref: P R IH0 Z AH1 M P CH AH0 W AH0 S cer: 0.5000
# 455 lysistrata pred: L IH0 S P EH1 R AH0 T AH0 L ref: L AY2 S IH0 S T R AA1 T AH0 cer: 0.6000
# 456 jonassaint pred: Y UW1 N AH0 S T AY2 Z ref: JH OW2 N AH0 S EY1 N T cer: 0.6250
# 457 desiderata pred: D IH0 S EH2 D ER0 EY1 T AH0 ref: D EY2 Z IH0 D ER0 AA1 T AH0 cer: 0.4444
# 458 tapestries pred: T AH0 P EH1 S T R IY0 Z ref: T AE1 P AH0 S T R IY0 Z cer: 0.2222
# 459 templates pred: T EH1 M P L AH0 T S ref: T EH1 M P L AH0 T S cer: 0.0000
# 460 superlative pred: S UW2 P ER0 AE1 L T IH0 V ref: S UH0 P ER1 L AH0 T IH0 V cer: 0.4444
# 461 deflection pred: D IH0 F L EH1 K SH AH0 N ref: D IH0 F L EH1 K SH AH0 N cer: 0.0000
# 462 excluding pred: IH0 K S K L UW1 D IH0 NG ref: IH0 K S K L UW1 D IH0 NG cer: 0.0000
# 463 trivialized pred: T R IH1 V AH0 L AY2 Z D ref: T R IH1 V IY0 AH0 L AY2 Z D cer: 0.1000
# 464 stanislav pred: S T AE1 N S AH0 L IH0 V ref: S T AE1 N IH0 S L AA0 V cer: 0.3333
# 465 vacuuming pred: V AH0 K UW1 M AH0 N IH0 NG ref: V AE1 K Y UW0 M IH0 NG cer: 0.6250
# 466 recruitment pred: R IH0 K R AH1 M P AH0 L ref: R AH0 K R UW1 T M AH0 N T cer: 0.6000
# 467 immiscible pred: IH1 M AH0 S IH0 B L IY0 ref: IH2 M IH1 S AH0 B AH0 L cer: 0.6250
# 468 overstaffed pred: OW1 V ER0 S T AE2 F T ref: OW1 V ER0 S T AE2 F T cer: 0.0000
# 469 cadences pred: K AE1 D AH0 N S IH0 Z ref: K EY1 D AH0 N S IH0 Z cer: 0.1250
# 470 blankinship pred: L AE1 N D IH0 SH M AH0 S ref: B L AE1 NG K IH0 N SH IH0 P cer: 0.7000
# 471 circulatory pred: S ER1 K AH0 L AH0 T AY2 Z ref: S ER1 K Y AH0 L AH0 T AO2 R IY0 cer: 0.3636
# 472 congruent pred: K AA1 N G R AH0 N T ref: K AO1 N G R UW0 EH2 N T cer: 0.3333
# 473 gruenhagen pred: G R OW1 N HH AE2 G AH0 N ref: G R UH1 N HH AH0 G AH0 N cer: 0.2222
# 474 vehicle's pred: V EH1 CH AH0 L IH0 Z ref: V IY1 HH IH0 K AH0 L Z cer: 0.6250
# 475 canonization pred: K AH0 N AH0 V IH1 L AH0 M AH0 N T ref: K AE2 N AH0 N AH0 Z EY1 SH AH0 N cer: 0.6364
# 476 transcribed pred: T R AE1 N S K R AY2 D ref: T R AE0 N S K R AY1 B D cer: 0.3000
# 477 graceland pred: G R AE1 S AH0 L M AH0 N T ref: G R EY1 S L AE0 N D cer: 0.6250
# 478 apartment pred: AE1 P ER0 T M AH0 N T ref: AH0 P AA1 R T M AH0 N T cer: 0.3333
# 479 watermarks pred: W AO1 T ER0 M AA2 R K S ref: W AO1 T ER0 M AA2 R K S cer: 0.0000
# 480 surprising pred: S ER1 P ER0 IH0 S IH0 NG ref: S ER0 P R AY1 Z IH0 NG cer: 0.5000
# 481 flagofficer pred: F L AE1 G F AE2 F IH0 NG ref: F L AE1 G AO0 F AH0 S ER0 cer: 0.5556
# 482 morihiro pred: M AO0 R IY0 HH OW1 R IY0 ref: M AO0 R IY0 HH IH1 R OW0 cer: 0.2500
# 483 daigrepont pred: D AE1 JH ER0 P AH0 N T ref: D EY1 G R IH0 P AA0 N T cer: 0.5556
# 484 granddaughter's pred: G R AE1 N D F AA2 R K IH0 V Z ref: G R AE1 N D AO2 T ER0 Z cer: 0.6667
# 485 nobility pred: N AA1 B AH0 L IH0 T IY0 ref: N OW0 B IH1 L AH0 T IY0 cer: 0.3750
# 486 transits pred: T R AE1 N S IH0 T S ref: T R AE1 N Z IH0 T S cer: 0.1250
# 487 infraction pred: IH2 N F R AE1 K SH AH0 N ref: IH2 N F R AE1 K SH AH0 N cer: 0.0000
# 488 amusingly pred: AH0 M Y UW1 Z IH0 NG L IY0 ref: AH0 M Y UW1 Z IH0 NG L IY0 cer: 0.0000
# 489 residency pred: R IH0 Z IH1 D AH0 N S IY0 ref: R EH1 Z IH0 D AH0 N S IY0 cer: 0.2222
# 490 nutcracker pred: N UW1 T K R AE2 K ER0 ref: N AH1 T K R AE2 K ER0 cer: 0.1250
# 491 biologically pred: B AY2 OW0 L AA1 JH IH0 K L IY0 ref: B AY0 AH0 L AA1 JH IH0 K L IY0 cer: 0.2000
# 492 scaleatron pred: S K EY1 L AH0 T ER0 N ref: S K EY1 L IY0 AH0 T R AA0 N cer: 0.3000
# 493 byelorussia pred: B AY2 AH0 L AO1 R IY0 AH0 S ref: B AY2 AH0 L OW0 R AH1 SH AH0 cer: 0.4444
# 494 delbarco's pred: D EH1 L B ER0 K OW2 Z ref: D EH0 L B AA1 R K OW0 Z cer: 0.4444
# 495 tamburrino pred: T AH0 M B AA0 R AA1 N OW0 ref: T AA0 M B UH0 R IY1 N OW0 cer: 0.3333
# 496 landscaping pred: L AE1 N D S K EY2 T IH0 NG ref: L AE1 N D S K EY2 P IH0 NG cer: 0.1000
# 497 lowdermilk pred: L AW1 D ER0 M IH0 K ref: L OW0 D ER1 M IH0 L K cer: 0.3750
# 498 amphitheaters pred: AE1 M F AH0 TH AY2 T ER0 Z ref: AE1 M F AH0 TH IY0 EY1 T ER0 Z cer: 0.2000
# 499 refrigerator pred: R IH0 F R AY1 T ER0 EY2 T ER0 ref: R AH0 F R IH1 JH ER0 EY2 T ER0 cer: 0.3000
# 500 landmark pred: L AE1 N D M AA2 R K ref: L AE1 N D M AA2 R K cer: 0.0000
# 501 artichokes pred: AA1 R T IH0 K OW2 Z IH0 Z ref: AA1 R T IH0 CH OW2 K S cer: 0.5000
# 502 zamarripa pred: Z AH0 M AA1 R AH0 S T ref: Z AA2 M AA0 R IY1 P AA0 cer: 0.6250
# 503 prospectus pred: P R AA1 S P IH0 K T S ref: P R AH0 S P EH1 K T AH0 S cer: 0.3000
# 504 pagliuca's pred: P AA0 G L IH1 JH AH0 S ref: P AE2 G L IY0 UW1 K AH0 Z cer: 0.5556
# 505 salveson pred: S AE1 L V AH0 S AH0 N ref: S AA0 L V EY1 S AH0 N cer: 0.2500
# 506 activism pred: AE1 T IH0 K AH0 N S ref: AE1 K T IH0 V IH2 Z AH0 M cer: 0.6667
# 507 galactose pred: G AE1 L AH0 K OW2 T ref: G AH0 L AE1 K T OW0 S cer: 0.6250
# 508 kurumizowa pred: K AO2 R Y UW0 EY1 SH M AH0 ref: K UH2 R UW0 M IY0 Z OW1 AH0 cer: 0.6667
# 509 plumages pred: P L UW1 M AH0 G Z ref: P L UW1 M AH0 JH AH0 Z cer: 0.2500
# 510 helmsburton pred: HH EH1 L B S T M ER0 N ref: HH EH1 L M Z B ER0 T AH0 N cer: 0.5000
# 511 longitudes pred: L AO1 NG G AH0 T IH0 D Z ref: L AA1 N JH AH0 T UW2 D Z cer: 0.4444
# 512 spelunked pred: S P EH1 N L IH0 K S ref: S P AH0 L AH1 NG K T cer: 0.6250
# 513 poparelli pred: P AH0 P EH1 R IY0 AH0 L ref: P OW2 P AH0 R EH1 L IY0 cer: 0.6250
# 514 newsmakers pred: N UW1 Z M AH0 N CH ER0 ref: N UW1 Z M EY2 K ER0 Z cer: 0.5000
# 515 eradication pred: EH2 R AH0 D IH1 SH AH0 N T ref: IH0 R AE2 D AH0 K EY1 SH AH0 N cer: 0.6000
# 516 qualifies pred: K W OW1 L IY0 F AY2 Z ref: K W AA1 L AH0 F AY2 Z cer: 0.2500
# 517 zuchowski pred: Z AH0 CH AO1 F S K IY0 ref: Z AH0 HH AO1 F S K IY0 cer: 0.1250
# 518 nonaligned pred: N AA1 N AH0 L D IH0 NG ref: N AA1 N AH0 L AY2 N D cer: 0.3750
# 519 childminder pred: CH IH1 L D M AH0 N D ref: CH AY1 L D M AY2 N D ER0 cer: 0.3333
# 520 diuretics pred: D ER0 IH1 T S K AH0 S ref: D AY2 UW0 R EH1 T IH0 K S cer: 0.6667
# 521 wagnerian pred: W AH0 G EH1 R N IY0 AH0 N ref: W AE2 G N EH1 R IY0 AH0 N cer: 0.3333
# 522 vanwieren pred: V AE1 N W ER0 N AH0 ref: V AE0 N W IH1 R AH0 N cer: 0.5000
# 523 savagery pred: S AE1 V AH0 G R IY0 ref: S AE1 V IH0 JH EH2 R IY0 cer: 0.3750
# 524 vartanian pred: V AA0 R T EY1 N IY0 AH0 N ref: V AA0 R T EY1 N IY0 AH0 N cer: 0.0000
# 525 religion's pred: R IH0 L IH1 JH AH0 N Z ref: R IH0 L IH1 JH AH0 N Z cer: 0.0000
# 526 sulfurophane pred: S AH1 B L F ER0 M OW2 N ref: S AH1 L F ER0 AH0 F EY2 N cer: 0.4444
# 527 thomasina pred: TH OW0 M AA0 S IY1 N IY0 ref: TH OW0 M AA0 S IY1 N AH0 cer: 0.1250
# 528 haakenson pred: HH AA1 K AH0 N S AH0 N ref: HH AA1 K IH0 N S AH0 N cer: 0.1250
# 529 jetliners pred: JH EH1 T AH0 N L ER0 Z ref: JH EH1 T L AY2 N ER0 Z cer: 0.3750
# 530 artifacts pred: AA1 R T IH0 F AE2 K T S ref: AA1 R T AH0 F AE2 K T S cer: 0.1111
# 531 unwieldiness pred: AH0 N V EH1 L D AH0 M Z ref: AH0 N W IY1 L D IY0 N AH0 S cer: 0.6000
# 532 delcastillo pred: D EH2 L K AH0 S T AA1 L IY0 ref: D EH0 L K AA0 S T IH1 L OW0 cer: 0.4000
# 533 ruthenberg pred: R AH1 TH N B EH2 R K ref: R AH1 TH AH0 N B ER0 G cer: 0.5000
# 534 landolfi pred: L AE2 N D UW1 F IY0 ref: L AA0 N D OW1 L F IY0 cer: 0.3750
# 535 shriveling pred: SH ER1 V IH0 L IH0 NG ref: SH R IH1 V AH0 L IH0 NG cer: 0.3750
# 536 foundation pred: F AW1 N D AH0 HH OW2 N ref: F AW0 N D EY1 SH AH0 N cer: 0.5000
# 537 deficiency pred: D IH0 F IH1 S AH0 N ref: D IH0 F IH1 SH AH0 N S IY0 cer: 0.3333
# 538 temptress pred: T EH1 M P T R AH0 S ref: T EH1 M P T R IH0 S cer: 0.1250
# ...
# 4824 segregation pred: S EH2 G R AH0 G EY1 SH AH0 N ref: S EH2 G R AH0 G EY1 SH AH0 N cer: 0.0000
# 4825 underemployment pred: AH2 N D ER0 M IH1 P AH0 L M AH0 N T ref: AH2 N D ER0 IH0 M P L OY1 M AH0 N T cer: 0.3077
# 4826 abnormalities pred: AH0 B AA1 N R AH0 M AH0 L IY0 Z ref: AE2 B N AO0 R M AE1 L AH0 T IY0 Z cer: 0.5833
# 4827 motorola's pred: M Y UW0 T AA1 R AH0 L Z ref: M OW2 T ER0 OW1 L AH0 Z cer: 0.7500
# 4828 freshwater pred: F R EH1 S W AO2 T ER0 ref: F R EH1 SH W AO2 T ER0 cer: 0.1250
# 4829 bankowski pred: B AH0 NG K AO1 F S K IY0 ref: B AH0 NG K AO1 F S K IY0 cer: 0.0000
# 4830 disinform pred: D IH1 S IH0 N F AO0 R M ref: D IH0 S IH0 N F AO1 R M cer: 0.2222
# 4831 decimals pred: D IH0 K IH1 M B AH0 L Z ref: D EH1 S AH0 M AH0 L Z cer: 0.5000
# 4832 cellular's pred: N IH1 L AH0 K W ER0 Z ref: S EH1 L Y AH0 L ER0 Z cer: 0.6250
# 4833 disclaimer pred: D IH0 S K L EY1 M ER0 ref: D IH0 S K L EY1 M ER0 cer: 0.0000
# 4834 requesting pred: R IH0 K W EH1 S T IH0 NG ref: R IH0 K W EH1 S T IH0 NG cer: 0.0000
# 4835 luncheonette pred: L AH0 N EH1 K T AH0 N ref: L AH2 N CH IH0 N EH1 T cer: 0.7500
# 4836 eventful pred: EH1 V AH0 N F AH2 L ref: IH0 V EH1 N T F AH0 L cer: 0.5000
# 4837 hallelujah pred: HH AE1 L AH0 W AH0 L ref: HH AE2 L AH0 L UW1 Y AH0 cer: 0.6250
# 4838 rostropovich pred: R AH0 S T R AA1 D AH0 T IY0 ref: R AO2 S T R AH0 P OW1 V IH0 CH cer: 0.6364
# 4839 hamanaka pred: HH AE2 M AH0 N AA1 K AH0 ref: HH AH0 M AH0 N AA1 K AH0 cer: 0.1250
# 4840 prillaman pred: P R IH1 L M AH0 N ref: P R IH1 L AH0 M AH0 N cer: 0.1250
# 4841 parliamentary pred: P AA2 R M AH0 L EH1 N SH IY0 ER0 ref: P AA2 R L AH0 M EH1 N T ER0 IY0 cer: 0.4545
# 4842 wonderfulness pred: W AH1 N D ER0 F AH0 L N Z ref: W AH1 N D ER0 F AH0 L N AH0 S cer: 0.1818
# 4843 thunderbolt pred: TH AH1 N D ER0 B AO2 L T ref: TH AH1 N D ER0 B AO2 L T cer: 0.0000
# 4844 diagnosed pred: D AY0 AE1 G N AH0 S D ref: D AY2 AH0 G N OW1 S T cer: 0.5000
# 4845 flavorings pred: F L AE1 V ER0 IH0 NG Z ref: F L EY1 V ER0 IH0 NG Z cer: 0.1250
# 4846 boguslavskaya pred: B AH0 G AH1 S T AH0 V IH2 L S IY0 ref: B OW0 G AH2 S L AH0 V S K AY1 AH0 cer: 0.5833
# 4847 iconography pred: IH2 K AH0 N AO1 R AH0 F IY0 ref: AY2 K AH0 N AA1 G R AH0 F IY0 cer: 0.3000
# 4848 milkovich pred: M IH1 L K AH0 V IH2 CH ref: M IH1 L K AH0 V IH0 CH cer: 0.1250
# 4849 giroldi's pred: G ER0 AE1 D L IY0 Z ref: G IH0 R OW1 L D IY0 Z cer: 0.5000
# 4850 hershkowitz pred: HH ER1 S K W IH0 TH S ref: HH ER1 SH K AH0 W IH0 T S cer: 0.3333
# 4851 clarifications pred: K L AO2 R AH0 F IH0 Z EY1 SH AH0 N Z ref: K L EH2 R IH0 F IH0 K EY1 SH AH0 N Z cer: 0.2308
# 4852 handholding pred: HH AE1 N D HH OW2 L D IH0 NG ref: HH AE1 N D HH OW2 L D IH0 NG cer: 0.0000
# 4853 picaresque pred: P IY0 K ER0 S EH1 K W AH0 ref: P IH2 K AH0 R EH1 S K cer: 0.7500
# 4854 confirmation pred: K AH0 N F ER0 M EY1 SH AH0 N ref: K AA2 N F ER0 M EY1 SH AH0 N cer: 0.1000
# 4855 institutionalized pred: IH2 N S T AH0 T IH1 SH AH0 N T L IY0 Z ref: IH2 N S T IH0 T UW1 SH AH0 N AH0 L AY2 Z D cer: 0.3333
# 4856 espinoza pred: IH0 S P EH1 N AH0 W AH0 ref: EY0 S P IY0 N OW1 Z AH0 cer: 0.5000
# 4857 lufthansa pred: L AH1 F T AH0 N AH0 M ref: L AH0 F T AE1 N Z AH0 cer: 0.5000
# 4858 stepdaughters pred: S T EH1 F AH0 N D EY2 T S ref: S T EH1 P D AO2 T ER0 Z cer: 0.6667
# 4859 grandfield pred: G R AE1 N D F AY2 L D ref: G R AE1 N D F IY2 L D cer: 0.1111
# 4860 pleasants pred: P L IY1 Z AH0 N T S ref: P L EH1 Z AH0 N T S cer: 0.1250
# 4861 sandbox pred: S AE1 N D B AE2 K S ref: S AE1 N D B AA2 K S cer: 0.1250
# 4862 dimorphic pred: D IH0 M AO1 R F IH0 K ref: D AY0 M AO1 R F IH0 K cer: 0.1250
# 4863 restaino pred: R IH0 S T AA1 N AH0 ref: R EH0 S T AA0 IY1 N OW0 cer: 0.5000
# 4864 steffensmeier pred: S T EH1 F S N AY2 M ER0 ref: S T EH1 F IH0 N S M AY0 ER0 cer: 0.3000
# 4865 gencarelli pred: JH EH2 N AH0 K EH1 L IY0 ref: JH EH0 N K AA0 R EH1 L IY0 cer: 0.4444
# 4866 memorialized pred: M EH1 M ER0 AH0 L AY2 Z D ref: M AH0 M AO1 R IY0 AH0 L AY2 Z D cer: 0.3636
# 4867 pharmacia pred: F AA0 R M AA1 SH IY0 ref: F AA0 R M EY1 S IY0 AH0 cer: 0.3750
# 4868 assuredly pred: AH0 S ER1 S AH0 L IY0 ref: AH0 SH UH1 R AH0 D L IY0 cer: 0.5000
# 4869 tempelsman pred: T EH1 M P L AH0 M AH0 N ref: T EH1 M P AH0 L Z M AH0 N cer: 0.2000
# 4870 quartets pred: K W AO1 R T AH0 T S ref: K W AO0 R T EH1 T S cer: 0.2500
# 4871 cartland pred: K AO1 R T L AH0 N D ref: K AA1 R T L AH0 N D cer: 0.1250
# 4872 sprogus's pred: S P R AH1 G AH0 S IH0 Z ref: S P R OW1 G AH0 S IH0 Z cer: 0.1111
# 4873 introduction pred: IH2 N T R AH0 D AH1 K SH AH0 N ref: IH2 N T R AH0 D AH1 K SH AH0 N cer: 0.0000
# 4874 carberry's pred: K AA1 R B ER0 IY0 Z ref: K AA1 R B EH2 R IY0 Z cer: 0.2500
# 4875 horticulture pred: HH AO1 R T IH0 K L AY2 T ER0 ref: HH AO1 R T IH0 K AH2 L CH ER0 cer: 0.3000
# 4876 reforestation pred: R EH2 F ER0 K AH0 V IH1 T AH0 N ref: R IY2 F AO0 R AH0 S T EY1 SH AH0 N cer: 0.5833
# 4877 stivoric pred: S T AY1 V R AH0 CH IY0 ref: S T IH0 V AO1 R IH0 K cer: 0.6250
# 4878 addidases pred: AE1 D D IH0 D AY2 Z IH0 Z ref: AH0 D IY1 D AH0 S IH0 Z cer: 0.6250
# 4879 proponent pred: P R OW1 P AH0 N T AH0 N ref: P R AH0 P OW1 N AH0 N T cer: 0.4444
# 4880 obligations pred: AH0 B L IY0 T EY1 SH AH0 N Z ref: AA2 B L AH0 G EY1 SH AH0 N Z cer: 0.3000
# 4881 medtronic pred: M AH0 D T R AA1 N IH0 K ref: M EH0 D T R AA1 N IH0 K cer: 0.1111
# 4882 filippello pred: F IH2 L F AH0 L AA1 P ref: F IY2 L IH0 P EH1 L OW0 cer: 0.7500
# 4883 papier-mache pred: P IY0 P AA1 R M IH0 K AH0 ref: P EY1 P ER0 M AH0 SH EY1 cer: 0.7500
# 4884 lionheart pred: L IY1 V M AH0 N T ref: L AY1 AH0 N HH AA2 R T cer: 0.7500
# 4885 ferromagnetism pred: F ER0 M AA1 N T R IH0 K S ref: F EH2 R OW0 M AE1 G N AH0 T IH2 Z AH0 M cer: 0.7143
# 4886 bilingual pred: B IH1 L IH0 NG W AA2 L ref: B AY0 L IH1 NG G W AH0 L cer: 0.4444
# 4887 thunderstorm pred: TH AH1 N D ER0 S T ER0 M ref: TH AH1 N D ER0 S T AO2 R M cer: 0.2000
# 4888 hollenbach pred: HH OW1 L V AH0 M AH0 L ref: HH AA1 L IH0 N B AA0 K cer: 0.7500
# 4889 overfunded pred: OW1 V ER0 F AH0 N D IH0 D ref: OW1 V ER0 F AH2 N D IH0 D cer: 0.1111
# 4890 skenandore pred: S K EH1 N D AH0 N ER0 ref: S K IH0 N AE1 N D ER0 cer: 0.5000
# 4891 burgundy's pred: B ER1 G AH0 N D AY2 Z ref: B ER1 G AH0 N D IY0 Z cer: 0.1250
# 4892 dressmaking pred: D R IH0 S M AE1 K IH0 NG ref: D R EH1 S M EY2 K IH0 NG cer: 0.2222
# 4893 polysaccharide pred: P AA2 L AH0 S EH1 F T IH0 NG ref: P AA2 L IY2 S AE1 K ER0 AY2 D cer: 0.6000
# 4894 irrevocably pred: IH2 R AA1 V IH0 K AH0 L IY0 ref: IH2 R EH1 V AH0 K AH0 B L IY0 cer: 0.3000
# 4895 arianespace pred: ER0 IH1 N AH0 S AH0 B AH0 N ref: EH2 R IY0 AE1 N S P EY1 S cer: 1.0000
# 4896 unconstitutionally pred: AH0 N K AH1 N T S AH0 SH AH0 L IY0 V ref: AH2 N K AA2 N S T AH0 T UW1 SH AH0 N AH0 L IY0 cer: 0.5625
# 4897 americorps pred: AH0 M EH1 R AH0 K AO2 R P S ref: AH0 M EH1 R IH0 K AO2 R cer: 0.3750
# 4898 wannemacher pred: W AA1 N AH0 M EY2 K ER0 ref: W AA1 N AH0 M AA0 K ER0 cer: 0.1250
# 4899 comprising pred: K AH0 M P R IH1 S IH0 NG ref: K AH0 M P R AY1 Z IH0 NG cer: 0.2222
# 4900 almendarez pred: AH0 L M AE1 N D ER0 M Z ref: AA0 L M EY0 N D AA1 R EH0 Z cer: 0.5000
# 4901 january pred: JH AA1 N Y AA2 R IY0 ref: JH AE1 N Y UW0 EH2 R IY0 cer: 0.3750
# 4902 revolvers pred: R EH1 V AH0 L V ER0 Z ref: R IH0 V AA1 L V ER0 Z cer: 0.2500
# 4903 islamabad's pred: IH2 S L AE1 B AH0 M AH0 N T S ref: IH2 S L AE1 M AH0 B AE0 D Z cer: 0.6000
# 4904 universities' pred: Y UW2 N IH0 V IH1 R AH0 S T S ref: Y UW2 N IH0 V ER1 S IH0 T IY0 Z cer: 0.5455
# 4905 detriment pred: D EH1 T R AH0 M AH0 N T ref: D EH1 T R AH0 M AH0 N T cer: 0.0000
# 4906 conducted pred: K AH0 N D AH1 K T IH0 D ref: K AH0 N D AH1 K T AH0 D cer: 0.1111
# 4907 minisupercomputer pred: M IH1 N S P EH2 R S IH0 M EY2 T ER0 D ref: M IH2 N IY0 S UW1 P ER0 K AH2 M P Y UW2 T ER0 cer: 0.6875
# 4908 graziano pred: G R AE2 Z IY0 OW1 N OW0 ref: G R AA0 T S IY0 AA1 N OW0 cer: 0.4444
# 4909 decommissioning pred: D IH0 K AH0 M IH1 SH AH0 N IH0 NG ref: D IY0 K AH0 M IH1 SH AH0 N IH0 NG cer: 0.0909
# 4910 padmanabhan pred: P AE1 D AH0 N HH AE2 M AH0 N ref: P AE0 D M AE1 N AH0 B AE2 N cer: 0.7000
# 4911 americare pred: AH0 M EH1 R AH0 K EH2 R ref: AH0 M EH1 R IH0 K EH2 R cer: 0.1250
# 4912 monteverde pred: M AA1 N T EH2 V ER0 D ref: M OW0 N T EH0 V EH1 R D IY0 cer: 0.5000
# 4913 estimating pred: IH0 S T IH1 M AH0 T IH0 NG ref: EH1 S T AH0 M EY2 T IH0 NG cer: 0.3333
# 4914 bollettieri pred: B AH0 L T IH1 R IY0 AH0 ref: B AH0 L EH2 T IY0 EH1 R IY0 cer: 0.4444
# 4915 textbooks pred: T EH1 K S T OW2 B Z ref: T EH1 K S T B UH2 K S cer: 0.4444
# 4916 mischievous pred: M IH0 S IH1 V AH0 S ref: M IH1 S CH AH0 V AH0 S cer: 0.3750
# 4917 vanblaricom pred: V AE0 N B L AA1 R IH0 K AH0 L ref: V AE2 N B L AE1 R IH0 K AH0 M cer: 0.2727
# 4918 carbonized pred: K AA1 R B IH0 N AY2 Z D ref: K AA1 R B AH0 N AY2 Z D cer: 0.1111
# 4919 deforest pred: D EH1 F ER0 S T ref: D IH0 F AO1 R AH0 S T cer: 0.5000
# 4920 feedstocks pred: F EH1 D AH0 S K AA2 T S ref: F IY1 D S T AA2 K S cer: 0.5000
# 4921 undernourished pred: AH0 N D ER0 N UW1 SH ER0 D ref: AH2 N D ER0 N ER1 IH0 SH T cer: 0.5556
# 4922 exonerated pred: IH0 K S AA1 N ER0 EY2 T IH0 D ref: IH0 G Z AA1 N ER0 EY2 T IH0 D cer: 0.2000
# 4923 vagabonds pred: V AE1 G AH0 B AO2 N D Z ref: V AE1 G AH0 B AA0 N D Z cer: 0.1111
# 4924 itinerant pred: IH2 T IH0 N AA1 R N AH0 T ref: AY0 T IH1 N ER0 AH0 N T cer: 0.6250
# 4925 mcevilly pred: M AH0 K IH1 V AH0 L IY0 ref: M AH0 K EH1 V AH0 L IY0 cer: 0.1250
# 4926 copperfields' pred: K AA1 P ER0 F IH2 D Z ref: K AA1 P ER0 F IY2 L D Z cer: 0.2222
# 4927 cleaveland pred: K L IY1 V AH0 L AH0 N D ref: K L IY1 V L AH0 N D cer: 0.1250
# 4928 telescopic pred: T EH2 L AH0 S AA1 K IH0 P ref: T EH2 L AH0 S K AO1 P IH0 K cer: 0.4000
# 4929 beverages pred: B EH1 V ER0 EY2 T S ref: B EH1 V R IH0 JH IH0 Z cer: 0.6250
# 4930 telesciences pred: T EH1 L AH0 S AH0 N S IH0 Z ref: T EH1 L AH0 S AY2 AH0 N S IH0 Z cer: 0.0909
# 4931 islamist pred: IH2 S L AE1 M IH0 T S ref: IH1 S L AH0 M IH0 S T cer: 0.5000
# 4932 ornamented pred: AO1 R N AH0 M AH0 N T IH0 D ref: AO1 R N AH0 M EH2 N T IH0 D cer: 0.1000
# 4933 aganbegyan pred: AE2 G AH0 N B EY1 D IH0 N ref: AE2 G AH0 N B EH1 G Y AH0 N cer: 0.4000
# 4934 ferryboats pred: F Y UW1 R AH0 B AO2 L Z ref: F EH1 R IY0 B OW2 T S cer: 0.7500
# 4935 disapprove pred: D IH0 S P AA1 R S AH0 D ref: D IH2 S AH0 P R UW1 V cer: 0.7500
# 4936 uniondale pred: Y UW2 N AH0 N IH1 D AH0 L ref: Y UW1 N Y AH0 N D EY2 L cer: 0.4444
# 4937 accessibility pred: AH0 S IH1 S AH0 B L IY0 T IH0 L ref: AE2 K S EH0 S AH0 B IH1 L IH0 T IY0 cer: 0.5833
# 4938 nawrocki pred: N AA0 R AA1 F S K IY0 ref: N AA0 V R OW1 T S K IY0 cer: 0.3333
# 4939 competitors pred: K AH0 M P EH1 T AH0 T ER0 Z ref: K AH0 M P EH1 T AH0 T ER0 Z cer: 0.0000
# 4940 kendavis pred: K AH0 V AE1 N D IH0 S ref: K EH1 N D EY1 V IH0 S cer: 0.6250
# 4941 dockendorf pred: D AA1 K AH0 N D AO2 R P ref: D AA1 K IH0 N D AO0 R F cer: 0.3333
# 4942 redecorated pred: R IY0 D EH1 K ER0 EY2 T IH0 D ref: R IY0 D EH1 K ER0 EY2 T IH0 D cer: 0.0000
# 4943 prototypes pred: P R AA1 T AH0 P EY2 T S ref: P R OW1 T AH0 T AY2 P S cer: 0.4444
# 4944 first-class pred: F ER1 S T AH0 K AH0 L Z ref: F ER2 S T K L AE1 S cer: 0.6250
# 4945 insemination pred: IH2 N S AH0 M EY1 SH AH0 N ref: IH2 N S EH2 M AH0 N EY1 SH AH0 N cer: 0.2727
# 4946 cara'veras pred: K AA0 R AA0 V EH1 R AH0 Z ref: K AA2 R AH0 V EH1 R AH0 Z cer: 0.2222
# 4947 excepting pred: IH0 K S P EH1 K T IH0 NG ref: EH2 K S EH1 P T IH0 NG cer: 0.3750
# 4948 coventry pred: K AH0 V EH1 N T R IY0 ref: K AH1 V AH0 N T R IY0 cer: 0.2500
# 4949 unmistakably pred: AH2 N M AH0 S T IH1 B IH0 K L IY0 ref: AH2 N M IH0 S T EY1 K AH0 B L IY0 cer: 0.4167
# 4950 geometrically pred: JH IY2 AH0 P EH1 R AH0 T L IY0 ref: JH IY2 AH0 M EH1 T R IH0 K L IY0 cer: 0.3636
# 4951 pediatricians pred: P EH2 D IY0 AH0 T R EY1 SH AH0 N Z ref: P IY2 D IY0 AH0 T R IH1 SH AH0 N Z cer: 0.1667
# 4952 stability pred: S T EY1 B AH0 L IH0 T IY0 ref: S T AH0 B IH1 L IH0 T IY0 cer: 0.2222
# 4953 headrests pred: HH EH1 D R AH0 S T S ref: HH EH1 D R EH2 S T S cer: 0.1250
# 4954 overuses pred: OW1 V ER0 Z AY2 Z ref: OW2 V ER0 Y UW1 Z IH0 Z cer: 0.5000
# 4955 finstrom pred: F AH1 N S T R AH0 M ref: F IH1 N S T R AH0 M cer: 0.1250
# 4956 lindstrand pred: L IH1 N D S T ER0 D ref: L IH1 N D S T R AH0 N D cer: 0.3000
# 4957 intently pred: IH2 N T EH1 N T L IY0 ref: IH2 N T EH1 N T L IY0 cer: 0.0000
# 4958 francisco's pred: F R AE1 N S K OW2 Z IH0 Z ref: F R AE0 N S IH1 S K OW0 Z cer: 0.5000
# 4959 angelino pred: AE2 NG G AH0 L IY1 N IY0 ref: AE2 N JH AH0 L IY1 N OW0 cer: 0.3750
# 4960 dobrynin pred: D AA1 R M AH0 V AH0 N ref: D AA1 B R IH0 N IH0 N cer: 0.6250
# 4961 bankable pred: B AE1 K AH0 N B AH0 L ref: B AE1 NG K AH0 B AH0 L cer: 0.2500
# 4962 cypriots pred: S IH1 P ER0 AH0 T S ref: S IH1 P R IY0 AH0 T S cer: 0.2500
# 4963 extracted pred: IH0 K S T R AE1 K T IH0 D ref: EH0 K S T R AE1 K T IH0 D cer: 0.1000
# 4964 definable pred: D IH0 F EH1 N D AH0 L ref: D IH0 F AY1 N AH0 B AH0 L cer: 0.3333
# 4965 aluminum pred: AH0 L UW1 M AH0 N AH0 M ref: AH0 L UW1 M AH0 N AH0 M cer: 0.0000
# 4966 misconstrue pred: M IH0 S K AH1 N T R AH0 S ref: M IH0 S K AH0 N S T R UW1 cer: 0.4000
# 4967 embellishes pred: EH1 M B AH0 L AY2 Z ER0 Z ref: EH0 M B EH1 L IH0 SH AH0 Z cer: 0.5556
# 4968 westchester's pred: W EH1 S T IH0 K ER0 Z T ref: W EH1 S T CH EH2 S T ER0 Z cer: 0.5000
# 4969 unsatisfied pred: AH0 N S IH1 SH AH0 W IH0 T IH0 D ref: AH0 N S AE1 T IH0 S F AY2 D cer: 0.7000
# 4970 surmounted pred: S ER1 M AH0 N T IH0 D ref: S ER0 M AW1 N T IH0 D cer: 0.2500
# 4971 fredericksen pred: F R EH1 D ER0 S AH0 N S ref: F R EH1 D ER0 IH0 K S AH0 N cer: 0.3000
# 4972 raudenbush pred: R AH1 D B EH2 N AH0 Z ref: R AW1 D IH0 N B UH0 SH cer: 0.7500
# 4973 disequilibrium pred: D IH0 S K AH0 F IH1 L V IY0 R IY0 ref: D IH0 S IY2 K W AH0 L IH1 B R IY0 AH0 M cer: 0.5000
# 4974 staffordshire's pred: S T AA1 F ER0 D W ER2 Z IH0 Z ref: S T AE1 F ER0 D SH ER0 Z cer: 0.5556
# 4975 hospices pred: HH OW1 Z AH0 P AY2 Z ref: HH AA1 S P AH0 S IH0 Z cer: 0.6250
# 4976 mcmasters pred: M AH0 K M AE1 S T ER0 Z ref: M AH0 K M AE1 S T ER0 Z cer: 0.0000
# 4977 albumin pred: AE1 L M B AH0 N IY0 ref: AE0 L B Y UW1 M AH0 N cer: 0.7500
# 4978 revelation pred: R IY0 V EH0 L EY1 SH AH0 N ref: R EH2 V AH0 L EY1 SH AH0 N cer: 0.2222
# 4979 poinsettias pred: P EH2 N S AH0 T UW1 V IH0 S ref: P OY2 N S EH1 T IY2 AH0 Z cer: 0.6667
# 4980 controlling pred: K AH0 N T R OW1 L IH0 NG ref: K AH0 N T R OW1 L IH0 NG cer: 0.0000
# 4981 laboratory's pred: L AE1 B ER0 AH0 T AO2 R IY0 Z ref: L AE1 B R AH0 T AO2 R IY0 Z cer: 0.1000
# 4982 bensinger pred: B EH1 N S IH0 NG ER0 ref: B EH1 N S IH0 N JH ER0 cer: 0.2500
# 4983 interstitial pred: IH2 N T ER0 T IH1 S T AH0 L ref: IH2 N T ER0 S T IH1 SH AH0 L cer: 0.3000
# 4984 st-mary pred: S T AE1 M IY0 ER0 ref: S EY1 N T M EH1 R IY0 cer: 0.7500
# 4985 protruding pred: P R AO1 T R AH0 D IH0 NG ref: P R OW0 T R UW1 D IH0 NG cer: 0.2222
# 4986 marchesano pred: M AA0 R K EH1 SH AH0 N ref: M AA0 R K EH0 S AA1 N OW0 cer: 0.4444
# 4987 subordinate pred: S AH1 B ER0 D AH0 N T IH0 D ref: S AH0 B AO1 R D AH0 N EY2 T cer: 0.6000
# 4988 impoverishing pred: IH2 M P AA1 V ER0 IH0 NG ref: IH2 M P AA1 V R IH0 SH IH0 NG cer: 0.3000
# 4989 riskiest pred: R IH0 S IH1 S T S ref: R IH1 S K IY0 AH0 S T cer: 0.6250
# 4990 probationary pred: P R OW0 B EY1 SH AH0 N IH0 R IY0 ref: P R OW0 B EY1 SH AH0 N EH2 R IY2 cer: 0.1818
# 4991 nonchalantly pred: N AA1 N K AH0 L T IY0 N ref: N AA1 N SH AH0 L AA1 N T L IY0 cer: 0.4545
# 4992 tangibly pred: T AE1 NG G AH0 B L IY0 ref: T AE1 N JH AH0 B L IY0 cer: 0.2500
# 4993 serological pred: S EH2 R AH0 L AA1 JH IH0 K AH0 L ref: S EH0 R AH0 L AO1 JH IH0 K AH0 L cer: 0.1818
# 4994 brentanos pred: B R EH1 N T AH0 N AH0 S ref: B R EH2 N T AA1 N OW0 Z cer: 0.4444
# 4995 jukeboxes pred: JH UW1 K AH0 B AO2 K S ref: JH UW1 K B AA2 K S IH0 Z cer: 0.4444
# 4996 entertainer pred: EH0 N T ER1 T AH0 N ER0 ref: EH2 N T ER0 T EY1 N ER0 cer: 0.3750
# 4997 profanity pred: P R AH0 F AA1 N IH0 T IY0 ref: P R OW0 F AE1 N AH0 T IY0 cer: 0.3333
# 4998 kalinske pred: K AH0 L IH1 N S K IY0 ref: K AH0 L IH1 N S K IY0 cer: 0.0000
# 4999 aromatic pred: AO0 R M AA1 T IH0 K ref: EH2 R AH0 M AE1 T IH0 K cer: 0.3750
# Avg CER: 0.3601

# %% [markdown]
# __Question:__ Report the number of params used by the model. _(2 points)_
#
# __Answer:__
# num parameters: 102014
#
# __Question:__ Report the training and validation loss at the end of 15 epochs. _(3 points)_
#
# __Answer:__
# train loss: 0.7265
#   dev loss: 0.7573
#
# __Question:__ Report the training and validation accuracies at the end of 15 epochs. _(2 points)_
#
# __Answer:__
# train acc: 0.7798
# dev acc: 0.7790
#
# __Question:__ Report the test average CER. _(3 points)_
#
# __Answer:__
# Avg CER: 0.3601

# %% [markdown]
# ## Part 2: Seq2Seq with Attention
#
# Next we will modify our EncoderDecoder to use an Attention mechanism.
# We will resue the RNNLM class you made in part 1 for the encoder.
#
# For the Decoder, we need to use an `AttentionDecoder`. The `AttentionDecoder`, inturn requires an `Attention` object.
#
# We will first build the `Attention` class. This class accepts 1) a sequence of encoder hidden states and 2) a decoder state as inputs. The output is a `context_vector` which is basically a weighted sum of the encoder hidden states. The weights (using which we computed the weighted sum) is also computed in this class. These weights are called attention weights.
#
# Complete the following code block to finish the attention mechanism. _(15 points)_

# %%
class Attention(torch.nn.Module):
  def __init__(self,
                hidden_size):
    super().__init__()
    self.hidden_size = hidden_size
    m = torch.Tensor(hidden_size, hidden_size)
    torch.nn.init.xavier_uniform_(m)
    self.attn_weight_matrix = torch.nn.Parameter(m)
      
  def forward(self, encoder_states, prev_decoder_state):
    """Computes a context vector from encoder_states and prev_decoder_state
    Args:
        encoder_states: sequence of encoder hidden states. shape should be (1, src_length, hidden_size) = (1,12,64)
        prev_decoder_state: the hidden state from the previous decoder time-step. shape should be (1, 1, hidden_size)
    Returns:
        context_vector: context vector summarizing the encoder states for the current time-step in the decoder. shape should be (1, 1, hidden_size)
    """
    #TODO: reshape the prev_decoder from (1, 1, hidden_size) to (1, hidden_size)

    prev_decoder_state = prev_decoder_state.squeeze(1)
    #print(prev_decoder_state.size()) = (1,64)

    #TODO: compute unnormalized attention weights for each position of the source encoding
    #TODO: this can be done using two matrix multipications
    #TODO: refer to https://pytorch.org/docs/stable/torch.html?highlight=torch%20mm#torch.mm
    #TODO: name the result of the two matrix multiplcations as `attn_wts`
    #TODO: the shape of `attn_wts` should be (src_length, 1)
    encoder_states = encoder_states.squeeze(-3) # srclen,64
    #print('after squeeze, encoder_states.size = ', encoder_states.size())
    
    attn_wts = torch.matmul(encoder_states,prev_decoder_state.T)
    #print("weights size(should be (scr,1)) = ",attn_wts.size())

    #TODO: scale the attention weights (i.e. divide by the sqrt of the length of the src sequence)

    attn_wts = attn_wts / math.sqrt(encoder_states.size()[0])

    #TODO: normalize the attention weights using the softmax function in pytorch
    #TODO: name the normalized attention weights as `attn_probs`

    attn_probs = torch.nn.functional.softmax(attn_wts,0)

    #TODO: the `context_vector` is the sum of encoder states weighted by `attn_probs`
    #TODO: compute the `context_vector` here 
    #TODO: you may find this useful (https://pytorch.org/docs/stable/notes/broadcasting.html#broadcasting-semantics)
    #TODO: the shape of the `context_vector` should be (1, hidden_size)
    
    #attn_probs:(12,1) encoder_states:(12,64)
    context_vector = torch.matmul(attn_probs.T,encoder_states)
    
    context_vector = context_vector.unsqueeze(1) # we reshape the `context_vector` to  (1, 1, hidden_size)
    # (1,1,64)
    return context_vector

# %% [markdown]
# Now complete the following implementation of an attention-based decoder. _(10 points)_

# %%
class AttentionDecoder(torch.nn.Module):
  def __init__(self,
                vocab_size,
                embedding_size,
                hidden_size,
                num_layers=1,
                dropout=0.1):
    super().__init__()
    self.vocab_size = vocab_size
    self.embedding_size = embedding_size
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.dropout_prop = dropout
    self.dropout = torch.nn.Dropout(dropout)
    self.num_layers = num_layers
    self.embedding = torch.nn.Embedding(self.vocab_size, self.embedding_size)
    self.output_proj = torch.nn.Linear(self.hidden_size, self.vocab_size)
    self.rnn = torch.nn.LSTM(embedding_size + hidden_size, hidden_size, num_layers,
                              batch_first=True, dropout=dropout, bidirectional=False)
    self.attention = Attention(self.hidden_size)

  def forward(self, encoder_states, y):
    """Computes loss and accuracy during training.
    Args:
        encoder_states: sequence of encoder hidden states. shape should be (1, src_length, hidden_size)
        y: sequence of target symbols. shape should be (1, tgt_length)
    Returns:
        output_dist: pytorch tensor with grad_fn of shape (1, tgt_length - 1, vocab_size)
    """
    # we create the initial hidden_state and cell_state for the Decoder here
    h, c = (torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states),
            torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states))
    
    #TODO: the first input to our Attention Decoder should always be the embedding corresponding to the "<BOS>" symbol
    #TODO: recall that y[0, 0] is always going to represent the <BOS> symbol
    #TODO: create the target embedding for the first time-step here
    #TODO: name this target embedding `tgt_embedding` , it should be of shape (1, embedding_size)
    tgt_embedding = self.embedding(y[0,0])
    tgt_embedding = tgt_embedding.unsqueeze(0)
    #print(tgt_embedding.size()) = (1,64)

    output_buffer = []
    for tgt_idx in range(y.shape[1] - 1):
      #TODO: compute the `context_vector` using self.attention object
      #TODO: `self.attention` takes `encoder_states` and the decoder hidden_state `h` as input
      context_vector = self.attention(encoder_states,h)
      #print(context_vector.size()) = (1,1,64)
      #TODO: concat the `context_vector` and the previous target word's embedding
      #TODO: the result should be of size (1, 1, embedding_size + hidden_size)
      #TODO: the concated tensor is going to be the input to our decoder
      #TODO: name the result of the concat operation `decoder_input`
      #TODO: `decoder_input` should be of size  (1, embed_size + hidden_size)
      #TODO: you may find this useful: https://pytorch.org/docs/stable/torch.html?highlight=torch%20cat#torch.cat

      decoder_input = torch.cat((context_vector, tgt_embedding.unsqueeze(1)), dim=2)
      #context: (1,1,64) tgt_emb:(1,64)

      #TODO: supply `decoder_input` to the decoder RNN i.e. `self.rnn`
      #TODO: also supply the hiddent_state `h` and the cell_state `c`
      #TODO: also supply the hidden state and cell state
     
      #TODO: the output of this operation should be: o, (h, c)
      #TODO: (new_hidden_state, new_cell_state) becomes (hidden_state, cell_state) for the next step 
      #TODO: `o`, `h`, `c` should be of size (1, 1, hidden_size)
      o, (h, c) = self.rnn(decoder_input, (h, c))
      #TODO: use the linear layer `self.output_proj` to project the output to the target vocabulary
      #TODO: name the result `output`
      #TODO: shape should be (1, 1, vocab_size)
      output = self.output_proj(o)

      output_buffer.append(output)
      tgt = y[:, tgt_idx + 1]
      tgt_embedding = self.embedding(tgt)
      #end of for loop
    output_dist = torch.cat(output_buffer, dim=1)
    return output_dist

  def generate(self, encoder_states, start_idx, end_idx, idx2vocab=None, max_len=50):
    """Generates and output sequence, i.e. predicts the output sequence.
    Args:
        encoder_states: sequence of encoder hidden states. shape should be (1, src_length, hidden_size)
        start_idx: index of the <BOS> token
        end_idx: index of the <EOS> token
        idx2vocab: a dictionary that maps indexes to the output tokens
    Returns:
        out: list of strings
    """
    # we create the initial hidden_state and cell_state for the Decoder here  
    h, c = (torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states),
            torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states))
    
    #TODO: create a tensor which contains the idx of the <BOS> symbol 
    #TODO: and copy it to the GPU using the .cuda() function
    #TODO: name this tensor `inp` it should be of size (1, 1)
    
    h = h.cuda()
    c = c.cuda() 
    inp = torch.tensor([start_idx]).long().unsqueeze(0)
    inp = inp.cuda() if self.embedding.weight.is_cuda else inp



    out = [] # a buffer that will hold the generated sequence
    for _ in range(max_len):

      #TODO: obtain the embedding of the input symbol (its shape should be (1, embed_size)
      #TODO: this is done using `self.embedding`
      #TODO: name the result `tgt_embedding`

      with torch.no_grad():
        tgt_embedding = self.embedding(inp)

      #TODO: compute the `context_vector` using `self.attention`
      #TODO: this step is simlar to that from the forward function.

      context_vector = self.attention(encoder_states,h)
      
      #TODO: compute the `decoder_input` by concating the `context_vector` and the `tgt_embedding`
      #TODO: the shape of the result should be (1, 1, embed_size + hidden_size)
      #TODO: supply the `decoder_input` along with the state tuple to `self.rnn`
      decoder_input = torch.cat((context_vector,tgt_embedding),dim =2)
      o, (h, c) = self.rnn(decoder_input, (h, c))

      #TODO: obtain the output distribution using the `self.output_proj` layer.
      #TODO: name the resulting output as `o_dist`, it should be of size (1, 1, vocab_size)
      o_dist = self.output_proj(o)
      
      #TODO: As we are generating the output, we must select one of the symbols to produce from
      #TODO: the output distribution. For this homework, we'll simply pick the index of the max-valued symbol from this distribution
      #TODO: This is known as "greedy" decoding
      _, pred = o_dist.max(dim=2)
      

      #TODO: to decide when to end the sequence, check if the index of the max-valued symbol is equal to `end_idx`
      #TODO: if it is the end_idx break out of the loop

      if pred.item() == end_idx:
          break
      out.append(pred.item() if idx2vocab is None else idx2vocab[pred.item()])
      inp = pred

      #TODO: if it is not the end_idx, convert the symbol from an index to a string using idx2vocab
      #TODO: add the string-symbol to the out buffer

      
      #TODO: lastly, we will use the predicted symbol as the input i.e. `inp` for the next time step


      #end of for loop
    return out

# %%
class EncoderDecoderAttention(torch.nn.Module):
  def __init__(self,
                src_vocab_size,
                tgt_vocab_size,
                embedding_size,
                hidden_size,
                num_layers=1,
                dropout=0.0,
                max_grad_norm=5.0):
    super().__init__()
    self.hidden_size = hidden_size
    self.embedding_size = embedding_size
    self.num_layers = num_layers
    self.max_grad_norm = max_grad_norm
    self.encoder = LSTMLM(src_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.decoder = AttentionDecoder(tgt_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.log_smax = torch.nn.LogSoftmax(dim=-1)
    self.loss = torch.nn.NLLLoss(reduction='mean', ignore_index=-1)
    #We are going to package the optimizer inside this class
    self.optimizer = torch.optim.Adam(self.parameters())

  def train_step(self, x, y):
    """ Performs one step of SGD
    Args:
      x: the input sequence, its size should be: (1, src_length)
      y: the output sequence, its size should be (1, tgt_length)
    Returns:
      loss: the loss for this example (note this is just for logging it is not a pytorch tensor)
      accuracy: the accuracy for this example
    """
    self.optimizer.zero_grad()
    _loss, acc = self(x, y)
    _loss.backward()
    grad_norm = torch.nn.utils.clip_grad_norm_(self.parameters(),
                                                self.max_grad_norm)

    if math.isnan(grad_norm):
      print('skipping update grad_norm is nan!')
    else:
      self.optimizer.step()
    loss = _loss.item()
    return loss, acc

  def forward(self, x, y):
    """Computes loss and accuracy during training.
    Args:
      x: sequence of source symbols. shape should be (1, src_length)
      y: sequence of target symbols. shape should be (1, tgt_length)
    Returns:
      loss: pytorch scalar with grad_fn. shape should be (1, 1)
      accuracy: scalar
    """
    _, encoder_states, _ = self.encoder(x)
    out_tgt = self.decoder(encoder_states, y)
    out_tgt_lsm = self.log_smax(out_tgt)
    y_output = y[:, 1:]
    loss = self.loss(out_tgt_lsm.squeeze(0), y_output.squeeze(0))
    _, pred = out_tgt.max(dim=2)
    accuracy = float((pred == y_output).sum()) / y_output.numel()
    return loss, accuracy

  def generate(self, x, start_idx, end_idx, idx2vocab=None, max_len=50):
    _, encoder_states, _ = self.encoder(x)
    out = self.decoder.generate(encoder_states, start_idx, end_idx, idx2vocab)
    return out

# %%
print(train_corpus.data_size, dev_corpus.data_size, test_corpus.data_size)
model_attn = EncoderDecoderAttention(src_vocab_size=len(train_corpus.src_vocab),
                                tgt_vocab_size=len(train_corpus.tgt_vocab),
                                embedding_size=64,
                                hidden_size=64,
                                num_layers=1)
model_attn = model_attn.cuda()
print(model_attn)
print('num parameters:', sum([p.numel() for p in model_attn.parameters()]))
# Out:
# 10000 2000 5000
# EncoderDecoderAttention(
#   (encoder): LSTMLM(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (embedding): Embedding(31, 64)
#     (rnn): LSTM(64, 64, batch_first=True)
#     (output): Linear(in_features=64, out_features=31, bias=True)
#   )
#   (decoder): AttentionDecoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (embedding): Embedding(75, 64)
#     (output_proj): Linear(in_features=64, out_features=75, bias=True)
#     (rnn): LSTM(128, 64, batch_first=True)
#     (attention): Attention()
#   )
#   (log_smax): LogSoftmax(dim=-1)
#   (loss): NLLLoss()
# )
# num parameters: 100714

# %%
model_attn = train(model_attn, train_corpus, dev_corpus, max_epochs=10) #takes 1 - 1.5 hours
# Out:
# epoch: 0 time elapsed: 106.80
# train loss: 1.6931 train acc: 0.5640
#   dev loss: 1.0394   dev acc: 0.7202
# epoch: 1 time elapsed: 220.93
# train loss: 0.8585 train acc: 0.7593
#   dev loss: 0.7794   dev acc: 0.7779
# epoch: 2 time elapsed: 335.30
# train loss: 0.6850 train acc: 0.8001
#   dev loss: 0.6896   dev acc: 0.7981
# epoch: 3 time elapsed: 449.98
# train loss: 0.6010 train acc: 0.8215
#   dev loss: 0.6616   dev acc: 0.8058
# epoch: 4 time elapsed: 564.42
# train loss: 0.5502 train acc: 0.8326
#   dev loss: 0.6126   dev acc: 0.8178
# epoch: 5 time elapsed: 679.20
# train loss: 0.5127 train acc: 0.8438
#   dev loss: 0.5802   dev acc: 0.8275
# epoch: 6 time elapsed: 793.40
# train loss: 0.4826 train acc: 0.8500
#   dev loss: 0.5908   dev acc: 0.8268
# epoch: 7 time elapsed: 907.24
# train loss: 0.4588 train acc: 0.8568
#   dev loss: 0.5826   dev acc: 0.8259
# epoch: 8 time elapsed: 1021.35
# train loss: 0.4375 train acc: 0.8630
#   dev loss: 0.5535   dev acc: 0.8380
# epoch: 9 time elapsed: 1135.13
# train loss: 0.4155 train acc: 0.8690
#   dev loss: 0.5566   dev acc: 0.8360

# %%
evaluate(model_attn, test_corpus)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1 utility's pred: Y UW0 T IH1 L AH0 T IY0 Z ref: Y UW0 T IH1 L AH0 T IY0 Z cer: 0.0000
# 2 rothenberg pred: R OW1 T AH0 N B ER0 G ref: R AO1 TH AH0 N B ER0 G cer: 0.2500
# 3 kinesiology pred: K IH2 N AH0 S IY0 AA1 L AH0 JH IY0 ref: K IH2 N IH0 S IY2 AA1 L AH0 JH IY0 cer: 0.1818
# 4 reclassified pred: R IH0 K L AE1 S AH0 F AY2 D ref: R IY0 K L AE1 S AH0 F AY2 D cer: 0.1000
# 5 substantive pred: S AH0 B S T AE1 N T IH0 V ref: S AH1 B S T AH0 N T IH0 V cer: 0.2000
# 6 situations pred: S IH2 T Y UW0 EY1 SH AH0 N Z ref: S IH2 CH UW0 EY1 SH AH0 N Z cer: 0.2222
# 7 lobianco pred: L OW0 B IY0 AA1 N K OW0 ref: L OW0 B IY0 AA1 N K OW0 cer: 0.0000
# 8 participants' pred: P AA1 R T IH0 S AH0 P AE2 N T S ref: P AA0 R T IH1 S AH0 P AH0 N T S cer: 0.2500
# 9 transportable pred: T R AE0 N S P AO1 R T AH0 B AH0 L ref: T R AE0 N S P AO1 R T AH0 B AH0 L cer: 0.0000
# 10 inscribes pred: IH2 N S K R IH1 B Z AH0 Z ref: IH2 N S K R AY1 B Z cer: 0.3750
# 11 grandbaby pred: G R AE1 N D B AE2 B IY0 ref: G R AE1 N D B EY2 B IY0 cer: 0.1111
# 12 costanzo pred: K AO1 S T AH0 N Z AA0 ref: K OW0 S T AA1 N Z OW0 cer: 0.3750
# 13 novakovich pred: N OW0 V AA0 K AA1 V IH0 CH ref: N AH0 V AA1 K AH0 V IH0 CH cer: 0.3333
# 14 engulfing pred: IH0 G D AH1 L F IH0 NG ref: IH0 N G AH1 L F IH0 NG cer: 0.2500
# 15 jorgenson pred: G ER1 JH AH0 N S AH0 N ref: JH AO1 R G IH0 N S AH0 N cer: 0.5556
# 16 marketeers pred: M AA1 R K AH0 T IY2 Z ER0 Z ref: M AA2 R K AH0 T IH1 R Z cer: 0.4444
# 17 branagan pred: B R AE1 N AH0 G AH0 N ref: B R AE1 N AH0 G AE0 N cer: 0.1250
# 18 toshimitsu pred: T OW0 SH IY1 M AH0 T AH0 S ref: T OW0 SH IY0 M IY1 T S UW0 cer: 0.4444
# 19 electrobiology pred: AH0 L EH2 K T R AH0 B IY0 AA1 L IY0 OW0 IY0 ref: IH2 L EH2 K T R OW0 B AY0 AA1 L AH0 JH IY2 cer: 0.4286
# 20 flagships pred: F L AE1 JH SH IH1 P S ref: F L AE1 G SH IH2 P S cer: 0.2500
# 21 downsizing pred: D AW1 N Z AY2 Z IH0 NG ref: D AW1 N S AY2 Z IH0 NG cer: 0.1250
# 22 biofeedback pred: B AY2 OW0 F EH1 D AH0 B AE2 K ref: B AY0 OW0 F IY1 D B AE2 K cer: 0.3333
# 23 retrovir pred: R IH0 T R AA1 V ER0 ref: R EH1 T R OW0 V IH2 R cer: 0.5000
# 24 jovanovic pred: V OW0 V AA0 N AA1 V IH0 K ref: Y AH0 V AH0 N AA1 V IH0 K cer: 0.3333
# 25 conjugated pred: K AH0 N JH AH1 G AH0 T IH0 D ref: K AA2 N JH AH0 G EY1 T IH0 D cer: 0.3000
# 26 brooksville pred: B R AO1 K S V IH2 L ref: B R UH1 K S V IH0 L cer: 0.2500
# 27 nonperforming pred: N AA1 N P ER0 F AO2 R M IH0 NG ref: N AA0 N P ER0 F AO1 R M IH0 NG cer: 0.1818
# 28 fulfilling pred: F Y UW1 L IH0 L IH0 NG ref: F UH0 L F IH1 L IH0 NG cer: 0.5000
# 29 conjecture pred: K AH0 N JH EH1 K T ER0 ref: K AH0 N JH EH1 K CH ER0 cer: 0.1250
# 30 adjustments pred: AH0 D AH1 S T M AH0 N T S ref: AH0 JH AH1 S T M AH0 N T S cer: 0.1000
# 31 hoglund's pred: HH AA1 G L AH0 N D Z ref: HH AO1 G L AH0 N D Z cer: 0.1250
# 32 languished pred: L AE1 JH AH0 SH IH0 D ref: L AE1 NG G W IH0 SH T cer: 0.6250
# 33 obscenity pred: AA1 B S AH0 N IH0 T IY0 ref: AH0 B S EH1 N IH0 T IY0 cer: 0.2500
# 34 kingsport pred: K IH1 NG S P AO2 R T ref: K IH1 NG S P AO2 R T cer: 0.0000
# 35 premonitory pred: P R IY0 M AA1 N AH0 T AO2 R IY0 ref: P R AH0 M AH1 N AH0 T ER0 IY0 cer: 0.4000
# 36 slowinski pred: S L OW1 AH0 N S K IY0 ref: S L OW0 IH1 N S K IY0 cer: 0.2500
# 37 schiltknecht pred: SH IH1 L T K N IH0 K T ref: SH IH1 L T N EH2 K T cer: 0.2500
# 38 stolichnaya pred: S T OW0 L IH1 K N AH0 ref: S T OW2 L IH0 K N AY1 AH0 cer: 0.3333
# 39 subfamily pred: S AH0 B F AE1 M AH0 L IY0 ref: S AH1 B F AE2 M AH0 L IY0 cer: 0.2222
# 40 peterbilt pred: P EH1 T ER0 B IH2 L T ref: P IY1 T ER0 B IH2 L T cer: 0.1250
# 41 mcdermid pred: M AH0 K D ER1 M AH0 D ref: M AH0 K D ER1 M AH0 D cer: 0.0000
# 42 simulcast pred: S IH1 M Y AH0 L AE2 S T ref: S AY1 M Y AH0 L K AE2 S T cer: 0.2000
# 43 reemergence pred: R IY0 EH1 R G IH0 N IH0 Z ref: R IY0 IH0 M ER1 JH AH0 N S cer: 0.7778
# 44 papadopoulos pred: P AA0 P AA0 D AA1 P OW0 L OW0 Z ref: P AE2 P AH0 D AA1 P AH0 L AH0 S cer: 0.4545
# 45 factually pred: F AE1 K CH AH0 W AH0 L IY0 ref: F AE1 K CH UW0 AH0 L IY0 cer: 0.2500
# 46 hildegarde pred: HH IH0 L D AA1 G D R D IY0 ref: HH IH1 L D IH0 G AA2 R D cer: 0.4444
# 47 gingerbread pred: G IH1 NG G ER0 B R EY2 D ref: JH IH1 N JH ER0 B R EH2 D cer: 0.4444
# 48 rosenman pred: R OW1 Z AH0 N M AH0 N ref: R OW1 Z AH0 N M AH0 N cer: 0.0000
# 49 unabated pred: AH0 N AE1 B AH0 T IH0 D ref: AH2 N AH0 B EY1 T IH0 D cer: 0.3750
# 50 batignolles pred: B AE1 T AH0 G N AH0 L AH0 Z ref: B AE2 T IH0 N Y OW1 L AH0 S cer: 0.6000
# 51 frazzini pred: F R AE2 Z AY2 N IY0 ref: F R AA0 T S IY1 N IY0 cer: 0.5000
# 52 disapproving pred: D IH0 S AA1 P R AH0 V IH0 NG ref: D IH0 S AH0 P R UW1 V IH0 NG cer: 0.2000
# 53 ventilating pred: V EH1 N T AH0 L EY2 T IH0 NG ref: V EH1 N T AH0 L EY2 T IH0 NG cer: 0.0000
# 54 believability pred: B EH2 L AH0 V EY1 B AH0 L AY2 ref: B AH0 L IY2 V AH0 B IH1 L IH0 T IY0 cer: 0.5833
# 55 punctuating pred: P AH1 NG K CH AH0 T IH0 NG ref: P AH1 NG K CH UW0 EY2 D IH0 NG cer: 0.3000
# 56 countdowns pred: K AW1 N T SH UW2 N Z ref: K AW1 N T D AW2 N Z cer: 0.2500
# 57 legalities pred: L AH0 G AE1 L AH0 T IY0 Z ref: L IY0 G AE1 L IH0 T IY0 Z cer: 0.2222
# 58 intercellular pred: IH2 N T ER0 S EH1 L AH0 L ER0 ref: IH2 N T ER0 S EH1 L Y AH0 L ER0 cer: 0.0909
# 59 extravaganza pred: AE2 K S T R AH0 V AA1 G AH0 N AH0 ref: EH0 K S T R AE2 V AH0 G AE1 N Z AH0 cer: 0.3846
# 60 entombment pred: EH0 N T OW1 M B AH0 N T ref: IH0 N T UW1 M M AH0 N T cer: 0.3333
# 61 suspensions pred: S AH0 S P EH1 N SH AH0 N Z ref: S AH0 S P EH1 N SH AH0 N Z cer: 0.0000
# 62 recognition's pred: R IY2 K AH0 G N IH1 SH AH0 N Z ref: R EH2 K IH0 G N IH1 SH AH0 N Z cer: 0.1818
# 63 compartments pred: K AH0 M P AA1 R T M AH0 N T S ref: K AH0 M P AA1 R T M AH0 N T S cer: 0.0000
# 64 triumphantly pred: T R IH1 M AH0 N T L IY0 ref: T R AY0 AH1 M F AH0 N T L IY0 cer: 0.2727
# 65 unreliable pred: AH0 N R EH1 L IY0 AH0 B AH0 L ref: AH2 N R IH0 L AY1 AH0 B AH0 L cer: 0.3000
# 66 northwestern's pred: N AO1 R TH ER0 AH0 S T ER0 Z ref: N AO2 R TH W EH1 S T ER0 N Z cer: 0.3636
# 67 hempfling pred: HH EH1 M P L IH0 NG ref: HH EH1 M P F AH0 L IH0 NG cer: 0.2222
# 68 renegotiate pred: R IH0 N IH0 G AA1 T IY0 EY2 T ref: R IY2 N IH0 G OW1 SH IY0 EY2 T cer: 0.3000
# 69 mandalit pred: M AE1 N D AH0 L IH0 T ref: M AE1 N D AH0 L IH2 T cer: 0.1250
# 70 criscione pred: K R IH2 S IH0 AA1 N AH0 ref: K R IY0 S CH OW1 N IY0 cer: 0.5000
# 71 gilchrest pred: G IH1 L K R AH0 S T ref: G IH1 L K ER0 IH0 S T cer: 0.2500
# 72 interiors pred: IH2 N T IH1 R IY0 AO0 R Z ref: IH2 N T IH1 R IY0 ER0 Z cer: 0.2500
# 73 misdiagnosis pred: M IH0 S D AH0 JH AA1 N AH0 S IY0 Z ref: M IH0 S D AY2 IH0 G N OW1 S AH0 S cer: 0.5000
# 74 repositories pred: R IH0 P AA1 S AH0 T ER0 IY0 Z ref: R IY0 P AA1 Z AH0 T AO2 R IY0 Z cer: 0.3636
# 75 lithuanian pred: L UW0 TH AH0 Y AA1 N AH0 N ref: L IH2 TH AH0 W EY1 N IY0 AH0 N cer: 0.4000
# 76 transcanada's pred: T R AE2 N Z K AE1 N AH0 Z AH0 Z ref: T R AE2 N Z K AE1 N AH0 D AH0 Z cer: 0.0833
# 77 badalamenti pred: B AE2 D AH0 L AA1 M AH0 N T IY0 ref: B AA0 D AA0 L AA0 M EH1 N T IY0 cer: 0.3636
# 78 verifiable pred: V ER0 IH1 F AH0 B AH0 L ref: V EH1 R AH0 F AY2 AH0 B AH0 L cer: 0.4000
# 79 hempstead pred: HH EH1 M P S T IY2 D ref: HH EH1 M P S T EH0 D cer: 0.1250
# 80 prerecorded pred: P R IY1 R K AO2 R D ref: P R IY2 R IY0 K AO1 R D IH0 D cer: 0.4545
# 81 clipboard pred: K L IH1 P B AO2 R D ref: K L IH1 P B AO2 R D cer: 0.0000
# 82 paganism pred: P AA0 G AA0 N IY1 Z AH0 M ref: P EY1 G AH0 N IH2 Z AH0 M cer: 0.3333
# 83 fabricate pred: F AE1 B R IH0 K EY2 T ref: F AE1 B R AH0 K EY2 T cer: 0.1250
# 84 teleprobe pred: T EH1 L AH0 P R AH0 B ref: T EH1 L AH0 P R OW1 B cer: 0.1250
# 85 cryogenic pred: K R IY0 OW0 JH EH1 N IH0 K ref: K R AY1 AH0 JH EH2 N IH0 K cer: 0.3333
# 86 unmanaged pred: AH0 N M AE1 N AH0 JH D ref: AH0 N M AE1 N IH0 JH D cer: 0.1250
# 87 intricate pred: IH2 N T R IH1 K AH0 T ref: IH1 N T R AH0 K AH0 T cer: 0.2500
# 88 familiarize pred: F AE2 M AH0 L IY1 ER0 Z ref: F AH0 M IH1 L Y ER0 AY2 Z cer: 0.4444
# 89 st-thomas pred: S T AH1 N T HH AA2 M AH0 S ref: S EY1 N T AA1 M AH0 S cer: 0.5000
# 90 kredietbank pred: K R EH1 D AH0 T AH0 G AE0 NG K ref: K R EH0 D IY0 T B AE1 NG K cer: 0.5000
# 91 santa-fe's pred: S AE1 N T AH0 F EH2 Z ref: S AE1 N T AH0 F EY1 Z cer: 0.1250
# 92 distillate pred: D IH0 S T IH1 L AH0 T ref: D IH1 S T AH0 L EY2 T cer: 0.3750
# 93 palkovic pred: P AE2 L K AA1 V IH0 K ref: P AH0 L K AA1 V IH0 K cer: 0.1250
# 94 calculate pred: K AH0 L K Y UW1 L T IY0 ref: K AE1 L K Y AH0 L EY2 T cer: 0.4444
# 95 plebeians pred: P L EH1 B AH0 Y AH0 N Z ref: P L AH0 B IY1 AH0 N Z cer: 0.3750
# 96 insubordination pred: IH2 N S AH0 B ER1 D AH0 N AH0 N EY2 T IY0 ref: IH2 N S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.5000
# 97 recommendations pred: R IY2 K AH0 M EH1 N D AH0 N EY2 SH AH0 N Z ref: R EH2 K AH0 M AH0 N D EY1 SH AH0 N Z cer: 0.3846
# 98 galentine pred: G AE1 L AH0 N T IY2 N ref: G AA0 L EH0 N T IY1 N IY0 cer: 0.4444
# 99 comedienne pred: K AH0 M EH1 D AH0 N ref: K AH0 M IY2 D IY0 EH1 N cer: 0.3750
# 100 stolarski pred: S T OW0 L AA1 R S K IY0 ref: S T AH0 L AA1 R S K IY2 cer: 0.2222
# 101 reprocessed pred: R IH0 P R AH0 S EH1 S T ref: R IY0 P R AO1 S EH0 S T cer: 0.3333
# 102 d'artagnan pred: D AA1 R T AH0 N AE2 N ref: D AH0 R T AE1 NG Y AH0 N # foreign french cer: 0.5833
# 103 radiators pred: R AE1 D IY0 EY2 T ER0 Z ref: R EY1 D IY0 EY2 T ER0 Z cer: 0.1250
# 104 rollerblading pred: R OW1 L ER0 B L EY2 D IH0 NG ref: R OW1 L ER0 B L EY2 D IH0 NG cer: 0.0000
# 105 depended pred: D IH0 P EH1 N D IH0 D ref: D IH0 P EH1 N D AH0 D cer: 0.1250
# 106 sardinia pred: S AA0 R D IY0 N IY1 AH0 ref: S AA0 R D IY1 N IY0 AH0 cer: 0.2500
# 107 intending pred: IH2 N T EH1 N D IH0 NG ref: IH2 N T EH1 N D IH0 NG cer: 0.0000
# 108 homogenization pred: HH OW2 M AH0 JH EH1 N AH0 Z AH0 AH0 T IH0 N ref: HH OW0 M AA1 JH AH0 N IH0 Z EY2 SH AH0 N cer: 0.6154
# 109 telecasts pred: T EH1 L AH0 K S T S ref: T EH1 L AH0 K AE2 S T S cer: 0.1111
# 110 matriculating pred: M AE2 T R IH0 K Y UW1 L AH0 T IH0 NG ref: M AH0 T R IH1 K Y AH0 L EY0 T IH0 NG cer: 0.3077
# 111 conception pred: K AH0 N S P EH1 SH AH0 N ref: K AH0 N S EH1 P SH AH0 N cer: 0.2222
# 112 simonson pred: S IY0 M OW1 N S AH0 N ref: S IH1 M AH0 N S AH0 N cer: 0.2500
# 113 inoffensive pred: IH2 N AH0 F EH1 N S IH0 V ref: IH2 N AH0 F EH1 N S IH0 V cer: 0.0000
# 114 nationalistic pred: N AE2 SH AH0 N AH0 L IH1 S T IH0 K ref: N AE2 SH AH0 N AH0 L IH1 S T IH0 K cer: 0.0000
# 115 fantastically pred: F AE2 N T AE1 S T IH0 K L IY0 ref: F AE0 N T AE1 S T IH0 K L IY0 cer: 0.0909
# 116 istituto pred: IH2 S T IH1 SH AH0 T OW0 ref: IH2 S T IH0 T UW1 T OW0 cer: 0.3750
# 117 florentino pred: F L AA2 R AH0 N T IY1 N OW0 ref: F L AO0 R EH0 N T IY1 N OW0 cer: 0.2000
# 118 microcircuit pred: K IH0 K R OW1 S AH0 S T Y UW0 T ref: M AY1 K R OW0 S ER2 K AH0 T cer: 0.8000
# 119 imperfectly pred: IH2 M P ER0 F EH1 K T L IY0 ref: IH2 M P ER1 F IH0 K T L IY0 cer: 0.2000
# 120 desegregation pred: D IH0 S EH2 G R AH0 G EY1 SH AH0 N ref: D IH0 S EH2 G R AH0 G EY1 SH AH0 N cer: 0.0000
# 121 fleischhacker pred: K L AY1 S K AE2 K ER0 ref: F L AY1 SH HH AH0 K ER0 cer: 0.5000
# 122 dupriest pred: D AH1 P R IY0 S T ref: D AH1 P ER0 IY0 IH0 S T cer: 0.2500
# 123 unattractive pred: AH0 N AE1 T R AE2 K T IH0 V ref: AH2 N AH0 T R AE1 K T IH0 V cer: 0.3000
# 124 sanhedrin pred: S AE1 N HH IH0 D R IH0 N ref: S AE2 N HH IY1 D R IH0 N cer: 0.2222
# 125 callousness pred: K AH0 L AH1 S N AH0 S ref: K AE1 L AH0 S N AH0 S cer: 0.2500
# 126 dermatologist pred: D ER0 M AE1 T AH0 L AH0 T S ref: D ER2 M AH0 T AA1 L AH0 JH IH0 S T cer: 0.5000
# 127 harmonics pred: HH AA1 R M AH0 N IH0 K S ref: HH AA0 R M AA1 N IH0 K S cer: 0.2222
# 128 deployable pred: D IH0 P L OY1 AH0 B AH0 L ref: D IH0 P L OY1 AH0 B AH0 L cer: 0.0000
# 129 approximately pred: AH0 P R AA1 K S AH0 M AH0 T L IY0 ref: AH0 P R AA1 K S AH0 M AH0 T L IY0 cer: 0.0000
# 130 remerchandise pred: R IH0 M ER1 K AH0 N D IY0 Z ref: R IY0 M ER1 CH AH0 N D AY2 Z cer: 0.3000
# 131 bianchini pred: B AY2 AH0 K HH IH1 N IY0 ref: B IY0 AA0 N CH IY1 N IY0 cer: 0.6250
# 132 invigorating pred: IH2 N V IH0 G AO1 R AH0 T IH0 NG ref: IH2 N V IH1 G ER0 EY2 T IH0 NG cer: 0.4000
# 133 castellanos pred: K AE2 S T AH0 L AA1 N OW0 Z ref: K AA0 S T EY0 L AA1 N OW0 Z cer: 0.2000
# 134 hippopotamus pred: F IH2 P AH0 P AA1 T AH0 M ref: HH IH2 P AH0 P AA1 T AH0 M AH0 S cer: 0.2727
# 135 vanorden pred: V AE2 N ER0 N EH1 N ref: V AE0 N AO1 R D AH0 N cer: 0.6250
# 136 biographical pred: B AY2 OW0 G R AE1 F IH0 K AH0 L ref: B AY2 AH0 G R AE1 F IH0 K AH0 L cer: 0.0909
# 137 tartikoff pred: T AA1 R T IH0 K AA2 F ref: T AA1 R T IH0 K AO2 F cer: 0.1250
# 138 transcontinental pred: T R AE2 N Z K AA1 N T AH0 N AH0 L ref: T R AE2 N Z K AA2 N T IH0 N EH1 N T AH0 L cer: 0.3125
# 139 mongosutu's pred: M AH0 NG G AO1 S AH0 T OW0 Z ref: M AA2 NG G OW0 S UW1 T UW0 Z cer: 0.4000
# 140 parametric pred: P EH2 R AH0 M EH1 T R IH0 K ref: P EH2 R AH0 M EH1 T R IH0 K cer: 0.0000
# 141 linguistically pred: L IH1 NG G UW0 S T IH0 K L IY0 ref: L IH0 NG G W IH1 S T IH0 K L IY0 cer: 0.2500
# 142 crotonville pred: K R AA1 T AH0 N V IH2 L ref: K R OW1 T AH0 N V IH2 L cer: 0.1111
# 143 recriminations pred: R IY2 K R IH0 M IH1 N AH0 T IY0 Z ref: R IH0 K R IH2 M IH0 N EY1 SH AH0 N Z cer: 0.5385
# 144 toxicologists pred: T AE2 K S AH0 K AA1 L AH0 JH IH0 S T S ref: T AA2 K S IH0 K AA1 L AH0 JH IH0 S T S cer: 0.1429
# 145 holtzapple pred: HH AA1 L T S P AA2 P AH0 L ref: HH OW1 L T Z AH0 P AH0 L cer: 0.4444
# 146 toriente pred: T AO0 R IY1 N T IY0 ref: T AO2 R IY0 EH1 N T EY0 cer: 0.5000
# 147 utility pred: Y UW0 T IH1 L AH0 T IY0 ref: Y UW0 T IH1 L AH0 T IY0 cer: 0.0000
# 148 norberta pred: N AO1 R B ER0 T EY2 T ref: N AO0 R B EH1 R T AH0 cer: 0.6250
# 149 amputated pred: AE1 M P AH0 T EY2 T IH0 D ref: AE1 M P Y AH0 T EY2 T IH0 D cer: 0.1000
# 150 pleasanton pred: P L IY2 AH0 S AE1 N T AH0 N ref: P L EH1 Z AH0 N T AH0 N cer: 0.4444
# 151 mollycoddle pred: M OW0 L IY0 K AA1 D AH0 L ref: M AA1 L IY0 K AA2 D AH0 L cer: 0.2222
# 152 lexical pred: L EH1 K S AH0 K AH0 L ref: L EH1 K S IH0 K AH0 L cer: 0.1250
# 153 omnipotent pred: AH0 M IH1 P AH0 T AH0 N T ref: AA0 M N IH1 P AH0 T AH0 N T cer: 0.2000
# 154 repudiating pred: R IH0 P Y UW1 D IY0 EY2 T IH0 NG ref: R IY0 P Y UW1 D IY0 EY2 T IH0 NG cer: 0.0909
# 155 avant-garde pred: AE1 V AH0 N T G R AA0 D ref: AH0 V AA1 N T G AA1 R D cer: 0.4444
# 156 toldrian pred: T OW1 L D R IY0 AH0 N ref: T OW1 L D R IY0 AH0 N cer: 0.0000
# 157 transformers pred: T R AE0 N S F AO1 R M ER0 Z ref: T R AE0 N S F AO1 R M ER0 Z cer: 0.0000
# 158 eurobond pred: OW1 R OW0 B OW2 N D ref: Y UW1 R OW0 B AA2 N D cer: 0.3750
# 159 redistributing pred: R IH0 D IH2 S T R AH0 B IH1 SH IH0 NG ref: R IY2 D IH0 S T R IH1 B Y UW0 T IH0 NG cer: 0.4286
# 160 osmundson pred: AH0 S M AH1 N D S AH0 N ref: AA1 Z M AH0 N D S AH0 N cer: 0.3333
# 161 basements pred: B AE1 S AH0 M AH0 N T S ref: B EY1 S M AH0 N T S cer: 0.2500
# 162 securely pred: S EH1 K Y ER0 IH0 L IY0 ref: S IH0 K Y UH1 R L IY0 cer: 0.3750
# 163 unremarked pred: AH0 N R EH1 M AH0 R K D ref: AH0 N R IH0 M AA1 R K T cer: 0.3333
# 164 comparing pred: K AH0 M P AA1 R IH0 NG ref: K AH0 M P EH1 R IH0 NG cer: 0.1250
# 165 lillibridge pred: L IH1 L IH0 B R IH0 JH ref: L IH1 L IH0 B R IH2 JH cer: 0.1250
# 166 afterimages pred: AE1 F T ER0 IH0 M AE2 G Z ref: AE1 F T ER0 IH2 M IH0 JH AH0 Z cer: 0.4000
# 167 supergiant pred: S UW2 P ER0 JH IY1 AH0 N T ref: S UW1 P ER0 JH AY1 AH0 N T cer: 0.2222
# 168 opponent's pred: AA1 P AH0 N AH0 N T S ref: AH0 P OW1 N AH0 N T S cer: 0.2500
# 169 microwaved pred: M AY1 K R OW0 HH AA2 V D ref: M AY1 K R OW0 W EY2 V D cer: 0.2222
# 170 corinthian pred: K AO2 R AH0 N TH IY0 AA1 N ref: K ER0 IH1 N TH IY0 AH0 N cer: 0.5000
# 171 lipoprotein pred: L IH2 P AH0 R AA1 P SH AH0 N ref: L IH2 P AH0 P R OW1 T IY0 N cer: 0.5000
# 172 repositioning pred: R IH0 P AH0 Z IH1 SH AH0 N IH0 NG ref: R IY2 P AH0 Z IH1 SH AH0 N IH0 NG cer: 0.0909
# 173 mutilation pred: M Y UW0 T IH1 L AH0 SH AH0 N ref: M Y UW2 T AH0 L EY1 SH AH0 N cer: 0.3000
# 174 meteorologists pred: M EH2 T ER0 AA1 L AH0 JH IH0 S T S ref: M IY2 T IY0 ER0 AA1 L AH0 JH IH0 S T S cer: 0.1538
# 175 pierrepont pred: P AY1 ER0 AH0 P AA2 N T ref: P IH0 R EY1 P OW0 N T cer: 0.5000
# 176 ecstatic pred: IH0 K S T AE1 T IH0 K ref: EH0 K S T AE1 T IH0 K cer: 0.1250
# 177 branaman pred: B R AE1 N AH0 M AH0 N ref: B R AE1 N AH0 M AH0 N cer: 0.0000
# 178 suffocated pred: S UW1 F AH0 K AE2 T IH0 D ref: S AH1 F AH0 K EY2 T IH0 D cer: 0.2222
# 179 hovnanian pred: HH OW0 V N AA0 N IY0 AA1 N ref: HH AA2 V N EY1 N IY0 AH0 N cer: 0.3333
# 180 criss-cross pred: K R IH1 S K R OW2 S ref: K R IH1 S K R AO1 S cer: 0.1250
# 181 northeast's pred: N AO1 R TH AH0 S T S ref: N AO2 R TH IY1 S T S cer: 0.2500
# 182 disfigurement pred: D IH0 S F IH1 G Y ER0 M AH0 N T ref: D IH0 S F IH1 G Y ER0 M EH0 N T cer: 0.0833
# 183 stapling pred: S T AE1 P L IH0 NG ref: S T EY1 P AH0 L IH0 NG cer: 0.2500
# 184 buttressing pred: B AH1 T R AH0 S IH0 NG ref: B AH1 T R AH0 S IH0 NG cer: 0.0000
# 185 telefonos pred: T EH2 L AH0 F AA1 N OW0 Z ref: T EH2 L EH0 F OW1 N OW0 S cer: 0.3333
# 186 reflexivity pred: R IH0 F L EH1 K S IH0 V IH0 T IY0 ref: R IY2 F L EH2 K S IH1 V IH0 T IY0 cer: 0.2500
# 187 profitably pred: P R AH0 F IH1 T AH0 B L IY0 ref: P R AA1 F AH0 T AH0 B L IY0 cer: 0.2000
# 188 grudzinski pred: G R UW0 D IH1 N S K IY0 ref: G R AH0 JH IH1 N S K IY0 cer: 0.2222
# 189 non-poisonous pred: N AA0 N P OY1 Z AH0 N AH0 S ref: N AA0 N P OY1 Z AH0 N AH0 S cer: 0.0000
# 190 tallahassee's pred: T AE1 L AH0 HH EH2 S IH0 Z ref: T AE2 L AH0 HH AE1 S IY0 Z cer: 0.3333
# 191 trombones pred: T R AE0 M B AA0 N AH0 Z ref: T R AA0 M B OW1 N Z cer: 0.3750
# 192 rosengrant pred: R OW1 Z AH0 N G R AE2 N T ref: R OW1 Z AH0 N G R AE2 N T cer: 0.0000
# 193 laceration pred: L AE2 S ER0 EY1 SH AH0 N ref: L AE2 S ER0 EY1 SH AH0 N cer: 0.0000
# 194 ricketson pred: R IH1 K AH0 S T AH0 N ref: R IH1 K IH0 T S AH0 N cer: 0.3750
# 195 bankworcester pred: B AE1 NG K ER0 W IH0 S T ER0 ref: B AE1 NG K W ER1 CH EH2 S T ER0 cer: 0.3636
# 196 operations pred: AA2 P ER0 EY1 SH AH0 N Z ref: AA2 P ER0 EY1 SH AH0 N Z cer: 0.0000
# 197 subunits pred: S AH0 B AH1 N IH0 T S ref: S AH2 B Y UW1 N IH0 T S cer: 0.3333
# 198 yogiisms pred: Y OW1 G IY0 S IH2 Z AH0 M Z ref: Y OW0 G IY1 S AH0 M Z cer: 0.5000
# 199 mazziotti pred: M AH0 Z AY2 Z AA1 T IY0 ref: M AA0 T S IY0 OW1 T IY0 cer: 0.6250
# 200 dornhens pred: D AA1 R D AH0 N Z ref: D AO1 R N HH EH0 N Z cer: 0.5000
# 201 crustaceous pred: K R UW0 S T EY1 S IY0 Z ref: K R AH0 S T EY1 SH AH0 S cer: 0.4444
# 202 dilenschneider pred: D IH1 L AH0 N SH IH0 N JH ER0 ref: D AY1 L AH0 N SH N AY2 D ER0 cer: 0.4000
# 203 innovated pred: IH2 N AA1 V AH0 T IH0 D ref: IH1 N AH0 V EY2 T IH0 D cer: 0.3750
# 204 disseminated pred: D IH0 S EH1 M AH0 N EY2 T IH0 D ref: D IH0 S EH1 M AH0 N EY2 T AH0 D cer: 0.0909
# 205 auxiliary pred: Y UW0 S IH1 L IY0 ER0 IY0 ref: AA0 G Z IH1 L Y ER0 IY0 cer: 0.5000
# 206 mississippi's pred: M IH0 S IH0 S IH1 P IH0 Z IY0 Z ref: M IH2 S IH0 S IH1 P IY0 Z cer: 0.3333
# 207 noranda's pred: N AO2 R AH0 N D EY1 Z AH0 Z ref: N AO0 R AE1 N D AH0 Z cer: 0.5000
# 208 altercations pred: AE2 L T ER0 K EY1 SH AH0 N Z ref: AA2 L T ER0 K EY1 SH AH0 N Z cer: 0.1000
# 209 overwhelming pred: OW1 V ER0 W AA1 L M IH0 NG ref: OW2 V ER0 W EH1 L M IH0 NG cer: 0.2222
# 210 enforces pred: EH1 N F ER0 S EH2 S IH0 Z ref: EH0 N F AO1 R S IH0 Z cer: 0.5000
# 211 reportedly pred: R IH0 P AO1 R T IH0 D L IY0 ref: R IH0 P AO1 R T AH0 D L IY0 cer: 0.1000
# 212 tricentrol pred: T R IH1 S AH0 N T R AH0 L ref: T R AY2 S EH1 N T R AA0 L cer: 0.3000
# 213 pontifical pred: P AA2 N T AH0 F AH0 K AE1 L ref: P AA0 N T IH1 F AH0 K AH0 L cer: 0.3000
# 214 intermittent pred: IH2 N T ER0 M IH1 T AH0 N T ref: IH2 N T ER0 M IH1 T AH0 N T cer: 0.0000
# 215 reacquired pred: R IY0 AE1 K Y ER0 AY2 D ref: R IY0 AH0 K W AY1 R D cer: 0.5000
# 216 expropriated pred: IH0 K S P R AA1 P R IY0 EY2 T IH0 D ref: EH0 K S P R OW1 P R IY0 EY2 T IH0 D cer: 0.1538
# 217 autenrieth pred: AH0 T EH1 R AH0 T ref: AW1 T IH0 N R IY0 IH0 TH cer: 0.7500
# 218 donaldson's pred: D AA1 N AH0 L D S AH0 N Z ref: D AA1 N AH0 L D S AH0 N Z cer: 0.0000
# 219 amputate pred: AH0 M P AH1 T AH0 T ref: AE1 M P Y AH0 T EY2 T cer: 0.5000
# 220 bankcards pred: B AE1 NG K AH0 R D Z D Z ref: B AE1 NG K AA2 R D Z cer: 0.3750
# 221 taliban's pred: T AE1 L AH0 B AH0 N Z ref: T AE1 L IH0 B AE2 N Z cer: 0.2500
# 222 overreacts pred: OW1 V ER0 R IY2 K T S ref: OW1 V ER0 R IY0 AE1 K T S cer: 0.2222
# 223 neutralizing pred: N UW0 T R AE1 L IH0 Z IH0 NG ref: N UW1 T R AH0 L AY2 Z IH0 NG cer: 0.3000
# 224 bighorns pred: B Y UW1 HH ER0 N Z ref: B IH1 G HH AO2 R N Z cer: 0.5000
# 225 marianas pred: M AA0 R IY0 AE1 N AH0 S ref: M EH2 R IY0 AE1 N AH0 S cer: 0.1250
# 226 obsessions pred: OW1 B S AH0 S AY2 N Z ref: AH0 B S EH1 SH AH0 N Z cer: 0.5000
# 227 chujitsuya pred: CH UW0 JH AH0 T S UW1 SH AH0 ref: CH UW2 JH IY0 T S UW2 Y AA0 cer: 0.5556
# 228 astronautical pred: AE2 S T R AH0 N AA1 T IH0 K AH0 L ref: AE2 S T R AH0 N AA1 T IH0 K AH0 L cer: 0.0000
# 229 wranglings pred: W AO1 NG K L IH0 NG Z ref: R AE1 NG G AH0 L IH0 NG Z cer: 0.4444
# 230 catacosinos pred: K AE2 T AH0 K AA1 S AH0 N OW0 Z ref: K AH0 T AE2 K AH0 S IY1 N OW0 S cer: 0.4545
# 231 counteroffers pred: K AW1 N T ER0 OW2 F S ER0 Z ref: K AW1 N T ER0 AO2 F ER0 Z cer: 0.2222
# 232 indigenous pred: IH2 N D IH0 JH EH1 N AH0 S ref: IH2 N D IH1 JH AH0 N AH0 S cer: 0.2222
# 233 muhabara pred: M UW0 HH AH0 B AA1 R AH0 ref: M UW2 HH AH0 B AA1 R AH0 cer: 0.1250
# 234 disinfection pred: D IH0 S IH0 N F EH1 K SH AH0 N ref: D IH0 S IH0 N F EH1 K SH AH0 N cer: 0.0000
# 235 interlinked pred: IH2 N T ER0 L IH1 NG K D ref: IH2 N T ER0 L IH1 NG K T cer: 0.1111
# 236 extensions pred: IH0 K S T EH1 N SH AH0 N Z ref: IH0 K S T EH1 N SH AH0 N Z cer: 0.0000
# 237 adjectives pred: AH0 D IH0 K T IH1 V Z IH0 Z ref: AE1 JH IH0 K T IH0 V Z cer: 0.6250
# 238 yoshimoto pred: Y OW2 SH AH0 M AA1 T OW0 ref: Y OW0 SH IY0 M OW1 T OW0 cer: 0.3750
# 239 instructions pred: IH2 N S T R AH1 K SH AH0 N Z ref: IH2 N S T R AH1 K SH AH0 N Z cer: 0.0000
# 240 kaffenberger pred: K AE1 F AH0 N B ER0 G ER0 ref: K AE1 F AH0 N B ER0 G ER0 cer: 0.0000
# 241 superheroes pred: S UW2 P ER0 HH EH1 R OW0 Z ref: S UW2 P ER0 HH IY1 R OW0 Z cer: 0.1111
# 242 wenceslaus pred: W EH1 N S AH0 L AE2 S ref: W EH1 N S AH0 S L AO2 S cer: 0.2222
# 243 harmoniously pred: HH AA2 R M AH0 N Y UW1 S AH0 L IY0 ref: HH AA0 R M OW1 N IY0 AH0 S L IY0 cer: 0.4545
# 244 one-sided pred: OW1 N AH0 S IH1 D IH0 D ref: W AH2 N S AY1 D AH0 D cer: 0.6250
# 245 submarine's pred: S AH0 B M AA1 R AH0 N Z ref: S AH1 B M ER0 IY2 N Z cer: 0.5000
# 246 gantenbein pred: G AE1 N T AH0 N B IY2 N ref: G AE1 N T IH0 N B AY0 N cer: 0.2222
# 247 diagnostics pred: D AY2 AH0 N AA1 S T IH0 K S ref: D AY2 AH0 G N AA1 S T IH0 K S cer: 0.0909
# 248 resembles pred: R EH1 Z AH0 M B AH0 L Z ref: R IH0 Z EH1 M B AH0 L Z cer: 0.2222
# 249 kafelnikov pred: K AE1 F AH0 L N IH0 K OW0 V ref: K AH0 F EH1 L N IH0 K AO2 F cer: 0.4000
# 250 infirmity pred: IH2 N F IH1 M AH0 L AY2 T IY0 ref: IH0 N F ER1 M IH0 T IY0 cer: 0.6250
# 251 mouthparts pred: M AH1 DH P ER0 T S ref: M AW1 TH P AA2 R T S cer: 0.5000
# 252 manderscheid pred: G AE1 N D ER0 SH IH0 D ref: M AE1 N D ER0 SH AY2 D cer: 0.2500
# 253 conference pred: K AH0 N F EH1 R AH0 N S ref: K AA1 N F ER0 AH0 N S cer: 0.3750
# 254 grunewald pred: G R AH1 N AH0 W AO2 L D ref: G R AH1 N IH0 W AO0 L D cer: 0.2222
# 255 albritton pred: AE2 L B R IH1 T AH0 N ref: AE1 L B R IH0 T AA0 N cer: 0.3750
# 256 delafuente pred: D IH0 L AE1 F AH0 N T ref: D EY0 L AA0 F W EH1 N T EY0 cer: 0.5000
# 257 contadora pred: K AA2 N T AH0 D AO1 R AH0 ref: K AA2 N T AH0 D AO1 R AH0 cer: 0.0000
# 258 rekindle pred: R IY0 K IH1 N D L IY0 ref: R IY0 K IH1 N D AH0 L cer: 0.2500
# 259 unglamorous pred: AH1 N G L AH0 M AO2 R OW0 S ref: AH0 N G L AE1 M ER0 AH0 S cer: 0.5556
# 260 augustinians pred: AE2 G D AH0 S T IH1 N AH0 Z ref: AA2 G AH0 S T IH1 N IY0 AH0 N Z cer: 0.3636
# 261 electricals pred: IH0 L EH1 K T R IH0 K AH0 L Z ref: IH0 L EH1 K T R IH0 K AH0 L Z cer: 0.0000
# 262 hamtramck pred: HH AA1 M T R AE2 M ref: HH AE0 M T R AE1 M IH0 K cer: 0.4444
# 263 detoxification pred: D IH0 T OW0 K S IH1 F AH0 K EY2 SH AH0 N ref: D IH0 T AA2 K S IH0 F IH0 K EY1 SH AH0 N cer: 0.2857
# 264 misprints pred: M IH0 S P R IH1 N T S ref: M IH1 S P R IH1 N T S cer: 0.1111
# 265 expansive pred: IH0 K S P AE1 N IH0 V ref: IH0 K S P AE1 N S IH0 V cer: 0.1111
# 266 lithuania pred: L AH0 TH UW1 AH0 N IY0 AH0 ref: L IH2 TH AH0 W EY1 N IY0 AH0 cer: 0.4444
# 267 arianism pred: AA0 R IY0 AE1 N IH0 S M ref: AE1 R IY0 AH0 N IH2 Z AH0 M cer: 0.5556
# 268 dusenbery pred: D UW1 S AH0 N B ER0 IY0 ref: D AH0 S EH1 N B ER0 IY0 cer: 0.2500
# 269 lekachman pred: L EH1 K AH0 K AE2 N ref: L EH1 K AA2 K M AH0 N cer: 0.3750
# 270 militarists pred: M IH1 L AH0 T EH2 R IH0 S T S ref: M IH1 L AH0 T ER0 IH0 S T S cer: 0.2000
# 271 mothershead pred: M AO1 TH ER0 SH EY2 D ref: M AH1 DH ER0 Z HH EH2 D cer: 0.6250
# 272 nonfiction pred: N AA2 N F IH0 K AA1 N ref: N AA0 N F IH1 K SH AH0 N cer: 0.4444
# 273 irrational pred: IH2 R AH0 T IH1 N AH0 L ref: IH2 R AE1 SH AH0 N AH0 L cer: 0.3750
# 274 parachuting pred: P AA1 R AH0 K AH0 T IH0 NG ref: P EH1 R AH0 SH UW2 T IH0 NG cer: 0.3333
# 275 somaliland pred: S OW0 M AA0 L IY1 L AH0 N D ref: S AH0 M AA1 L IY0 L AE2 N D cer: 0.4000
# 276 graphically pred: G R AH0 F IH1 K AH0 L IY0 ref: G R AE1 F IH0 K L IY0 cer: 0.3750
# 277 pendergast pred: P EH1 N D ER0 G AH0 S T ref: P EH1 N D ER0 G AE2 S T cer: 0.1111
# 278 tousignant pred: T AW2 S IH1 G N AH0 N T ref: T UW1 S IH0 G N AH0 N T cer: 0.2222
# 279 himmelberger pred: HH IH1 M AH0 L B ER0 G ER0 ref: HH IH1 M AH0 L B ER0 G ER0 cer: 0.0000
# 280 analyzing pred: AE1 N AH0 L AY2 Z IH0 NG ref: AE1 N AH0 L AY2 Z IH0 NG cer: 0.0000
# 281 unashamedly pred: AE2 N AH0 SH EY1 M D L IY0 ref: AH2 N AH0 SH EY1 M AH0 D L IY0 cer: 0.2000
# 282 cyclamen pred: S IH1 K L AH0 M AH0 N ref: S AY1 K L AH0 M EH2 N cer: 0.2500
# 283 demodulates pred: D IH0 M OW1 D UW0 L EY2 T S ref: D IY2 M AA2 JH AH0 L EY1 T S cer: 0.5000
# 284 interoperates pred: IH2 N T ER0 AA1 P ER0 AH0 T S ref: IH2 N T ER0 AO1 P ER0 AH0 T S cer: 0.1000
# 285 handicapper pred: HH AE1 N D IH0 K AH0 P ER0 ref: HH AE1 N D IY0 K AE2 P ER0 cer: 0.2222
# 286 stuyvesant pred: S T UW1 V AH0 S AH0 N T ref: S T AY1 V AH0 S AH0 N T cer: 0.1111
# 287 mccleary's pred: M AH0 K L EH1 R IY0 Z ref: M AH0 K L IH1 R IY0 Z cer: 0.1250
# 288 proficiency pred: P R AH0 F IH1 SH AH0 N S IY0 ref: P R AH0 F IH1 SH AH0 N S IY0 cer: 0.0000
# 289 gift-horse pred: G IH1 CH F ER0 Z ref: G IH1 F T HH AO1 R S cer: 0.7500
# 290 horsemanship pred: HH AO2 R S AH0 M AE1 N SH IH0 P ref: HH AO1 R S M AH0 N SH IH0 P cer: 0.3000
# 291 protocols pred: P R AA1 T AH0 K OW2 L Z ref: P R OW1 T AH0 K AO2 L Z cer: 0.2222
# 292 templeton's pred: T EH1 M P L AH0 T AH0 N Z ref: T EH1 M P AH0 L T AH0 N Z cer: 0.2000
# 293 jonbenet's pred: JH AA1 N B AH0 N AH0 T S ref: JH AO1 N B AH0 N EY1 S cer: 0.3750
# 294 harbinger pred: HH AA1 R B IH0 NG ER0 IH0 NG ref: HH AA1 R B IH0 N JH ER0 cer: 0.5000
# 295 edification pred: EH2 D AH0 F AH0 K EY1 SH AH0 N ref: EH2 D AH0 F AH0 K EY1 SH AH0 N cer: 0.0000
# 296 cherrystones pred: K ER1 IH0 S T AH0 N Z ref: CH EH1 R IY0 S T OW2 N Z cer: 0.5556
# 297 overemphasizes pred: OW2 V ER0 EH1 M F AH0 S IH0 Z ref: OW1 V ER0 EH1 M F AH0 S AY2 Z IH0 Z cer: 0.2500
# 298 clydesdale pred: K L AY1 D S AH0 D AE2 L ref: K L AY1 D Z D EY2 L cer: 0.3750
# 299 goldmark pred: G OW1 L D M AA2 R K ref: G OW1 L D M AA2 R K cer: 0.0000
# 300 drinkwater pred: D R IH1 NG K W AH0 T ER0 ref: D R IH1 NG K W AO2 T ER0 cer: 0.1111
# 301 destructed pred: D IH0 S T R AH1 K T IH0 D ref: D IH0 S T R AH1 K T IH0 D cer: 0.0000
# 302 stockholdings pred: S T OW1 K HH OW2 L D IH0 NG Z ref: S T AA1 K HH OW2 L D IH0 NG Z cer: 0.0909
# 303 friendship pred: F R IY1 N D SH IH2 P ref: F R EH1 N D SH IH0 P cer: 0.2500
# 304 isolated pred: IH2 Z AH0 L EY1 T IH0 D ref: AY1 S AH0 L EY2 T AH0 D cer: 0.5000
# 305 konishiroku pred: K AH0 N IH0 SH IH1 R OW0 K ref: K AA2 N IH2 SH IH0 R OW1 K UW2 cer: 0.5000
# 306 arcement pred: AA1 R S AH0 M AH0 N T ref: AA0 R S EY1 M AH0 N T cer: 0.2500
# 307 crackpots pred: K R AE1 K P AH0 T S ref: K R AE1 K P AA2 T S cer: 0.1250
# 308 tapestry pred: T AE1 P AH0 S T R IY0 ref: T AE1 P AH0 S T R IY0 cer: 0.0000
# 309 krogstad pred: K R AA1 S T AE2 D ref: K R AA1 G S T AH0 D cer: 0.2500
# 310 peterson's pred: P EH1 T ER0 S AH0 N Z ref: P IY1 T ER0 S AH0 N Z cer: 0.1250
# 311 experimentally pred: EH2 K S P ER0 IH0 M EH1 N T AH0 L IY0 ref: IH0 K S P EH2 R AH0 M EH1 N T AH0 L IY0 cer: 0.2857
# 312 humbarger pred: HH Y UW1 M B EH2 R G ER0 ref: HH AH1 M B AA2 R G ER0 cer: 0.3750
# 313 ragavan's pred: R EY1 G AH0 V AH0 N Z ref: R AA1 G AH0 V AA2 N Z cer: 0.2500
# 314 dedicating pred: D IH0 D IH1 K AH0 T IH0 NG ref: D EH1 D IH0 K EY2 T IH0 NG cer: 0.3333
# 315 legislating pred: L IH0 JH IH1 L AH0 T IH0 NG ref: L EH1 JH IH0 S L EY2 T IH0 NG cer: 0.4000
# 316 participated pred: P AA1 R T IH0 S AH0 P EY2 T IH0 D ref: P AA0 R T IH1 S AH0 P EY2 T IH0 D cer: 0.1667
# 317 cassandras pred: K AE1 S AH0 N D R AE2 S ref: K AH0 S AE1 N D R AH0 S cer: 0.3333
# 318 mcmillon pred: M AH0 K M IH1 L AH0 N ref: M AH0 K M IH1 L AH0 N cer: 0.0000
# 319 ustrust pred: AH0 S T R AH1 S T ref: Y UW1 EH1 S T R AH1 S T cer: 0.3333
# 320 transnational pred: T R AE2 N Z N AA1 T IY0 AH0 L ref: T R AE0 N S N AE1 SH AH0 N AH0 L cer: 0.5000
# 321 mcingvale pred: M AH0 K IH1 N V AA0 L ref: M AE1 K IH0 NG V EY2 L cer: 0.5000
# 322 hornstein pred: HH AO1 R N S T IY2 N ref: HH AO1 R N S T AY2 N cer: 0.1250
# 323 rebounded pred: R IH0 B AW1 N D IH0 D ref: R IY0 B AW1 N D IH0 D cer: 0.1250
# 324 prosecuting pred: P R AH0 S EH1 K AH0 T IH0 NG ref: P R AA1 S IH0 K Y UW2 T IH0 NG cer: 0.3636
# 325 richmond's pred: R IH1 K M AH0 N D Z ref: R IH1 CH M AH0 N D Z cer: 0.1250
# 326 pentagons pred: P EH1 N T AH0 G AA2 N Z ref: P EH1 N T IH0 G AA2 N Z cer: 0.1111
# 327 cywinski pred: S AY2 IH2 N IH0 S K S IY0 ref: K IH0 V IH1 N S K IY0 cer: 0.7500
# 328 waldheim's pred: W AO1 L D HH IH2 M Z ref: W AO1 L D HH AY2 M Z cer: 0.1250
# 329 forfeiting pred: F AO1 F R IH0 T IH0 NG ref: F AO1 R F AH0 T IH0 NG cer: 0.3750
# 330 forgettable pred: F AO1 R G AH0 T AH0 B AH0 L ref: F AO0 R G EH1 T AH0 B AH0 L cer: 0.2000
# 331 interpreted pred: IH2 N T ER0 P R EH1 T IH0 D ref: IH2 N T ER1 P R AH0 T AH0 D cer: 0.3000
# 332 advisedly pred: AE1 D V IH0 S AH0 D L IY0 ref: AE0 D V AY1 Z AH0 D L IY0 cer: 0.3333
# 333 ukrainians pred: AA2 K R AH0 N IY0 AA1 N Z ref: Y UW0 K R EY1 N IY0 AH0 N Z cer: 0.4000
# 334 pornographic pred: P AO2 R N AH0 G R AE1 F IH0 K ref: P AO2 R N AH0 G R AE1 F IH0 K cer: 0.0000
# 335 cardiologist pred: K AA2 R D IY0 AA1 L AH0 JH IH0 S T ref: K AA2 R D IY0 AA1 L AH0 JH IH0 S T cer: 0.0000
# 336 mcelravy pred: M AH0 K EH1 L R AH0 V IY0 ref: M AE1 K AH0 L R EY2 V IY0 cer: 0.3333
# 337 bottenfield pred: B AA1 T AH0 N F IY2 L D ref: B AH0 T EH1 N F IY0 L D cer: 0.3333
# 338 allegis's pred: AE1 L AH0 JH IH0 Z IH0 Z ref: AE2 L EY1 JH IH0 S IH0 Z cer: 0.3750
# 339 omnibank pred: AH0 M IH1 N AH0 B AE2 NG K ref: AA1 M N IH0 B AE2 NG K cer: 0.3750
# 340 uncovering pred: Y UW1 N K AH0 V ER2 IH0 NG ref: AH0 N K AH1 V ER0 IH0 NG cer: 0.5000
# 341 humidity pred: HH Y UW0 M IH1 D AH0 T IY0 ref: HH Y UW0 M IH1 D AH0 T IY0 cer: 0.0000
# 342 newslink's pred: N UW0 S L IH1 N K S ref: N UW1 Z L IH0 NG K S cer: 0.5000
# 343 littlest pred: L IH1 T AH0 L S T ref: L IH1 T AH0 L AH0 S T cer: 0.1250
# 344 quantifying pred: K W AA1 N T IH0 V IH0 NG ref: K W AA1 N T IH0 F AY2 IH0 NG cer: 0.2000
# 345 thorniest pred: TH AO1 R N IY0 Z T ref: TH AO1 R N IY0 AH0 S T cer: 0.2500
# 346 lomonaco pred: L OW0 M OW0 N AA1 K OW0 ref: L OW0 M OW0 N AA1 K OW0 cer: 0.0000
# 347 spectrograph pred: S P EH1 K T R AH0 G R AE2 F ref: S P EH1 K T R AH0 G R AE2 F cer: 0.0000
# 348 nonvolatile pred: N AA0 N V AA1 L AH0 T IH0 L ref: N AA0 N V AA1 L AH0 T AH0 L cer: 0.1000
# 349 ljubljana pred: L UW0 B L AH1 S AH0 N ref: L Y UW1 B L Y AA0 N AH0 cer: 0.6667
# 350 likeliest pred: L IH1 K AH0 L AY2 S T ref: L AY1 K L IY0 AH0 S T cer: 0.5000
# 351 angleton pred: AE1 N G L AH0 T AH0 N ref: AE1 NG G AH0 L T AH0 N cer: 0.3750
# 352 polakowski pred: P AH0 L AE1 K AH0 F S K IY0 ref: P AH0 L AH0 K AO1 F S K IY0 cer: 0.2000
# 353 entomologist pred: EH2 N T AH0 M AA1 L AH0 JH IH0 S T ref: EH2 N T AH0 M AA1 L AH0 JH AH0 S T cer: 0.0833
# 354 longstreth pred: L AA1 NG G S T R AH0 TH ref: L AA1 NG S T R EH0 TH cer: 0.2500
# 355 steinbrink pred: S T AY1 N B R IH0 NG K ref: S T AY1 N B R IH2 NG K cer: 0.1111
# 356 mormonism pred: M AO1 R M AH0 N IH0 Z AH0 M ref: M AO1 R M AH0 N IH0 Z M cer: 0.1111
# 357 assailants pred: AE1 S AH0 L EY2 N T S ref: AH0 S EY1 L AH0 N T S cer: 0.3750
# 358 attributable pred: AE2 T R AH0 B UW1 T AH0 B AH0 L ref: AH0 T R IH1 B Y AH0 T AH0 B AH0 L cer: 0.3333
# 359 rotational pred: R OW0 T EY1 SH AH0 N AH0 L ref: R OW0 T EY1 SH AH0 N AH0 L cer: 0.0000
# 360 repetitious pred: R IH0 P EH1 T IH0 T IY0 Z ref: R EH2 P AH0 T IH1 SH AH0 S cer: 0.6667
# 361 hawkinson pred: HH AW1 K S AH0 N S AH0 N ref: HH AO1 K IH0 N S AH0 N cer: 0.3750
# 362 subordination pred: S AH0 B AA1 R D AH0 N EY2 SH AH0 N ref: S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.1667
# 363 transitory pred: T R AE0 N Z IH1 T ER0 IY0 ref: T R AE1 N Z AH0 T AO2 R IY0 cer: 0.4000
# 364 incomparable pred: IH2 N K AA1 M P R AH0 B AH0 L ref: IH2 N K AA1 M P ER0 AH0 B AH0 L cer: 0.0909
# 365 ferguson's pred: F ER1 G AH0 S AH0 N Z ref: F ER1 G AH0 S AH0 N Z cer: 0.0000
# 366 sandhogs pred: S AE1 N D HH AW0 G Z ref: S AE1 N D HH AO2 G Z cer: 0.1250
# 367 schoolgirls pred: SH OW1 L G IH0 L ER0 Z ref: S K UW1 L G ER2 L Z cer: 0.6250
# 368 metrically pred: M EH1 T R IH0 K AH0 L IY0 ref: M EH1 T R IH0 K AH0 L IY0 cer: 0.0000
# 369 castration pred: K AE2 S T R EY1 SH AH0 N ref: K AE2 S T R EY1 SH AH0 N cer: 0.0000
# 370 liberalism's pred: L IH1 B ER0 AH0 L IH2 Z AH0 M Z ref: L IH1 B ER2 AH0 L IH2 Z AH0 M Z cer: 0.0909
# 371 introduce pred: IH2 N T R AA1 D AH0 S ref: IH2 N T R AH0 D UW1 S cer: 0.2500
# 372 alleviating pred: AH0 L IY1 V AH0 T IH0 NG ref: AH0 L IY1 V IY0 EY2 T IH0 NG cer: 0.2222
# 373 refurbishment pred: R IH0 F ER1 B IH0 SH M AH0 N T ref: R IY0 F ER1 B IH0 SH M AH0 N T cer: 0.0909
# 374 closeted pred: K L OW1 S T IH0 D IH0 D ref: K L AA1 Z AH0 T IH0 D cer: 0.6250
# 375 linguists pred: L IH1 NG G Y AH0 S T S ref: L IH1 NG G W IH0 S T S cer: 0.2222
# 376 adoptions pred: AE2 D OW0 P T AW1 N Z ref: AH0 D AA1 P SH AH0 N Z cer: 0.5000
# 377 unadorned pred: Y UW1 N AH0 D AO2 R D ref: AH2 N AH0 D AO1 R N D cer: 0.5000
# 378 snowboards pred: S N OW1 B ER0 D Z ref: S N OW1 B AO2 R D Z cer: 0.2500
# 379 perquisite pred: P ER0 K W IH1 Z AH0 T ref: P ER1 K W AH0 Z IH0 T cer: 0.3750
# 380 transparently pred: T R AE0 N S P AA1 R AH0 N T L IY0 ref: T R AE0 N S P EH1 R AH0 N T L IY0 cer: 0.0769
# 381 cross-pollinate pred: K R AA2 S P AH0 L EY1 SH AH0 N AH0 T ref: K R AO1 S P AA2 L AH0 N EY2 T cer: 0.4545
# 382 children's pred: CH IH1 L D R AH0 N Z ref: CH IH1 L D R AH0 N Z cer: 0.0000
# 383 semolina pred: S EH2 M AH0 L IH1 N AH0 ref: S EH2 M AH0 L IY1 N AH0 cer: 0.1250
# 384 buthelezi pred: B AH1 TH AH0 L AY2 Z IY0 ref: B UW2 T AH0 L EY1 Z IY0 cer: 0.3750
# 385 sympathized pred: S IH1 M P AH0 TH AY2 Z D ref: S IH1 M P AH0 TH AY2 Z D cer: 0.0000
# 386 morganti pred: M AO0 R G AA1 N T IY0 ref: M AO0 R G AA1 N T IY0 cer: 0.0000
# 387 amalgams pred: AE1 M AH0 L G AE2 M Z ref: AH0 M AE1 L G AH0 M Z cer: 0.3750
# 388 loeffelholz pred: L OW1 F AH0 L HH OW2 L Z ref: L OW1 F IH0 L HH OW0 L Z cer: 0.2222
# 389 hallenbeck pred: HH AH0 L EH1 N B EH0 K ref: HH AO1 L AH0 N B EH2 K cer: 0.3750
# 390 agrivisor pred: AA1 G R IH0 V AY2 Z ER0 ref: AE1 G R AH0 V AY2 Z ER0 cer: 0.2500
# 391 montezuma pred: M OW0 N T EH1 Z AH0 M AH0 ref: M AA2 N T IH0 Z UW1 M AH0 cer: 0.3333
# 392 convention's pred: K AH0 N V EH1 N SH AH0 N Z ref: K AH0 N V EH1 N SH AH0 N Z cer: 0.0000
# 393 unjustified pred: Y UW1 N JH AH0 S T AY2 Z D ref: AH0 N JH AH1 S T AH0 F AY2 D cer: 0.6000
# 394 marketscope pred: M AA1 R K AH0 T S K OW2 P ref: M AA1 R K AH0 T S K OW2 P cer: 0.0000
# 395 interdigital pred: IH2 N T ER0 D IH1 JH AH0 T AH0 L ref: IH2 N T ER0 D IH1 JH AH0 T AH0 L cer: 0.0000
# 396 swartzentruber pred: S W AO1 R T S AH0 N T R UW0 B ER0 ref: S W AO1 R T S AH0 N T R UW0 B ER0 cer: 0.0000
# 397 incidents pred: IH2 N S IH1 D AH0 N T S ref: IH1 N S AH0 D AH0 N T S cer: 0.2222
# 398 non-proliferation pred: N AA2 N P R AH0 L IH1 F R AH0 N EY2 SH AH0 R AH0 N ref: N AA0 N P R AO0 L IH2 F ER0 EY1 SH AH0 N cer: 0.6429
# 399 gorczynski pred: G AO2 R CH IH0 N S K IY0 ref: G ER0 CH IH1 N S K IY0 cer: 0.3750
# 400 directorships pred: D ER0 EH1 K T ER0 SH IH2 P S ref: D ER0 EH1 K T ER0 SH IH2 P S cer: 0.0000
# 401 homeland's pred: HH AA1 M AH0 L AE2 N D Z ref: HH OW1 M L AE2 N D Z cer: 0.2500
# 402 mantione pred: M AE2 N T IY0 AA1 N IY0 ref: M AA0 N T IY0 OW1 N IY0 cer: 0.2500
# 403 companies's pred: K AH0 M P AE1 N IY0 Z IH0 Z ref: K AH1 M P AH0 N IY0 Z IH0 Z cer: 0.2000
# 404 quietness pred: K W IY1 T N AH0 S ref: K W AY1 AH0 T N AH0 S cer: 0.2500
# 405 distinctiveness pred: D IH0 S T IH1 N CH T IH0 V N AH0 S ref: D IH0 S T IH1 NG K T IH0 V N AH0 S cer: 0.1538
# 406 solidarity pred: S OW0 L IH0 D AA1 R AH0 T IY0 ref: S AA2 L AH0 D EH1 R AH0 T IY0 cer: 0.3000
# 407 stellmacher pred: S T EH1 L M EY2 K ER0 ref: S T EH1 L M AH0 K ER0 cer: 0.1250
# 408 milliseconds pred: M IH1 L AH0 S AH0 K N D Z ref: M IH1 L IH0 S EH2 K AH0 N D Z cer: 0.2727
# 409 parchment pred: P AA1 R K AH0 N T ref: P AA1 R CH M AH0 N T cer: 0.2500
# 410 schulenberg pred: SH AH0 L EH1 N B ER0 G ref: SH UW1 L AH0 N B ER0 G cer: 0.2500
# 411 facility pred: F AH0 S IH1 L AH0 T IY0 ref: F AH0 S IH1 L IH0 T IY0 cer: 0.1250
# 412 dyslexic pred: D IH0 S L EH1 K S IH0 K ref: D IH0 S L EH1 K S IH0 K cer: 0.0000
# 413 stadium's pred: S T EY1 D IY0 AH0 M Z ref: S T EY1 D IY0 AH0 M Z cer: 0.0000
# 414 beleaguering pred: B EH1 L AH0 G Y UW2 ER0 IH0 NG ref: B IH0 L IY1 G ER0 IH0 NG cer: 0.5000
# 415 investigation pred: IH2 N V AH0 S T IH1 G AH0 N EY2 SH AH0 N ref: IH2 N V EH2 S T AH0 G EY1 SH AH0 N cer: 0.4167
# 416 granada's pred: G R AE1 N AH0 D AH0 Z ref: G R AH0 N AA1 D AH0 Z cer: 0.2500
# 417 permeating pred: P EH1 R M AH0 T IH0 NG ref: P ER1 M IY0 EY2 T IH0 NG cer: 0.5000
# 418 discounters pred: D IH0 S K AW1 N T ER0 Z ref: D IH0 S K AW1 N T ER0 Z cer: 0.0000
# 419 whimsical pred: HH AY2 M S IH1 K AH0 L ref: W IH1 M Z IH0 K AH0 L cer: 0.5000
# 420 portraying pred: P AO1 R T R EY2 IH0 NG ref: P AO0 R T R EY1 IH0 NG cer: 0.2500
# 421 religione pred: R IH0 L IH1 JH AH0 N AH0 ref: R IH0 L IH2 JH IY0 OW1 N IY0 cer: 0.4444
# 422 verizons pred: V ER0 IH1 Z AH0 N Z ref: V EH2 R AY1 Z AH0 N Z cer: 0.3750
# 423 macedonian pred: M AE2 K AH0 D AA1 N IY0 AH0 N ref: M AE2 S AH0 D OW1 N Y AH0 N cer: 0.3000
# 424 afrocentric pred: AE2 F R OW0 S EH1 N T R IH0 K ref: AE1 F R OW0 S EH1 N T R IH0 K cer: 0.0909
# 425 self-governing pred: S EH1 L F G AO2 V ER0 N IH0 NG ref: S EH1 L F G AH1 V ER0 N IH0 NG cer: 0.0909
# 426 red-herrings pred: R IH0 D HH ER1 N IH0 NG Z ref: R EH1 D HH EH1 R IH0 NG Z cer: 0.3333
# 427 underscoring pred: AH1 N D ER0 S K AO2 R IH0 NG ref: AH2 N D ER0 S K AO1 R IH0 NG cer: 0.2000
# 428 mcgarrigle pred: M AH0 G AE1 R IH0 G AH0 L ref: M AH0 G AE1 R AH0 G AH0 L cer: 0.1111
# 429 globetrotter pred: G L AA1 B AH0 T R AA2 T ER0 ref: G L OW1 B T R AO0 T ER0 cer: 0.3333
# 430 melodious pred: M EH0 L AH0 D IY1 ZH AH0 Z ref: M AH0 L OW1 D IY0 AH0 S cer: 0.6250
# 431 westwards pred: W EH1 S T W AA2 R D Z ref: W EH1 S T W ER0 D Z cer: 0.2500
# 432 mutagens pred: M Y UW1 T AH0 JH AH0 N Z ref: M Y UW1 T AH0 JH EH0 N Z cer: 0.1111
# 433 shipbuilder pred: SH IH1 P B IH2 L D ER0 ref: SH IH1 P B IH2 L D ER0 cer: 0.0000
# 434 religiously pred: R IH0 L IH1 JH AH0 W AH0 S L IY0 ref: R IH0 L IH1 JH AH0 S L IY0 cer: 0.2222
# 435 exhaustive pred: IH0 G Z AH1 S T IH0 V ref: IH0 G Z AO1 S T IH0 V cer: 0.1250
# 436 accompanying pred: AH0 K AA1 M P AH0 N IH0 NG ref: AH0 K AH1 M P AH0 N IY0 IH0 NG cer: 0.2000
# 437 aramaic pred: AA2 R AH0 M EY1 IH0 K ref: AA2 R AA0 M EH1 Y IH0 K cer: 0.3750
# 438 collinson pred: K AH0 L IH1 N S AH0 N ref: K AA1 L IH0 N S AH0 N cer: 0.2500
# 439 disorders pred: D IH0 S AO1 R D ER0 Z ref: D IH0 S AO1 R D ER0 Z cer: 0.0000
# 440 seminoles pred: S EH1 M AH0 N AH0 L AH0 Z ref: S EH1 M IH0 N OW2 L Z cer: 0.3750
# 441 standalone pred: S T AE2 N D AH0 L AA1 N AH0 N ref: S T AE1 N D AH0 L OW2 N cer: 0.4444
# 442 negligence pred: N EH1 G L AH0 JH AH0 N S ref: N EH1 G L AH0 JH AH0 N S cer: 0.0000
# 443 fresenius pred: F R EH1 S AH0 N Y UW2 Z ref: F R AH0 S IY1 N IY0 AH0 S cer: 0.5556
# 444 speechwriters pred: S P IY1 CH R AY2 T ER0 Z ref: S P IY1 CH R AY2 T ER0 Z cer: 0.0000
# 445 persevering pred: P ER1 S IH0 V ER0 IH0 NG ref: P ER0 S AH0 V IH1 R IH0 NG cer: 0.4444
# 446 inflexibility pred: IH2 N F L IH0 K S IH0 B IH1 L IH0 T IY0 ref: IH2 N F L EH2 K S IH0 B IH1 L IH0 T IY0 cer: 0.0714
# 447 guantanamo pred: G W AA2 N T AE1 N AH0 M OW0 ref: G W AA2 N T AA1 N AH0 M OW2 cer: 0.2000
# 448 hardison pred: HH AA1 R D IH0 S AH0 N ref: HH AA1 R D IH0 S AH0 N cer: 0.0000
# 449 podcaster pred: P AA1 D K AE2 S T ER0 ref: P AO1 D K AE2 S T ER0 cer: 0.1250
# 450 dissipation pred: D IH0 S IH2 P AH0 T EY1 SH AH0 N ref: D IH2 S IH0 P EY1 SH AH0 N cer: 0.4444
# 451 josephine's pred: JH AA1 S AH0 F AY2 N Z ref: JH OW1 S AH0 F IY2 N Z cer: 0.2500
# 452 contemporaneous pred: K AA2 N T AH0 M P AO1 R AH0 N AH0 S ref: K AH0 N T EH2 M P ER0 EY1 N IY0 AH0 S cer: 0.4615
# 453 desensitize pred: D IH0 S EH1 N S AH0 T AY2 Z ref: D IH0 S EH1 N S AH0 T AY2 Z cer: 0.0000
# 454 presumptuous pred: P R IY0 S AH0 M T UW1 S ref: P R IH0 Z AH1 M P CH AH0 W AH0 S cer: 0.6667
# 455 lysistrata pred: L IH2 S IH0 S T R AE1 T AH0 ref: L AY2 S IH0 S T R AA1 T AH0 cer: 0.2000
# 456 jonassaint pred: JH OW2 N AH0 S EY1 N T ref: JH OW2 N AH0 S EY1 N T cer: 0.0000
# 457 desiderata pred: D IH0 S IH0 D EH1 R AH0 T AH0 ref: D EY2 Z IH0 D ER0 AA1 T AH0 cer: 0.5556
# 458 tapestries pred: T AE1 P AH0 S T R IY0 Z ref: T AE1 P AH0 S T R IY0 Z cer: 0.0000
# 459 templates pred: T EH1 M P L EY2 T S ref: T EH1 M P L AH0 T S cer: 0.1250
# 460 superlative pred: S UW2 P ER0 L EY1 SH AH0 V ref: S UH0 P ER1 L AH0 T IH0 V cer: 0.5556
# 461 deflection pred: D IH0 F L EH1 K SH AH0 N ref: D IH0 F L EH1 K SH AH0 N cer: 0.0000
# 462 excluding pred: IH0 K S K L UW1 D IH0 NG ref: IH0 K S K L UW1 D IH0 NG cer: 0.0000
# 463 trivialized pred: T R IH1 V AH0 L AY2 Z D ref: T R IH1 V IY0 AH0 L AY2 Z D cer: 0.1000
# 464 stanislav pred: S T AE1 N IH0 S L EY2 V ref: S T AE1 N IH0 S L AA0 V cer: 0.1111
# 465 vacuuming pred: V EY1 K W IH0 NG IH0 NG ref: V AE1 K Y UW0 M IH0 NG cer: 0.5000
# 466 recruitment pred: R IY0 K R IH1 T M AH0 N T ref: R AH0 K R UW1 T M AH0 N T cer: 0.2000
# 467 immiscible pred: IH2 M IH1 S IH0 B AH0 L ref: IH2 M IH1 S AH0 B AH0 L cer: 0.1250
# 468 overstaffed pred: OW1 V ER0 S T AE2 F T ref: OW1 V ER0 S T AE2 F T cer: 0.0000
# 469 cadences pred: K AE1 D AH0 N S IH0 Z ref: K EY1 D AH0 N S IH0 Z cer: 0.1250
# 470 blankinship pred: B L AE1 NG K IH0 N SH IH2 P ref: B L AE1 NG K IH0 N SH IH0 P cer: 0.1000
# 471 circulatory pred: S ER0 K Y AH0 L EY1 SH ER0 IY0 ref: S ER1 K Y AH0 L AH0 T AO2 R IY0 cer: 0.4545
# 472 congruent pred: K AH0 N G R UW1 AH0 N T ref: K AO1 N G R UW0 EH2 N T cer: 0.3333
# 473 gruenhagen pred: G R UW1 AH0 N HH IH0 JH AH0 N ref: G R UH1 N HH AH0 G AH0 N cer: 0.4444
# 474 vehicle's pred: V EH1 V IH0 K AH0 L Z ref: V IY1 HH IH0 K AH0 L Z cer: 0.2500
# 475 canonization pred: K AE2 N AH0 N AH0 Z EY1 SH AH0 N ref: K AE2 N AH0 N AH0 Z EY1 SH AH0 N cer: 0.0000
# 476 transcribed pred: T R AE0 N S K R AY1 B D ref: T R AE0 N S K R AY1 B D cer: 0.0000
# 477 graceland pred: G R AE1 S AH0 L AE2 N D ref: G R EY1 S L AE0 N D cer: 0.3750
# 478 apartment pred: AE1 P ER0 T M AH0 N T ref: AH0 P AA1 R T M AH0 N T cer: 0.3333
# 479 watermarks pred: W AO1 T ER0 M AA2 R K S ref: W AO1 T ER0 M AA2 R K S cer: 0.0000
# 480 surprising pred: S ER1 P R IH0 S IH0 NG ref: S ER0 P R AY1 Z IH0 NG cer: 0.3750
# 481 flagofficer pred: F L AH0 G AA1 F IH0 S ER0 ref: F L AE1 G AO0 F AH0 S ER0 cer: 0.3333
# 482 morihiro pred: M AO0 R IY0 HH IH1 R OW0 ref: M AO0 R IY0 HH IH1 R OW0 cer: 0.0000
# 483 daigrepont pred: D EY1 JH G R EH2 P AH0 N T ref: D EY1 G R IH0 P AA0 N T cer: 0.3333
# 484 granddaughter's pred: G R AE1 N D AH0 HH EY2 T ER0 Z ref: G R AE1 N D AO2 T ER0 Z cer: 0.3333
# 485 nobility pred: N OW0 B IH1 L AH0 T IY0 ref: N OW0 B IH1 L AH0 T IY0 cer: 0.0000
# 486 transits pred: T R AE0 N Z IH1 T S ref: T R AE1 N Z IH0 T S cer: 0.2500
# 487 infraction pred: IH2 N F R AE1 K SH AH0 N ref: IH2 N F R AE1 K SH AH0 N cer: 0.0000
# 488 amusingly pred: AH0 M Y UW1 Z IH0 NG L IY0 ref: AH0 M Y UW1 Z IH0 NG L IY0 cer: 0.0000
# 489 residency pred: R IH0 Z IH1 D AH0 N S IY0 ref: R EH1 Z IH0 D AH0 N S IY0 cer: 0.2222
# 490 nutcracker pred: N UW0 T K AH1 R AH0 S ER0 ref: N AH1 T K R AE2 K ER0 cer: 0.5000
# 491 biologically pred: B AY2 OW0 L AH0 JH IH1 K AH0 L IY0 ref: B AY0 AH0 L AA1 JH IH0 K L IY0 cer: 0.5000
# 492 scaleatron pred: S K AE1 L AH0 L EY2 R AH0 N ref: S K EY1 L IY0 AH0 T R AA0 N cer: 0.5000
# 493 byelorussia pred: B AY2 L AH0 R AH0 S IY1 AH0 ref: B AY2 AH0 L OW0 R AH1 SH AH0 cer: 0.5556
# 494 delbarco's pred: D IH0 L AE1 K AH0 R AE2 Z ref: D EH0 L B AA1 R K OW0 Z cer: 0.6667
# 495 tamburrino pred: T AA0 M B ER0 R IY1 N OW0 ref: T AA0 M B UH0 R IY1 N OW0 cer: 0.1111
# 496 landscaping pred: L AE1 N D S K EY2 P IH0 NG ref: L AE1 N D S K EY2 P IH0 NG cer: 0.0000
# 497 lowdermilk pred: L UW0 D ER1 M AH0 L K ref: L OW0 D ER1 M IH0 L K cer: 0.2500
# 498 amphitheaters pred: AE1 M F AH0 TH AH0 T ER0 Z ref: AE1 M F AH0 TH IY0 EY1 T ER0 Z cer: 0.2000
# 499 refrigerator pred: R IH0 F R IH1 JH ER0 EY2 T ER0 ref: R AH0 F R IH1 JH ER0 EY2 T ER0 cer: 0.1000
# 500 landmark pred: L AE1 N D M AA2 R K ref: L AE1 N D M AA2 R K cer: 0.0000
# 501 artichokes pred: AA1 R T IH0 K AO2 K S ref: AA1 R T IH0 CH OW2 K S cer: 0.2500
# 502 zamarripa pred: Z AA0 M AA0 R IH1 P AH0 ref: Z AA2 M AA0 R IY1 P AA0 cer: 0.3750
# 503 prospectus pred: P R AA1 S P AH0 K T ref: P R AH0 S P EH1 K T AH0 S cer: 0.4000
# 504 pagliuca's pred: P AH0 G IH1 L Y AH0 Z ref: P AE2 G L IY0 UW1 K AH0 Z cer: 0.5556
# 505 salveson pred: S AE1 L V IH0 S AH0 N ref: S AA0 L V EY1 S AH0 N cer: 0.2500
# 506 activism pred: AE1 K T AH0 V IH2 Z AH0 M ref: AE1 K T IH0 V IH2 Z AH0 M cer: 0.1111
# 507 galactose pred: G AE2 L AH0 K T OW1 Z ref: G AH0 L AE1 K T OW0 S cer: 0.5000
# 508 kurumizowa pred: K ER0 UW0 M AY2 Z AH0 ref: K UH2 R UW0 M IY0 Z OW1 AH0 cer: 0.4444
# 509 plumages pred: P L AH1 M AH0 JH IH0 Z ref: P L UW1 M AH0 JH AH0 Z cer: 0.2500
# 510 helmsburton pred: HH EH1 L M S B ER0 T AH0 N ref: HH EH1 L M Z B ER0 T AH0 N cer: 0.1000
# 511 longitudes pred: L AA1 NG G IH0 T UW0 D Z ref: L AA1 N JH AH0 T UW2 D Z cer: 0.4444
# 512 spelunked pred: S P EH1 L Y AH0 G D ref: S P AH0 L AH1 NG K T cer: 0.6250
# 513 poparelli pred: P AA2 P ER0 EH1 L Y IY0 ref: P OW2 P AH0 R EH1 L IY0 cer: 0.5000
# 514 newsmakers pred: N UW0 Z M AE1 K ER0 Z ref: N UW1 Z M EY2 K ER0 Z cer: 0.2500
# 515 eradication pred: EH2 R AH0 D IH1 K AH0 N ref: IH0 R AE2 D AH0 K EY1 SH AH0 N cer: 0.5000
# 516 qualifies pred: K W AA1 L IH0 F AY2 Z ref: K W AA1 L AH0 F AY2 Z cer: 0.1250
# 517 zuchowski pred: V AH0 HH AO1 F S K IY0 ref: Z AH0 HH AO1 F S K IY0 cer: 0.1250
# 518 nonaligned pred: N AA1 N AH0 L IH0 NG ref: N AA1 N AH0 L AY2 N D cer: 0.3750
# 519 childminder pred: CH IH1 L D M AY2 N D ER0 ref: CH AY1 L D M AY2 N D ER0 cer: 0.1111
# 520 diuretics pred: D UW0 R IH1 T IH0 K S ref: D AY2 UW0 R EH1 T IH0 K S cer: 0.2222
# 521 wagnerian pred: W AA2 G R AH0 N AA1 N ref: W AE2 G N EH1 R IY0 AH0 N cer: 0.6667
# 522 vanwieren pred: V AE1 N W IY0 ER0 AH0 N ref: V AE0 N W IH1 R AH0 N cer: 0.3750
# 523 savagery pred: S AE1 V AH0 G EH2 R IY0 ref: S AE1 V IH0 JH EH2 R IY0 cer: 0.2500
# 524 vartanian pred: V AA0 R T AA0 N IY1 AH0 N ref: V AA0 R T EY1 N IY0 AH0 N cer: 0.2222
# 525 religion's pred: R IH0 L IH1 JH AH0 N Z ref: R IH0 L IH1 JH AH0 N Z cer: 0.0000
# 526 sulfurophane pred: S AH2 L F ER0 AA1 F AH0 N ref: S AH1 L F ER0 AH0 F EY2 N cer: 0.3333
# 527 thomasina pred: T AA2 M AH0 S IH1 N AH0 ref: TH OW0 M AA0 S IY1 N AH0 cer: 0.5000
# 528 haakenson pred: HH AA1 K AH0 N S AH0 N ref: HH AA1 K IH0 N S AH0 N cer: 0.1250
# 529 jetliners pred: JH EH1 T L IH0 N ER0 Z ref: JH EH1 T L AY2 N ER0 Z cer: 0.1250
# 530 artifacts pred: AE1 R T AH0 F AE2 K T S ref: AA1 R T AH0 F AE2 K T S cer: 0.1111
# 531 unwieldiness pred: AH0 N W IY1 L D IH0 N Z ref: AH0 N W IY1 L D IY0 N AH0 S cer: 0.3000
# 532 delcastillo pred: D IH0 K S T S T IH1 L OW0 ref: D EH0 L K AA0 S T IH1 L OW0 cer: 0.4000
# 533 ruthenberg pred: R UW1 TH AH0 N B ER0 G ref: R AH1 TH AH0 N B ER0 G cer: 0.1250
# ...
# 4825 underemployment pred: AH0 N D ER1 AH0 P L M AH0 N T ref: AH2 N D ER0 IH0 M P L OY1 M AH0 N T cer: 0.3846
# 4826 abnormalities pred: AE2 B N ER0 AE1 L AH0 T IY0 Z ref: AE2 B N AO0 R M AE1 L AH0 T IY0 Z cer: 0.2500
# 4827 motorola's pred: M OW0 T AO0 R AA1 L AH0 Z ref: M OW2 T ER0 OW1 L AH0 Z cer: 0.5000
# 4828 freshwater pred: F R EH1 SH W EY2 T ER0 ref: F R EH1 SH W AO2 T ER0 cer: 0.1250
# 4829 bankowski pred: B AH0 NG K AO1 F S K IY0 ref: B AH0 NG K AO1 F S K IY0 cer: 0.0000
# 4830 disinform pred: D IH0 S IH1 N F ER0 M ref: D IH0 S IH0 N F AO1 R M cer: 0.3333
# 4831 decimals pred: D IH0 S IH1 M AH0 L Z ref: D EH1 S AH0 M AH0 L Z cer: 0.2500
# 4832 cellular's pred: S EH1 L Y AH0 L ER0 Z ref: S EH1 L Y AH0 L ER0 Z cer: 0.0000
# 4833 disclaimer pred: D IH0 S K L EY1 M ER0 ref: D IH0 S K L EY1 M ER0 cer: 0.0000
# 4834 requesting pred: R IH0 K W EH1 S T IH0 NG ref: R IH0 K W EH1 S T IH0 NG cer: 0.0000
# 4835 luncheonette pred: L AH1 N CH AH0 N AH0 T ref: L AH2 N CH IH0 N EH1 T cer: 0.3750
# 4836 eventful pred: EH0 V AH0 N T F AH1 L ref: IH0 V EH1 N T F AH0 L cer: 0.3750
# 4837 hallelujah pred: HH AH0 L EH1 L Y UW0 HH AA0 D ref: HH AE2 L AH0 L UW1 Y AH0 cer: 0.8750
# 4838 rostropovich pred: R OW0 S T R AA1 P AH0 V IH0 CH ref: R AO2 S T R AH0 P OW1 V IH0 CH cer: 0.2727
# 4839 hamanaka pred: HH AE2 M AH0 N AE1 K AH0 ref: HH AH0 M AH0 N AA1 K AH0 cer: 0.2500
# 4840 prillaman pred: P R IH1 L AH0 M AH0 N ref: P R IH1 L AH0 M AH0 N cer: 0.0000
# 4841 parliamentary pred: P AA0 R IY0 AA1 M AH0 N T R IY0 ref: P AA2 R L AH0 M EH1 N T ER0 IY0 cer: 0.4545
# 4842 wonderfulness pred: W AO1 N D ER0 F AH2 L N AH0 S ref: W AH1 N D ER0 F AH0 L N AH0 S cer: 0.1818
# 4843 thunderbolt pred: TH AH1 N D ER0 B OW2 L T ref: TH AH1 N D ER0 B AO2 L T cer: 0.1111
# 4844 diagnosed pred: D AY0 AA1 N AH0 S T ref: D AY2 AH0 G N OW1 S T cer: 0.5000
# 4845 flavorings pred: F L AA1 V ER0 IH0 NG Z ref: F L EY1 V ER0 IH0 NG Z cer: 0.1250
# 4846 boguslavskaya pred: B AH0 JH AH0 S L AA1 V S K AH0 ref: B OW0 G AH2 S L AH0 V S K AY1 AH0 cer: 0.4167
# 4847 iconography pred: IH2 K AH0 N G AA1 R AH0 F IY0 ref: AY2 K AH0 N AA1 G R AH0 F IY0 cer: 0.3000
# 4848 milkovich pred: M IH1 L K AH0 V IH0 CH ref: M IH1 L K AH0 V IH0 CH cer: 0.0000
# 4849 giroldi's pred: JH ER1 AH0 L D IY0 Z ref: G IH0 R OW1 L D IY0 Z cer: 0.5000
# 4850 hershkowitz pred: HH ER0 SH HH AO1 F T ref: HH ER1 SH K AH0 W IH0 T S cer: 0.6667
# 4851 clarifications pred: K L EH2 R AH0 F AH0 K EY1 SH AH0 N Z ref: K L EH2 R IH0 F IH0 K EY1 SH AH0 N Z cer: 0.1538
# 4852 handholding pred: HH AE1 N D HH OW2 L D IH0 NG ref: HH AE1 N D HH OW2 L D IH0 NG cer: 0.0000
# 4853 picaresque pred: P IH1 K AH0 R EH2 S K ref: P IH2 K AH0 R EH1 S K cer: 0.2500
# 4854 confirmation pred: K AA2 N F AH0 L AA1 T IY0 AH0 N ref: K AA2 N F ER0 M EY1 SH AH0 N cer: 0.5000
# 4855 institutionalized pred: IH2 N S T IH1 T AH0 N AH0 T IH0 Z ref: IH2 N S T IH0 T UW1 SH AH0 N AH0 L AY2 Z D cer: 0.4000
# 4856 espinoza pred: Z EH2 P IH0 N OW1 Z AH0 ref: EY0 S P IY0 N OW1 Z AH0 cer: 0.3750
# 4857 lufthansa pred: L UW0 T F AE1 N S AH0 ref: L AH0 F T AE1 N Z AH0 cer: 0.5000
# 4858 stepdaughters pred: S T EH1 P D AH0 T ER0 Z ER0 Z ref: S T EH1 P D AO2 T ER0 Z cer: 0.3333
# 4859 grandfield pred: G R AE1 N D F IY2 L D ref: G R AE1 N D F IY2 L D cer: 0.0000
# 4860 pleasants pred: P L IY1 Z AH0 N T S ref: P L EH1 Z AH0 N T S cer: 0.1250
# 4861 sandbox pred: S AE1 N D B AO2 K S ref: S AE1 N D B AA2 K S cer: 0.1250
# 4862 dimorphic pred: D IH0 M AO1 R F IH0 K ref: D AY0 M AO1 R F IH0 K cer: 0.1250
# 4863 restaino pred: R IH0 S T EY1 N OW0 ref: R EH0 S T AA0 IY1 N OW0 cer: 0.3750
# 4864 steffensmeier pred: S T EH1 F AH0 N Z M IH2 R ref: S T EH1 F IH0 N S M AY0 ER0 cer: 0.4000
# 4865 gencarelli pred: G IH0 N K AA1 R AH0 L IY0 ref: JH EH0 N K AA0 R EH1 L IY0 cer: 0.4444
# 4866 memorialized pred: M EH1 M ER0 AH0 L AY2 Z D ref: M AH0 M AO1 R IY0 AH0 L AY2 Z D cer: 0.3636
# 4867 pharmacia pred: F AA0 R M AE1 SH IY0 AH0 ref: F AA0 R M EY1 S IY0 AH0 cer: 0.2500
# 4868 assuredly pred: AE1 S ER0 AH0 D L IY0 ref: AH0 SH UH1 R AH0 D L IY0 cer: 0.5000
# 4869 tempelsman pred: T EH1 M P AH0 L Z M AH0 N ref: T EH1 M P AH0 L Z M AH0 N cer: 0.0000
# 4870 quartets pred: K W AO1 R T AH0 T S ref: K W AO0 R T EH1 T S cer: 0.2500
# 4871 cartland pred: K AA1 R T L AE2 N D ref: K AA1 R T L AH0 N D cer: 0.1250
# 4872 sprogus's pred: S P R AA1 G Y AH0 S IH0 Z ref: S P R OW1 G AH0 S IH0 Z cer: 0.2222
# 4873 introduction pred: IH2 N T R AH0 D UW1 S CH AH0 N ref: IH2 N T R AH0 D AH1 K SH AH0 N cer: 0.2727
# 4874 carberry's pred: K AA1 R B ER0 R IY0 Z ref: K AA1 R B EH2 R IY0 Z cer: 0.1250
# 4875 horticulture pred: HH AO2 R T IH0 K Y UW1 L T ER0 ref: HH AO1 R T IH0 K AH2 L CH ER0 cer: 0.4000
# 4876 reforestation pred: R IH0 F AO1 R AH0 S T EY2 SH AH0 N ref: R IY2 F AO0 R AH0 S T EY1 SH AH0 N cer: 0.2500
# 4877 stivoric pred: S T Y UW0 V AO1 R IH0 K ref: S T IH0 V AO1 R IH0 K cer: 0.2500
# 4878 addidases pred: AE1 D D AH0 D AE2 S IH0 Z ref: AH0 D IY1 D AH0 S IH0 Z cer: 0.5000
# 4879 proponent pred: P R AA1 P AH0 N AH0 N T ref: P R AH0 P OW1 N AH0 N T cer: 0.2222
# 4880 obligations pred: AA2 B L IH0 G EY1 SH AH0 N Z ref: AA2 B L AH0 G EY1 SH AH0 N Z cer: 0.1000
# 4881 medtronic pred: M EH1 D T R AH0 N IH0 K ref: M EH0 D T R AA1 N IH0 K cer: 0.2222
# 4882 filippello pred: F IH2 L IH0 P EH1 L OW0 ref: F IY2 L IH0 P EH1 L OW0 cer: 0.1250
# 4883 papier-mache pred: P EY1 P ER0 AH0 M AE2 K ref: P EY1 P ER0 M AH0 SH EY1 cer: 0.5000
# 4884 lionheart pred: L IY0 AA1 N HH AA2 R T ref: L AY1 AH0 N HH AA2 R T cer: 0.2500
# 4885 ferromagnetism pred: F EH2 R AH0 M AH0 G N EH1 T IH0 Z M ref: F EH2 R OW0 M AE1 G N AH0 T IH2 Z AH0 M cer: 0.3571
# 4886 bilingual pred: B IH1 L IH0 NG G W AH0 L ref: B AY0 L IH1 NG G W AH0 L cer: 0.2222
# 4887 thunderstorm pred: TH AH1 N D ER0 S T AO0 R M ref: TH AH1 N D ER0 S T AO2 R M cer: 0.1000
# 4888 hollenbach pred: HH OW1 L AH0 N B AE2 K ref: HH AA1 L IH0 N B AA0 K cer: 0.3750
# 4889 overfunded pred: OW1 V ER0 F AH0 N D IH0 D ref: OW1 V ER0 F AH2 N D IH0 D cer: 0.1111
# 4890 skenandore pred: S K EH1 N AH0 N D AO2 R ref: S K IH0 N AE1 N D ER0 cer: 0.5000
# 4891 burgundy's pred: B ER1 G AH0 N D IY0 Z ref: B ER1 G AH0 N D IY0 Z cer: 0.0000
# 4892 dressmaking pred: D R EH1 S M AE2 K IH0 NG ref: D R EH1 S M EY2 K IH0 NG cer: 0.1111
# 4893 polysaccharide pred: P AA2 L IY2 S AA1 K SH IH0 D ref: P AA2 L IY2 S AE1 K ER0 AY2 D cer: 0.3000
# 4894 irrevocably pred: IH2 R EH1 V AH0 K AH0 B L IY0 ref: IH2 R EH1 V AH0 K AH0 B L IY0 cer: 0.0000
# 4895 arianespace pred: AE2 R AH0 S EH1 N S AH0 K ref: EH2 R IY0 AE1 N S P EY1 S cer: 0.7778
# 4896 unconstitutionally pred: AH2 N K AH0 N S T IH1 SH AH0 N AH0 L AY2 AH0 T IY0 ref: AH2 N K AA2 N S T AH0 T UW1 SH AH0 N AH0 L IY0 cer: 0.4375
# 4897 americorps pred: AA1 M ER0 IH0 K R P R OW2 Z ref: AH0 M EH1 R IH0 K AO2 R cer: 0.8750
# 4898 wannemacher pred: W AO1 N AH0 M AH0 K ER0 ref: W AA1 N AH0 M AA0 K ER0 cer: 0.2500
# 4899 comprising pred: K AH0 M P R IH1 Z IH0 NG ref: K AH0 M P R AY1 Z IH0 NG cer: 0.1111
# 4900 almendarez pred: AE2 L M AH0 N D EH1 R Z ref: AA0 L M EY0 N D AA1 R EH0 Z cer: 0.4000
# 4901 january pred: JH AA0 N Y UW0 AA1 R IY0 ref: JH AE1 N Y UW0 EH2 R IY0 cer: 0.2500
# 4902 revolvers pred: R IY0 V OW1 L V ER0 Z ref: R IH0 V AA1 L V ER0 Z cer: 0.2500
# 4903 islamabad's pred: AE2 S L AH0 M AE1 B AH0 D Z ref: IH2 S L AE1 M AH0 B AE0 D Z cer: 0.4000
# 4904 universities' pred: Y UW2 N IH0 V ER1 S AH0 T IY0 Z ref: Y UW2 N IH0 V ER1 S IH0 T IY0 Z cer: 0.0909
# 4905 detriment pred: D IH0 T R IH1 M AH0 N T ref: D EH1 T R AH0 M AH0 N T cer: 0.2222
# 4906 conducted pred: K AH0 N D AH1 K T AH0 D ref: K AH0 N D AH1 K T AH0 D cer: 0.0000
# 4907 minisupercomputer pred: P IH2 N IH0 S UW1 P ER0 K AH0 M ref: M IH2 N IY0 S UW1 P ER0 K AH2 M P Y UW2 T ER0 cer: 0.5000
# 4908 graziano pred: G R AH0 Z AY2 AA1 N OW0 ref: G R AA0 T S IY0 AA1 N OW0 cer: 0.4444
# 4909 decommissioning pred: D IH0 K AH0 M IH1 SH AH0 N IH0 NG ref: D IY0 K AH0 M IH1 SH AH0 N IH0 NG cer: 0.0909
# 4910 padmanabhan pred: M AA0 D M AE1 N AH0 HH AE2 N ref: P AE0 D M AE1 N AH0 B AE2 N cer: 0.3000
# 4911 americare pred: AA1 M ER0 IH0 K AA2 R ref: AH0 M EH1 R IH0 K EH2 R cer: 0.5000
# 4912 monteverde pred: M AA1 N T AH0 V ER2 D ref: M OW0 N T EH0 V EH1 R D IY0 cer: 0.5000
# 4913 estimating pred: IH0 S T IH1 M AH0 T IH0 NG ref: EH1 S T AH0 M EY2 T IH0 NG cer: 0.3333
# 4914 bollettieri pred: B OW0 L EH1 T AH0 Y ER0 IY0 ref: B AH0 L EH2 T IY0 EH1 R IY0 cer: 0.5556
# 4915 textbooks pred: T EH1 K S T B UH2 K S ref: T EH1 K S T B UH2 K S cer: 0.0000
# 4916 mischievous pred: M IH0 S K IY1 V OW0 S ref: M IH1 S CH AH0 V AH0 S cer: 0.5000
# 4917 vanblaricom pred: V AE2 N B L AA1 R IH0 K OW0 M ref: V AE2 N B L AE1 R IH0 K AH0 M cer: 0.1818
# 4918 carbonized pred: K AA1 R B AH0 N AY2 Z D ref: K AA1 R B AH0 N AY2 Z D cer: 0.0000
# 4919 deforest pred: D IH0 F AO1 R AH0 S T ref: D IH0 F AO1 R AH0 S T cer: 0.0000
# 4920 feedstocks pred: F EH1 D S T OW2 K S ref: F IY1 D S T AA2 K S cer: 0.2500
# 4921 undernourished pred: AH1 N D ER0 N AW2 D IH0 SH ref: AH2 N D ER0 N ER1 IH0 SH T cer: 0.4444
# 4922 exonerated pred: EH1 K S AH0 N EH2 R AH0 D ref: IH0 G Z AA1 N ER0 EY2 T IH0 D cer: 0.8000
# 4923 vagabonds pred: V EY1 G AH0 B AA0 N D Z ref: V AE1 G AH0 B AA0 N D Z cer: 0.1111
# 4924 itinerant pred: IH2 T IH1 N ER0 AH0 N T ref: AY0 T IH1 N ER0 AH0 N T cer: 0.1250
# 4925 mcevilly pred: M AH0 K EH1 V AH0 L IY0 ref: M AH0 K EH1 V AH0 L IY0 cer: 0.0000
# 4926 copperfields' pred: K AA1 P ER0 F IY2 L D Z ref: K AA1 P ER0 F IY2 L D Z cer: 0.0000
# 4927 cleaveland pred: K L EH1 AH0 V AH0 L D AH0 N D ref: K L IY1 V L AH0 N D cer: 0.5000
# 4928 telescopic pred: T EH2 L AH0 S K AA1 P IH0 K ref: T EH2 L AH0 S K AO1 P IH0 K cer: 0.1000
# 4929 beverages pred: B EH1 V ER0 AH0 JH IH0 Z ref: B EH1 V R IH0 JH IH0 Z cer: 0.2500
# 4930 telesciences pred: T EH1 L AH0 S K IY2 N S IH0 Z ref: T EH1 L AH0 S AY2 AH0 N S IH0 Z cer: 0.1818
# 4931 islamist pred: IH2 S L AE1 M IH0 S T ref: IH1 S L AH0 M IH0 S T cer: 0.2500
# 4932 ornamented pred: AO2 R N AH0 M EH1 N T IH0 D ref: AO1 R N AH0 M EH2 N T IH0 D cer: 0.2000
# 4933 aganbegyan pred: AE2 G AH0 N B IY1 M AH0 N ref: AE2 G AH0 N B EH1 G Y AH0 N cer: 0.3000
# 4934 ferryboats pred: F EH1 R IY0 B OW2 T S ref: F EH1 R IY0 B OW2 T S cer: 0.0000
# 4935 disapprove pred: D IH0 S AA1 P R OW0 V ref: D IH2 S AH0 P R UW1 V cer: 0.3750
# 4936 uniondale pred: Y UW1 N Y AH0 N D AE2 L ref: Y UW1 N Y AH0 N D EY2 L cer: 0.1111
# 4937 accessibility pred: AH0 K S IH0 S IH1 B AH0 L IH0 T IY0 ref: AE2 K S EH0 S AH0 B IH1 L IH0 T IY0 cer: 0.3333
# 4938 nawrocki pred: N AA0 R OW0 K IH1 T IY0 ref: N AA0 V R OW1 T S K IY0 cer: 0.5556
# 4939 competitors pred: K AH0 M P EH1 T AH0 T ER0 Z ref: K AH0 M P EH1 T AH0 T ER0 Z cer: 0.0000
# 4940 kendavis pred: K AH0 N D EY1 V IH0 S ref: K EH1 N D EY1 V IH0 S cer: 0.1250
# 4941 dockendorf pred: D AA1 K AH0 N D AO2 R F ref: D AA1 K IH0 N D AO0 R F cer: 0.2222
# 4942 redecorated pred: R IH0 D EH1 K ER0 EY2 T IH0 D ref: R IY0 D EH1 K ER0 EY2 T IH0 D cer: 0.1000
# 4943 prototypes pred: P R AA1 T AH0 T AY2 P S ref: P R OW1 T AH0 T AY2 P S cer: 0.1111
# 4944 first-class pred: S ER1 S T K S L AE2 S ref: F ER2 S T K L AE1 S cer: 0.5000
# 4945 insemination pred: IH2 N S AH0 M IH1 N AH0 T IY0 AH0 N ref: IH2 N S EH2 M AH0 N EY1 SH AH0 N cer: 0.4545
# 4946 cara'veras pred: K AA0 R AA0 M V EH1 R AH0 Z ref: K AA2 R AH0 V EH1 R AH0 Z cer: 0.3333
# 4947 excepting pred: IH0 K S EH1 P AH0 N T IH0 NG ref: EH2 K S EH1 P T IH0 NG cer: 0.3750
# 4948 coventry pred: K AH0 V EH1 N T R IY0 ref: K AH1 V AH0 N T R IY0 cer: 0.2500
# 4949 unmistakably pred: AH0 N M IH1 S T AH0 K AH0 L IY0 ref: AH2 N M IH0 S T EY1 K AH0 B L IY0 cer: 0.3333
# 4950 geometrically pred: JH IY2 AH0 M EH1 T R AH0 K AH0 L IY0 ref: JH IY2 AH0 M EH1 T R IH0 K L IY0 cer: 0.1818
# 4951 pediatricians pred: P EH2 D AH0 EY1 T R IY0 AH0 Z ref: P IY2 D IY0 AH0 T R IH1 SH AH0 N Z cer: 0.5000
# 4952 stability pred: S T EY1 B AH0 L IH0 T IY0 ref: S T AH0 B IH1 L IH0 T IY0 cer: 0.2222
# 4953 headrests pred: HH EH1 D R AH0 S T S ref: HH EH1 D R EH2 S T S cer: 0.1250
# 4954 overuses pred: OW1 V ER0 AH0 S AH0 Z ref: OW2 V ER0 Y UW1 Z IH0 Z cer: 0.6250
# 4955 finstrom pred: F IH1 N S T R AH0 M ref: F IH1 N S T R AH0 M cer: 0.0000
# 4956 lindstrand pred: L IH1 N D S T R AE2 N D ref: L IH1 N D S T R AH0 N D cer: 0.1000
# 4957 intently pred: IH2 N T EH1 N T L IY0 ref: IH2 N T EH1 N T L IY0 cer: 0.0000
# 4958 francisco's pred: F R AE2 N S AH0 S K OW1 Z OW0 Z ref: F R AE0 N S IH1 S K OW0 Z cer: 0.4000
# 4959 angelino pred: AE2 N JH AH0 L IH1 N OW0 ref: AE2 N JH AH0 L IY1 N OW0 cer: 0.1250
# 4960 dobrynin pred: D AA1 B R IY0 N IH0 N ref: D AA1 B R IH0 N IH0 N cer: 0.1250
# 4961 bankable pred: B AE1 NG K AH0 B AH0 L ref: B AE1 NG K AH0 B AH0 L cer: 0.0000
# 4962 cypriots pred: S IH1 P R IY0 OW0 T S ref: S IH1 P R IY0 AH0 T S cer: 0.1250
# 4963 extracted pred: IH0 K S T R AE1 K T IH0 D ref: EH0 K S T R AE1 K T IH0 D cer: 0.1000
# 4964 definable pred: D IH0 F IH1 N AH0 B AH0 L ref: D IH0 F AY1 N AH0 B AH0 L cer: 0.1111
# 4965 aluminum pred: AH0 L UW1 M AH0 N AH0 M ref: AH0 L UW1 M AH0 N AH0 M cer: 0.0000
# 4966 misconstrue pred: M IH0 S K AA1 N S T R UW0 ref: M IH0 S K AH0 N S T R UW1 cer: 0.2000
# 4967 embellishes pred: IH0 M B EH1 L IH0 SH IH0 Z ref: EH0 M B EH1 L IH0 SH AH0 Z cer: 0.2222
# 4968 westchester's pred: W EH1 S T HH EH2 S T ER0 Z ref: W EH1 S T CH EH2 S T ER0 Z cer: 0.1000
# 4969 unsatisfied pred: AH0 N S AE1 T IH0 SH IH0 D ref: AH0 N S AE1 T IH0 S F AY2 D cer: 0.3000
# 4970 surmounted pred: S ER1 M AH0 N T IH0 D ref: S ER0 M AW1 N T IH0 D cer: 0.2500
# 4971 fredericksen pred: F R EH1 D ER0 IH0 S K AH0 N ref: F R EH1 D ER0 IH0 K S AH0 N cer: 0.2000
# 4972 raudenbush pred: R AW1 D AH0 N B IH0 SH ref: R AW1 D IH0 N B UH0 SH cer: 0.2500
# 4973 disequilibrium pred: D IH0 S EH2 K W AH0 L IH1 M B ER0 ref: D IH0 S IY2 K W AH0 L IH1 B R IY0 AH0 M cer: 0.4286
# 4974 staffordshire's pred: S T AE1 F AH0 R D SH ER0 Z ref: S T AE1 F ER0 D SH ER0 Z cer: 0.2222
# 4975 hospices pred: HH AA1 S P IH0 S IH0 Z ref: HH AA1 S P AH0 S IH0 Z cer: 0.1250
# 4976 mcmasters pred: M AH0 K M AE1 S T ER0 Z ref: M AH0 K M AE1 S T ER0 Z cer: 0.0000
# 4977 albumin pred: AH0 L B AE1 M AH0 N ref: AE0 L B Y UW1 M AH0 N cer: 0.3750
# 4978 revelation pred: R IY0 V EH1 L AH0 SH AH0 N ref: R EH2 V AH0 L EY1 SH AH0 N cer: 0.3333
# 4979 poinsettias pred: P IY0 AH0 N S EH1 T IY0 Z ref: P OY2 N S EH1 T IY2 AH0 Z cer: 0.4444
# 4980 controlling pred: K AH0 N T R AA1 L IH0 NG ref: K AH0 N T R OW1 L IH0 NG cer: 0.1111
# 4981 laboratory's pred: L AA0 B ER0 AA1 T ER0 IY0 Z ref: L AE1 B R AH0 T AO2 R IY0 Z cer: 0.5000
# 4982 bensinger pred: B EH1 N Z IH0 N JH ER0 ref: B EH1 N S IH0 N JH ER0 cer: 0.1250
# 4983 interstitial pred: IH2 N T ER0 S T IH1 T IY0 AH0 L ref: IH2 N T ER0 S T IH1 SH AH0 L cer: 0.2000
# 4984 st-mary pred: S T N AE1 M ER0 IY0 ref: S EY1 N T M EH1 R IY0 cer: 0.5000
# 4985 protruding pred: P R AH0 T R AH1 D IH0 NG ref: P R OW0 T R UW1 D IH0 NG cer: 0.2222
# 4986 marchesano pred: M AA0 R K EH0 S AA1 N OW0 ref: M AA0 R K EH0 S AA1 N OW0 cer: 0.0000
# 4987 subordinate pred: S AH0 B AA1 R D AH0 N EY2 T ref: S AH0 B AO1 R D AH0 N EY2 T cer: 0.1000
# 4988 impoverishing pred: IH2 M P AH0 V EH1 R IH0 SH IH0 NG ref: IH2 M P AA1 V R IH0 SH IH0 NG cer: 0.2000
# 4989 riskiest pred: R IH1 S K AY2 Z T ref: R IH1 S K IY0 AH0 S T cer: 0.3750
# 4990 probationary pred: P R OW0 B EY1 SH AH0 N EH2 R IY0 ref: P R OW0 B EY1 SH AH0 N EH2 R IY2 cer: 0.0909
# 4991 nonchalantly pred: N AA0 N K AA0 L AA1 N T L IY0 ref: N AA1 N SH AH0 L AA1 N T L IY0 cer: 0.2727
# 4992 tangibly pred: T AE1 NG AH0 B AH0 L IY0 ref: T AE1 N JH AH0 B L IY0 cer: 0.3750
# 4993 serological pred: S EH2 R AH0 L AA1 JH IH0 K AH0 L ref: S EH0 R AH0 L AO1 JH IH0 K AH0 L cer: 0.1818
# 4994 brentanos pred: B R EH1 N T AH0 N OW0 Z ref: B R EH2 N T AA1 N OW0 Z cer: 0.2222
# 4995 jukeboxes pred: JH AH1 K AH0 B AA0 K S IH0 Z ref: JH UW1 K B AA2 K S IH0 Z cer: 0.3333
# 4996 entertainer pred: EH0 N T ER0 T EY1 N ER0 ref: EH2 N T ER0 T EY1 N ER0 cer: 0.1250
# 4997 profanity pred: P R AH0 F AE1 N IH0 T IY0 ref: P R OW0 F AE1 N AH0 T IY0 cer: 0.2222
# 4998 kalinske pred: K AH0 L IH1 N S K ref: K AH0 L IH1 N S K IY0 cer: 0.1250
# 4999 aromatic pred: AA2 R AH0 M EY1 T IH0 K ref: EH2 R AH0 M AE1 T IH0 K cer: 0.2500
# Avg CER: 0.2557

# %% [markdown]
# __Question:__ Report the number of params used by the model. _(2 points)_
#
# __Answer:__
# num parameters: 100714
#
# __Question:__ Report the training and validation loss at the end of 15 epochs. _(3 points)_
#
# __Answer:__
# train loss: 0.4155, dev loss: 0.5566
#
# __Question:__ Report the training and validation accuracies at the end of 15 epochs. _(2 points)_
#
# __Answer:__
# train acc: 0.8690, dev acc: 0.8360
#
# __Question:__ Report the test average CER. _(3 points)_
#
# __Answer:__
# Avg CER: 0.2557

# %% [markdown]
# __Extra credit:__ Try to improve on the Attention-based model you have implemented. You can either increase the number of parameters in your model or implement a fancier attention scheme, such as dot-product attention or attention weights computed from a feed forward network. _(10 points)_

# %% [markdown]
# __Answer:__
# We increase the number of parameters to 301034 (adds the size of hidden layers) and the performance of Attention-based model is better than the former one, which has CER = 0.2185.

# %%
class NewLSTMLM(torch.nn.Module):
  def __init__(self,
              vocab_size,
              embedding_size,
              hidden_size,
              num_layers=1,
              dropout=0.1):
    super().__init__()
    self.vocab_size = vocab_size
    self.embedding_size = embedding_size
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.dropout = torch.nn.Dropout(dropout)
    
    #TODO: create an embedding layer here
    #TODO: the embedding layer takes a sequence of ints and converts them into a sequence of real-valued vectors
    #TODO: see https://pytorch.org/docs/stable/nn.html?highlight=embedding#torch.nn.Embedding
    self.embedding = torch.nn.Embedding(self.vocab_size,self.embedding_size)

    #TODO: create a unidirectional RNN-LSTM here
    #TODO: Note: use the batch_first=True option, 
    #TODO: the rest of the code assumes the first dimension of any tensor is the batch_size (which is 1 for simplicity)
    #TODO: see https://pytorch.org/docs/stable/nn.html?highlight=lstm#torch.nn.LSTM
    self.rnn = torch.nn.LSTM(self.embedding_size,self.hidden_size,self.num_layers,batch_first=True,dropout=dropout)

    #TODO: create a Linear layer
    #TODO: https://pytorch.org/docs/stable/nn.html?highlight=linear#torch.nn.Linear
    self.output = torch.nn.Linear(self.hidden_size,self.vocab_size)
           

  def forward(self, x, init_hidden_state=None):
    # x should be of shape (1, N) where N is the length of the source
    assert x.shape[0] == 1 # only supporting batch size of 1 to keep the implementation simple
    x_len = len(x)
    x = x.cuda() if self.embedding.weight.is_cuda else x
    #TODO: use `self.embedding` to convert x into a sequence of vector representations
    #TODO: name the result `emb` it should have shape (1, N, embedding_size)
    emb = self.embedding(x)
    emb = self.dropout(emb) # keep this line here

    #TODO: supply the embeddings `emb` to the RNN-LSTM
    #TODO: the LSTM requires a tuple as it's initial state (h0, c0) 
    #TODO: where `h0` is the initial hidden state and `c0` is the cell_state
    #TODO: if the argument init_hidden_state is None, create a tuple (h0, c0) where h0=zeros and c0=zeros.
    #TODO: if init_hidden_state is not None, then supply it as the second argument to the RNN-LSTM

    if init_hidden_state is None:
      h = torch.zeros((self.num_layers, x_len, self.hidden_size))
      c = torch.zeros((self.num_layers, x_len, self.hidden_size))
      h = h.cuda() if self.embedding.weight.is_cuda else h
      c = c.cuda() if self.embedding.weight.is_cuda else c
    else:
      h, c = init_hidden_state

    #TODO: the LSTM will output 2 objects
    #TODO: the first is a tensor representing the hidden states of the encoder (name the first object `hidden_states`)
    #TODO: the second is a tuple representing (final hidden state, final cell state)
    #TODO: each item in the tuple is a tensor. 
    #TODO: name the tuple as `final_state`.
    #TODO: hidden_states should have size (1, N, hidden_size)
    #TODO: each tensor in the final_state should have size (1, 1, hidden_size)

    hidden_states, final_state = self.rnn(emb, (h, c))
  
    hidden_states = self.dropout(hidden_states) # keep this line here

    #TODO: supply the hidden_states (after dropout) to the ourput layer
    #TODO: the output layer will "project" from hidden_size to output_size
    #TODO: i.e. the result of the output layer will be of size (1, N, vocab_size)
    #TODO: https://pytorch.org/docs/stable/nn.html?highlight=linear#torch.nn.Linear
    #TODO: name the result of the output layer as "output_dist"
    #hidden_states = hidden_states.reshape(hidden_states.size(0)*hidden_states.size(1),hidden_states.size(2))
    output_dist = self.output(hidden_states)

    return output_dist, hidden_states, final_state # do not change this line
    
  def generate(self, start_idx, end_idx, init_hidden_state=None, idx2vocab=None, max_len=50):
    """ Performs the sequence generation process
    Args:
      start_idx: is the starting symbol (i.e. the integer corresponding to the <BOS> symbol)
      end_idx: is the end symbol (i.e. the integer corresponding to the <EOS> symbol)
      init_hidden_state: (optional) is the tuple (hidden_state, cell_state) at the starting step of generation
      If init_hidden_state is None, zero vectors are used for the hidden and cell states.
      idx2vocab: A dictionary to convert integer representation of symbols to human-readable symbols i.e. characters.
      max_len: The maximum length of the generated sequence.
    Returns:
      out: A List of generated characters
    """
    if init_hidden_state is None:
      h = torch.zeros((self.num_layers, 1, self.hidden_size))
      c = torch.zeros((self.num_layers, 1, self.hidden_size))
      h = h.cuda() if self.embedding.weight.is_cuda else h
      c = c.cuda() if self.embedding.weight.is_cuda else c
    else:
      h, c = init_hidden_state
    
    inp = torch.tensor([start_idx]).long().unsqueeze(0)
    inp = inp.cuda() if self.embedding.weight.is_cuda else inp

    out = []
    for _ in range(max_len):
      with torch.no_grad():
        emb = self.embedding(inp)
        o, (h, c) = self.rnn(emb, (h, c))
        o_dist = self.output(o)
        _, pred = o_dist.max(dim=2)
        if pred.item() == end_idx:
          break
        out.append(pred.item() if idx2vocab is None else idx2vocab[pred.item()])
        inp = pred
    return out

# %%
class NewAttentionDecoder(torch.nn.Module):
  def __init__(self,
                vocab_size,
                embedding_size,
                hidden_size,
                num_layers=1,
                dropout=0.1):
    super().__init__()
    self.vocab_size = vocab_size
    self.embedding_size = embedding_size
    self.hidden_size = hidden_size
    self.num_layers = num_layers
    self.dropout_prop = dropout
    self.dropout = torch.nn.Dropout(dropout)
    self.num_layers = num_layers
    self.embedding = torch.nn.Embedding(self.vocab_size, self.embedding_size)
    self.output_proj = torch.nn.Linear(self.hidden_size, self.vocab_size)
    self.rnn = torch.nn.LSTM(embedding_size + hidden_size, hidden_size, num_layers,
                              batch_first=True, dropout=dropout, bidirectional=False)
    self.attention = Attention(self.hidden_size)

  def forward(self, encoder_states, y):
    """Computes loss and accuracy during training.
    Args:
        encoder_states: sequence of encoder hidden states. shape should be (1, src_length, hidden_size)
        y: sequence of target symbols. shape should be (1, tgt_length)
    Returns:
        output_dist: pytorch tensor with grad_fn of shape (1, tgt_length - 1, vocab_size)
    """
    # we create the initial hidden_state and cell_state for the Decoder here
    h, c = (torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states),
            torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states))
    
    #TODO: the first input to our Attention Decoder should always be the embedding corresponding to the "<BOS>" symbol
    #TODO: recall that y[0, 0] is always going to represent the <BOS> symbol
    #TODO: create the target embedding for the first time-step here
    #TODO: name this target embedding `tgt_embedding` , it should be of shape (1, embedding_size)
    tgt_embedding = self.embedding(y[0,0])
    tgt_embedding = tgt_embedding.unsqueeze(0)
    #print(tgt_embedding.size()) = (1,64)

    output_buffer = []
    for tgt_idx in range(y.shape[1] - 1):
      #TODO: compute the `context_vector` using self.attention object
      #TODO: `self.attention` takes `encoder_states` and the decoder hidden_state `h` as input
      context_vector = self.attention(encoder_states,h)
      #print(context_vector.size()) = (1,1,64)
      #TODO: concat the `context_vector` and the previous target word's embedding
      #TODO: the result should be of size (1, 1, embedding_size + hidden_size)
      #TODO: the concated tensor is going to be the input to our decoder
      #TODO: name the result of the concat operation `decoder_input`
      #TODO: `decoder_input` should be of size  (1, embed_size + hidden_size)
      #TODO: you may find this useful: https://pytorch.org/docs/stable/torch.html?highlight=torch%20cat#torch.cat
      decoder_input = torch.cat((context_vector, tgt_embedding.unsqueeze(1)), dim=2)
      #context: (2,1,64) tgt_emb:(1,64)

      #TODO: supply `decoder_input` to the decoder RNN i.e. `self.rnn`
      #TODO: also supply the hiddent_state `h` and the cell_state `c`
      #TODO: also supply the hidden state and cell state
     
      #TODO: the output of this operation should be: o, (h, c)
      #TODO: (new_hidden_state, new_cell_state) becomes (hidden_state, cell_state) for the next step 
      #TODO: `o`, `h`, `c` should be of size (1, 1, hidden_size)
      o, (h, c) = self.rnn(decoder_input, (h, c))
      #TODO: use the linear layer `self.output_proj` to project the output to the target vocabulary
      #TODO: name the result `output`
      #TODO: shape should be (1, 1, vocab_size)
      output = self.output_proj(o)

      output_buffer.append(output)
      tgt = y[:, tgt_idx + 1]
      tgt_embedding = self.embedding(tgt)
      #end of for loop
    output_dist = torch.cat(output_buffer, dim=1)
    return output_dist

  def generate(self, encoder_states, start_idx, end_idx, idx2vocab=None, max_len=50):
    """Generates and output sequence, i.e. predicts the output sequence.
    Args:
        encoder_states: sequence of encoder hidden states. shape should be (1, src_length, hidden_size)
        start_idx: index of the <BOS> token
        end_idx: index of the <EOS> token
        idx2vocab: a dictionary that maps indexes to the output tokens
    Returns:
        out: list of strings
    """
    # we create the initial hidden_state and cell_state for the Decoder here  
    h, c = (torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states),
            torch.zeros(self.num_layers, 1, self.hidden_size).type_as(encoder_states))
    
    #TODO: create a tensor which contains the idx of the <BOS> symbol 
    #TODO: and copy it to the GPU using the .cuda() function
    #TODO: name this tensor `inp` it should be of size (1, 1)
    
    h = h.cuda()
    c = c.cuda() 
    inp = torch.tensor([start_idx]).long().unsqueeze(0)
    inp = inp.cuda() if self.embedding.weight.is_cuda else inp



    out = [] # a buffer that will hold the generated sequence
    for _ in range(max_len):

      #TODO: obtain the embedding of the input symbol (its shape should be (1, embed_size)
      #TODO: this is done using `self.embedding`
      #TODO: name the result `tgt_embedding`

      with torch.no_grad():
        tgt_embedding = self.embedding(inp)

      #TODO: compute the `context_vector` using `self.attention`
      #TODO: this step is simlar to that from the forward function.

      context_vector = self.attention(encoder_states,h)
      
      #TODO: compute the `decoder_input` by concating the `context_vector` and the `tgt_embedding`
      #TODO: the shape of the result should be (1, 1, embed_size + hidden_size)
      #TODO: supply the `decoder_input` along with the state tuple to `self.rnn`
      decoder_input = torch.cat((context_vector,tgt_embedding),dim =2)
      o, (h, c) = self.rnn(decoder_input, (h, c))

      #TODO: obtain the output distribution using the `self.output_proj` layer.
      #TODO: name the resulting output as `o_dist`, it should be of size (1, 1, vocab_size)
      o_dist = self.output_proj(o)
      
      #TODO: As we are generating the output, we must select one of the symbols to produce from
      #TODO: the output distribution. For this homework, we'll simply pick the index of the max-valued symbol from this distribution
      #TODO: This is known as "greedy" decoding
      _, pred = o_dist.max(dim=2)
      

      #TODO: to decide when to end the sequence, check if the index of the max-valued symbol is equal to `end_idx`
      #TODO: if it is the end_idx break out of the loop

      if pred.item() == end_idx:
          break
      out.append(pred.item() if idx2vocab is None else idx2vocab[pred.item()])
      inp = pred

      #TODO: if it is not the end_idx, convert the symbol from an index to a string using idx2vocab
      #TODO: add the string-symbol to the out buffer

      
      #TODO: lastly, we will use the predicted symbol as the input i.e. `inp` for the next time step


      #end of for loop
    return out

# %%
class NewEncoderDecoderAttention(torch.nn.Module):
  def __init__(self,
                src_vocab_size,
                tgt_vocab_size,
                embedding_size,
                hidden_size,
                num_layers=1,
                dropout=0.0,
                max_grad_norm=5.0):
    super().__init__()
    self.hidden_size = hidden_size
    self.embedding_size = embedding_size
    self.num_layers = num_layers
    self.max_grad_norm = max_grad_norm
    self.encoder = NewLSTMLM(src_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.decoder = NewAttentionDecoder(tgt_vocab_size, embedding_size, hidden_size, num_layers, dropout)
    self.log_smax = torch.nn.LogSoftmax(dim=-1)
    self.loss = torch.nn.NLLLoss(reduction='mean', ignore_index=-1)
    #We are going to package the optimizer inside this class
    self.optimizer = torch.optim.Adam(self.parameters())

  def train_step(self, x, y):
    """ Performs one step of SGD
    Args:
      x: the input sequence, its size should be: (1, src_length)
      y: the output sequence, its size should be (1, tgt_length)
    Returns:
      loss: the loss for this example (note this is just for logging it is not a pytorch tensor)
      accuracy: the accuracy for this example
    """
    self.optimizer.zero_grad()
    _loss, acc = self(x, y)
    _loss.backward()
    grad_norm = torch.nn.utils.clip_grad_norm_(self.parameters(),
                                                self.max_grad_norm)

    if math.isnan(grad_norm):
      print('skipping update grad_norm is nan!')
    else:
      self.optimizer.step()
    loss = _loss.item()
    return loss, acc

  def forward(self, x, y):
    """Computes loss and accuracy during training.
    Args:
      x: sequence of source symbols. shape should be (1, src_length)
      y: sequence of target symbols. shape should be (1, tgt_length)
    Returns:
      loss: pytorch scalar with grad_fn. shape should be (1, 1)
      accuracy: scalar
    """
    _, encoder_states, _ = self.encoder(x)
    out_tgt = self.decoder(encoder_states, y)
    out_tgt_lsm = self.log_smax(out_tgt)
    y_output = y[:, 1:]
    loss = self.loss(out_tgt_lsm.squeeze(0), y_output.squeeze(0))
    _, pred = out_tgt.max(dim=2)
    accuracy = float((pred == y_output).sum()) / y_output.numel()
    return loss, accuracy

  def generate(self, x, start_idx, end_idx, idx2vocab=None, max_len=50):
    _, encoder_states, _ = self.encoder(x)
    out = self.decoder.generate(encoder_states, start_idx, end_idx, idx2vocab)
    return out

# %%
print(train_corpus.data_size, dev_corpus.data_size, test_corpus.data_size)
new_model_attn = NewEncoderDecoderAttention(src_vocab_size=len(train_corpus.src_vocab),
                                tgt_vocab_size=len(train_corpus.tgt_vocab),
                                embedding_size=64,
                                hidden_size=128,
                                num_layers=1)
new_model_attn = new_model_attn.cuda()
print(new_model_attn)
print('num parameters:', sum([p.numel() for p in new_model_attn.parameters()]))
# Out:
# 10000 2000 5000
# NewEncoderDecoderAttention(
#   (encoder): NewLSTMLM(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (embedding): Embedding(31, 64)
#     (rnn): LSTM(64, 128, batch_first=True)
#     (output): Linear(in_features=128, out_features=31, bias=True)
#   )
#   (decoder): NewAttentionDecoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (embedding): Embedding(75, 64)
#     (output_proj): Linear(in_features=128, out_features=75, bias=True)
#     (rnn): LSTM(192, 128, batch_first=True)
#     (attention): Attention()
#   )
#   (log_smax): LogSoftmax(dim=-1)
#   (loss): NLLLoss()
# )
# num parameters: 301034

# %%
new_model_attn = train(new_model_attn, train_corpus, dev_corpus, max_epochs=10) #takes 1 - 1.5 hours
# Out:
# epoch: 0 time elapsed: 112.91
# train loss: 1.3418 train acc: 0.6488
#   dev loss: 0.7760   dev acc: 0.7808
# epoch: 1 time elapsed: 233.13
# train loss: 0.6500 train acc: 0.8087
#   dev loss: 0.6182   dev acc: 0.8161
# epoch: 2 time elapsed: 353.19
# train loss: 0.5414 train acc: 0.8362
#   dev loss: 0.5798   dev acc: 0.8266
# epoch: 3 time elapsed: 473.52
# train loss: 0.4761 train acc: 0.8528
#   dev loss: 0.5399   dev acc: 0.8374
# epoch: 4 time elapsed: 594.31
# train loss: 0.4313 train acc: 0.8636
#   dev loss: 0.5233   dev acc: 0.8446
# epoch: 5 time elapsed: 715.35
# train loss: 0.3940 train acc: 0.8752
#   dev loss: 0.5132   dev acc: 0.8472
# epoch: 6 time elapsed: 835.74
# train loss: 0.3671 train acc: 0.8827
#   dev loss: 0.5047   dev acc: 0.8506
# epoch: 7 time elapsed: 956.25
# train loss: 0.3430 train acc: 0.8897
#   dev loss: 0.5087   dev acc: 0.8505
# epoch: 8 time elapsed: 1077.30
# train loss: 0.3239 train acc: 0.8943
#   dev loss: 0.5032   dev acc: 0.8520
# epoch: 9 time elapsed: 1198.44
# train loss: 0.3040 train acc: 0.9005
#   dev loss: 0.5106   dev acc: 0.8547

# %%
evaluate(new_model_attn, test_corpus)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1 utility's pred: Y UW0 T IY0 L IH1 T IY0 Z ref: Y UW0 T IH1 L AH0 T IY0 Z cer: 0.2222
# 2 rothenberg pred: R OW1 TH AH0 N B ER0 G ref: R AO1 TH AH0 N B ER0 G cer: 0.1250
# 3 kinesiology pred: K IH2 N IH0 S IY0 AA1 L AH0 JH IY0 ref: K IH2 N IH0 S IY2 AA1 L AH0 JH IY0 cer: 0.0909
# 4 reclassified pred: R IY0 K L AE1 S IH0 F AY2 D ref: R IY0 K L AE1 S AH0 F AY2 D cer: 0.1000
# 5 substantive pred: S AH0 B S T AE1 N T IH0 V ref: S AH1 B S T AH0 N T IH0 V cer: 0.2000
# 6 situations pred: S IH2 T UW0 EY1 SH AH0 N Z ref: S IH2 CH UW0 EY1 SH AH0 N Z cer: 0.1111
# 7 lobianco pred: L OW0 B IY0 AA1 L K OW0 ref: L OW0 B IY0 AA1 N K OW0 cer: 0.1250
# 8 participants' pred: P AA0 R T IH1 S AH0 P AH0 N T S ref: P AA0 R T IH1 S AH0 P AH0 N T S cer: 0.0000
# 9 transportable pred: T R AE1 N S P AO2 R T AH0 B AH0 L ref: T R AE0 N S P AO1 R T AH0 B AH0 L cer: 0.1538
# 10 inscribes pred: IH2 N S K R AY1 B Z ref: IH2 N S K R AY1 B Z cer: 0.0000
# 11 grandbaby pred: G R AE1 N G B AE2 B IY0 ref: G R AE1 N D B EY2 B IY0 cer: 0.2222
# 12 costanzo pred: K AA0 S T AA1 N Z OW0 ref: K OW0 S T AA1 N Z OW0 cer: 0.1250
# 13 novakovich pred: N AH0 V AA1 K AH0 V IH0 CH ref: N AH0 V AA1 K AH0 V IH0 CH cer: 0.0000
# 14 engulfing pred: EH1 NG G AH0 L F IH0 NG ref: IH0 N G AH1 L F IH0 NG cer: 0.3750
# 15 jorgenson pred: JH AO1 R G IH0 N S AH0 N ref: JH AO1 R G IH0 N S AH0 N cer: 0.0000
# 16 marketeers pred: M AA1 R K AH0 T ER0 Z ref: M AA2 R K AH0 T IH1 R Z cer: 0.3333
# 17 branagan pred: B R AE1 N AH0 G AH0 N ref: B R AE1 N AH0 G AE0 N cer: 0.1250
# 18 toshimitsu pred: T AH0 SH IH1 M IH0 T S ref: T OW0 SH IY0 M IY1 T S UW0 cer: 0.4444
# 19 electrobiology pred: EH2 L EH2 K T R OW0 B IY0 AA1 L AH0 JH IY0 ref: IH2 L EH2 K T R OW0 B AY0 AA1 L AH0 JH IY2 cer: 0.2143
# 20 flagships pred: F L AE1 JH F IH2 P S ref: F L AE1 G SH IH2 P S cer: 0.2500
# 21 downsizing pred: D AW1 N S AY2 Z IH0 NG ref: D AW1 N S AY2 Z IH0 NG cer: 0.0000
# 22 biofeedback pred: B IY0 OW0 F EH1 D B AH0 K ref: B AY0 OW0 F IY1 D B AE2 K cer: 0.3333
# 23 retrovir pred: R IY0 T R AO1 V ER0 ref: R EH1 T R OW0 V IH2 R cer: 0.5000
# 24 jovanovic pred: Y OW0 V AA0 N OW1 V IH0 K ref: Y AH0 V AH0 N AA1 V IH0 K cer: 0.3333
# 25 conjugated pred: K AH0 N JH AH1 G AH0 T IH0 D ref: K AA2 N JH AH0 G EY1 T IH0 D cer: 0.3000
# 26 brooksville pred: B R UH1 K S V IH2 L ref: B R UH1 K S V IH0 L cer: 0.1250
# 27 nonperforming pred: N AA1 N P R F AO2 R M IH0 NG ref: N AA0 N P ER0 F AO1 R M IH0 NG cer: 0.2727
# 28 fulfilling pred: F AH1 L F AH0 L IH0 NG ref: F UH0 L F IH1 L IH0 NG cer: 0.2500
# 29 conjecture pred: K AH0 N JH EH1 K CH ER0 ref: K AH0 N JH EH1 K CH ER0 cer: 0.0000
# 30 adjustments pred: AH0 JH AH1 T S AH0 N T S ref: AH0 JH AH1 S T M AH0 N T S cer: 0.2000
# 31 hoglund's pred: HH AA1 G L AH0 N D Z ref: HH AO1 G L AH0 N D Z cer: 0.1250
# 32 languished pred: L AE1 NG G W IH0 SH AH0 D ref: L AE1 NG G W IH0 SH T cer: 0.2500
# 33 obscenity pred: AA2 B S K EH1 N IH0 T IY0 ref: AH0 B S EH1 N IH0 T IY0 cer: 0.2500
# 34 kingsport pred: K IH1 NG G S P AO2 R T ref: K IH1 NG S P AO2 R T cer: 0.1250
# 35 premonitory pred: P R IY0 M AA1 N IH0 T ER0 IY0 ref: P R AH0 M AH1 N AH0 T ER0 IY0 cer: 0.3000
# 36 slowinski pred: S L AH0 W IH1 N S K IY0 ref: S L OW0 IH1 N S K IY0 cer: 0.2500
# 37 schiltknecht pred: SH IH1 L T N EH2 K T ref: SH IH1 L T N EH2 K T cer: 0.0000
# 38 stolichnaya pred: S T OW1 L IH0 NG N EY2 ref: S T OW2 L IH0 K N AY1 AH0 cer: 0.4444
# 39 subfamily pred: S AH0 B F AE1 M AH0 L IY0 ref: S AH1 B F AE2 M AH0 L IY0 cer: 0.2222
# 40 peterbilt pred: P EH1 T ER0 B IH2 L T ref: P IY1 T ER0 B IH2 L T cer: 0.1250
# 41 mcdermid pred: M AH0 K ER1 T IH0 D ref: M AH0 K D ER1 M AH0 D cer: 0.3750
# 42 simulcast pred: S IH1 M Y AH0 L K S T ref: S AY1 M Y AH0 L K AE2 S T cer: 0.2000
# 43 reemergence pred: R IY0 EH1 M ER0 G AH0 N S ref: R IY0 IH0 M ER1 JH AH0 N S cer: 0.3333
# 44 papadopoulos pred: P AE2 P AH0 D OW1 P AH0 L AH0 S ref: P AE2 P AH0 D AA1 P AH0 L AH0 S cer: 0.0909
# 45 factually pred: F AE1 K CH UW0 AH0 L IY0 ref: F AE1 K CH UW0 AH0 L IY0 cer: 0.0000
# 46 hildegarde pred: HH IH1 L D IH0 G AA0 R D ref: HH IH1 L D IH0 G AA2 R D cer: 0.1111
# 47 gingerbread pred: G IH1 NG G ER0 B R EY2 D ref: JH IH1 N JH ER0 B R EH2 D cer: 0.4444
# 48 rosenman pred: R OW1 Z AH0 N M AH0 N ref: R OW1 Z AH0 N M AH0 N cer: 0.0000
# 49 unabated pred: AH0 N AO1 B AH0 T IH0 D ref: AH2 N AH0 B EY1 T IH0 D cer: 0.3750
# 50 batignolles pred: B AE1 T AH0 G N OW0 L Z ref: B AE2 T IH0 N Y OW1 L AH0 S cer: 0.7000
# 51 frazzini pred: F R AA0 T S IY0 N IY1 AH0 L ref: F R AA0 T S IY1 N IY0 cer: 0.5000
# 52 disapproving pred: D IH0 S AE1 P R AH0 V IH2 NG ref: D IH0 S AH0 P R UW1 V IH0 NG cer: 0.3000
# 53 ventilating pred: V EH1 N T AH0 L EY2 T IH0 NG ref: V EH1 N T AH0 L EY2 T IH0 NG cer: 0.0000
# 54 believability pred: B EH2 L AH0 V EY1 B AH0 T IY0 ref: B AH0 L IY2 V AH0 B IH1 L IH0 T IY0 cer: 0.5000
# 55 punctuating pred: P AH1 NG K T AH2 T IH0 NG ref: P AH1 NG K CH UW0 EY2 D IH0 NG cer: 0.4000
# 56 countdowns pred: K AW1 N T IH0 D S ref: K AW1 N T D AW2 N Z cer: 0.5000
# 57 legalities pred: L EH1 G AH0 L IH0 T IY0 Z ref: L IY0 G AE1 L IH0 T IY0 Z cer: 0.2222
# 58 intercellular pred: IH2 N T ER0 S EH1 L Y AH0 L ER0 ref: IH2 N T ER0 S EH1 L Y AH0 L ER0 cer: 0.0000
# 59 extravaganza pred: EH2 K S T R AE1 V AH0 JH AH0 N Z ref: EH0 K S T R AE2 V AH0 G AE1 N Z AH0 cer: 0.3846
# 60 entombment pred: EH1 N T AH0 M B M AH0 N T ref: IH0 N T UW1 M M AH0 N T cer: 0.3333
# 61 suspensions pred: S AH0 S P EH1 N SH AH0 N Z ref: S AH0 S P EH1 N SH AH0 N Z cer: 0.0000
# 62 recognition's pred: R IY0 K AH0 G N IH1 T IY0 N Z ref: R EH2 K IH0 G N IH1 SH AH0 N Z cer: 0.3636
# 63 compartments pred: K AA1 M P AA2 R T M AH0 N T S ref: K AH0 M P AA1 R T M AH0 N T S cer: 0.1667
# 64 triumphantly pred: T R IH1 M F AH0 N T L IY0 ref: T R AY0 AH1 M F AH0 N T L IY0 cer: 0.1818
# 65 unreliable pred: AH0 N R EH1 L IY0 AH0 B AH0 L ref: AH2 N R IH0 L AY1 AH0 B AH0 L cer: 0.3000
# 66 northwestern's pred: N AO1 R TH W EH2 S T ER0 Z ref: N AO2 R TH W EH1 S T ER0 N Z cer: 0.2727
# 67 hempfling pred: HH EH1 M P L IH0 NG ref: HH EH1 M P F AH0 L IH0 NG cer: 0.2222
# 68 renegotiate pred: R EH2 N AH0 G OW1 T IY0 AH0 T ref: R IY2 N IH0 G OW1 SH IY0 EY2 T cer: 0.4000
# 69 mandalit pred: M AE1 N D AH0 L IH0 T ref: M AE1 N D AH0 L IH2 T cer: 0.1250
# 70 criscione pred: K R IH1 S IY0 AH0 N IY0 ref: K R IY0 S CH OW1 N IY0 cer: 0.3750
# 71 gilchrest pred: G IH1 NG K R EH2 S T ref: G IH1 L K ER0 IH0 S T cer: 0.3750
# 72 interiors pred: IH2 N T ER0 IH1 R Z ref: IH2 N T IH1 R IY0 ER0 Z cer: 0.3750
# 73 misdiagnosis pred: M IH0 S D IY0 AE1 G N AH0 S IH0 S ref: M IH0 S D AY2 IH0 G N OW1 S AH0 S cer: 0.3333
# 74 repositories pred: R EH2 P AH0 S IH1 T ER0 IY0 Z ref: R IY0 P AA1 Z AH0 T AO2 R IY0 Z cer: 0.5455
# 75 lithuanian pred: L IH2 T UW0 HH EY1 N IY0 ref: L IH2 TH AH0 W EY1 N IY0 AH0 N cer: 0.5000
# 76 transcanada's pred: T R AE2 N Z K AE1 N AH0 Z ref: T R AE2 N Z K AE1 N AH0 D AH0 Z cer: 0.1667
# 77 badalamenti pred: B AE2 D AH0 L AE1 M AH0 N T IY0 ref: B AA0 D AA0 L AA0 M EH1 N T IY0 cer: 0.3636
# 78 verifiable pred: V ER0 IY0 F IY0 AA1 B L ref: V EH1 R AH0 F AY2 AH0 B AH0 L cer: 0.6000
# 79 hempstead pred: HH EH1 M P S T EH2 D ref: HH EH1 M P S T EH0 D cer: 0.1250
# 80 prerecorded pred: P R IY1 R K AO2 R D IH0 D ref: P R IY2 R IY0 K AO1 R D IH0 D cer: 0.2727
# 81 clipboard pred: K L IH1 P B AO2 R D ref: K L IH1 P B AO2 R D cer: 0.0000
# 82 paganism pred: P AE1 G AH0 N IH2 Z AH0 M ref: P EY1 G AH0 N IH2 Z AH0 M cer: 0.1111
# 83 fabricate pred: F AO1 B R IH0 K EY2 T ref: F AE1 B R AH0 K EY2 T cer: 0.2500
# 84 teleprobe pred: T EH1 L AH0 P R AH0 B EH0 ref: T EH1 L AH0 P R OW1 B cer: 0.2500
# 85 cryogenic pred: K R IY0 AO1 JH AH0 N IH0 K ref: K R AY1 AH0 JH EH2 N IH0 K cer: 0.3333
# 86 unmanaged pred: AH0 N M AE1 N IH0 JH IH0 D ref: AH0 N M AE1 N IH0 JH D cer: 0.1250
# 87 intricate pred: IH2 N T R IH1 K AH0 T ref: IH1 N T R AH0 K AH0 T cer: 0.2500
# 88 familiarize pred: F AA2 M AH0 L IY1 R AY2 Z ref: F AH0 M IH1 L Y ER0 AY2 Z cer: 0.4444
# 89 st-thomas pred: S T N T F T AE1 M AH0 S ref: S EY1 N T AA1 M AH0 S cer: 0.5000
# 90 kredietbank pred: K R EH1 D IY0 AH0 T B AE2 NG K ref: K R EH0 D IY0 T B AE1 NG K cer: 0.3000
# 91 santa-fe's pred: S AE1 N T AH0 F Z ref: S AE1 N T AH0 F EY1 Z cer: 0.1250
# 92 distillate pred: D IH1 S T AH0 L EY2 T ref: D IH1 S T AH0 L EY2 T cer: 0.0000
# 93 palkovic pred: P AA0 L K AH0 V IH1 K ref: P AH0 L K AA1 V IH0 K cer: 0.3750
# 94 calculate pred: K AE1 L K Y AH0 L EY2 T ref: K AE1 L K Y AH0 L EY2 T cer: 0.0000
# 95 plebeians pred: P L EH1 B IY0 AH0 N Z ref: P L AH0 B IY1 AH0 N Z cer: 0.2500
# 96 insubordination pred: IH2 N S AH0 B AO1 R D AH0 N ref: IH2 N S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.3571
# 97 recommendations pred: R EH2 K AH0 M EH1 N D AH0 T AH0 N Z ref: R EH2 K AH0 M AH0 N D EY1 SH AH0 N Z cer: 0.2308
# 98 galentine pred: G AH0 L EH1 N T AH0 N ref: G AA0 L EH0 N T IY1 N IY0 cer: 0.4444
# 99 comedienne pred: K AH0 M EH1 D IY0 AH0 N ref: K AH0 M IY2 D IY0 EH1 N cer: 0.2500
# 100 stolarski pred: S T AA1 L ER0 S K IY0 ref: S T AH0 L AA1 R S K IY2 cer: 0.4444
# 101 reprocessed pred: R IY0 P R AA1 S EH0 S T ref: R IY0 P R AO1 S EH0 S T cer: 0.1111
# 102 d'artagnan pred: D AO1 R T AH0 G N AH0 N ref: D AH0 R T AE1 NG Y AH0 N # foreign french cer: 0.5833
# 103 radiators pred: R AH0 D IH1 AH0 T AO2 R Z ref: R EY1 D IY0 EY2 T ER0 Z cer: 0.6250
# 104 rollerblading pred: R OW1 L ER0 B L AE0 D IH0 NG ref: R OW1 L ER0 B L EY2 D IH0 NG cer: 0.1000
# 105 depended pred: D IH0 P EH1 N D IH0 D ref: D IH0 P EH1 N D AH0 D cer: 0.1250
# 106 sardinia pred: S AA0 R D IY1 N IY0 AH0 ref: S AA0 R D IY1 N IY0 AH0 cer: 0.0000
# 107 intending pred: IH2 N T EH1 N D IH0 NG ref: IH2 N T EH1 N D IH0 NG cer: 0.0000
# 108 homogenization pred: HH OW2 M OW0 G AH0 N EY1 Z AH0 N ref: HH OW0 M AA1 JH AH0 N IH0 Z EY2 SH AH0 N cer: 0.4615
# 109 telecasts pred: T EH1 L AH0 K AH0 S T S ref: T EH1 L AH0 K AE2 S T S cer: 0.1111
# 110 matriculating pred: M AH0 T R IH1 K Y AH0 L AH0 T IH0 NG ref: M AH0 T R IH1 K Y AH0 L EY0 T IH0 NG cer: 0.0769
# 111 conception pred: K AH0 N S EH1 P SH AH0 N ref: K AH0 N S EH1 P SH AH0 N cer: 0.0000
# 112 simonson pred: S IH1 M AH0 N S AH0 N ref: S IH1 M AH0 N S AH0 N cer: 0.0000
# 113 inoffensive pred: IH2 N AO1 F AH0 N S IH0 V ref: IH2 N AH0 F EH1 N S IH0 V cer: 0.2222
# 114 nationalistic pred: N AE2 SH AH0 N AE1 L AH0 S T IH0 K ref: N AE2 SH AH0 N AH0 L IH1 S T IH0 K cer: 0.1667
# 115 fantastically pred: F AH0 N T AE1 S T IH0 K L IY0 ref: F AE0 N T AE1 S T IH0 K L IY0 cer: 0.0909
# 116 istituto pred: Y IH2 S T IH1 T UW0 T UW2 ref: IH2 S T IH0 T UW1 T OW0 cer: 0.5000
# 117 florentino pred: F L AO0 R EH1 N T AH0 N OW0 ref: F L AO0 R EH0 N T IY1 N OW0 cer: 0.2000
# 118 microcircuit pred: M AY2 K R OW0 S IH1 R IH0 T ref: M AY1 K R OW0 S ER2 K AH0 T cer: 0.4000
# 119 imperfectly pred: IH2 M P ER1 F AH0 K L IY0 ref: IH2 M P ER1 F IH0 K T L IY0 cer: 0.2000
# 120 desegregation pred: D EH2 Z AH0 G R EH1 G SH AH0 N ref: D IH0 S EH2 G R AH0 G EY1 SH AH0 N cer: 0.4167
# 121 fleischhacker pred: F L AY1 K W ER2 K ER0 ref: F L AY1 SH HH AH0 K ER0 cer: 0.3750
# 122 dupriest pred: D UH1 P R IY0 AH0 S T ref: D AH1 P ER0 IY0 IH0 S T cer: 0.3750
# 123 unattractive pred: AH0 N AE1 T R AH0 K T IH0 V ref: AH2 N AH0 T R AE1 K T IH0 V cer: 0.3000
# 124 sanhedrin pred: S AE1 N HH IH0 D R IH0 N ref: S AE2 N HH IY1 D R IH0 N cer: 0.2222
# 125 callousness pred: K AE1 L AH0 S N AH0 S ref: K AE1 L AH0 S N AH0 S cer: 0.0000
# 126 dermatologist pred: D EH2 R M AH0 T OW1 L AH0 JH IH0 S T ref: D ER2 M AH0 T AA1 L AH0 JH IH0 S T cer: 0.2500
# 127 harmonics pred: HH AA0 R M AA1 N IH0 K S ref: HH AA0 R M AA1 N IH0 K S cer: 0.0000
# 128 deployable pred: D IH0 P L OY1 AH0 B AH0 L ref: D IH0 P L OY1 AH0 B AH0 L cer: 0.0000
# 129 approximately pred: AH0 P R AA1 K S IH0 M AH0 T L IY0 ref: AH0 P R AA1 K S AH0 M AH0 T L IY0 cer: 0.0833
# 130 remerchandise pred: R IH0 M ER1 SH AH0 N D IH0 S ref: R IY0 M ER1 CH AH0 N D AY2 Z cer: 0.4000
# 131 bianchini pred: B IY0 AH0 N K IY1 N IY0 ref: B IY0 AA0 N CH IY1 N IY0 cer: 0.2500
# 132 invigorating pred: IH2 N V IH1 G R AH0 T IH0 NG ref: IH2 N V IH1 G ER0 EY2 T IH0 NG cer: 0.2000
# 133 castellanos pred: K AA0 S T EH0 L AA1 N OW0 Z ref: K AA0 S T EY0 L AA1 N OW0 Z cer: 0.1000
# 134 hippopotamus pred: HH AY2 P AH0 P AA1 T AH0 M AH0 S ref: HH IH2 P AH0 P AA1 T AH0 M AH0 S cer: 0.0909
# 135 vanorden pred: V AH0 N AO1 R D AH0 N ref: V AE0 N AO1 R D AH0 N cer: 0.1250
# 136 biographical pred: B AY2 OW0 G R AE1 F IH0 K AH0 L ref: B AY2 AH0 G R AE1 F IH0 K AH0 L cer: 0.0909
# 137 tartikoff pred: T AA1 R T IH0 K AO2 F ref: T AA1 R T IH0 K AO2 F cer: 0.0000
# 138 transcontinental pred: T R AE2 N Z K AH0 N T IH1 N AH0 N T ref: T R AE2 N Z K AA2 N T IH0 N EH1 N T AH0 L cer: 0.3125
# 139 mongosutu's pred: M AA2 NG G OW0 S UW1 T UW0 Z ref: M AA2 NG G OW0 S UW1 T UW0 Z cer: 0.0000
# 140 parametric pred: P AA2 R AH0 M EH1 T R IH0 K ref: P EH2 R AH0 M EH1 T R IH0 K cer: 0.1000
# 141 linguistically pred: L IH2 NG G W IH0 S T IH1 K AH0 L IY0 ref: L IH0 NG G W IH1 S T IH0 K L IY0 cer: 0.3333
# 142 crotonville pred: K R OW1 T AH0 N V IH2 L ref: K R OW1 T AH0 N V IH2 L cer: 0.0000
# 143 recriminations pred: R EH2 K R AH0 M IH1 N AH0 T IY0 N Z ref: R IH0 K R IH2 M IH0 N EY1 SH AH0 N Z cer: 0.4615
# 144 toxicologists pred: T AA2 K S IH0 K AA1 L AH0 JH IH0 S T S ref: T AA2 K S IH0 K AA1 L AH0 JH IH0 S T S cer: 0.0000
# 145 holtzapple pred: HH OW1 L T S T P AE2 L ref: HH OW1 L T Z AH0 P AH0 L cer: 0.3333
# 146 toriente pred: T AO0 R IY0 EH1 N T IY0 ref: T AO2 R IY0 EH1 N T EY0 cer: 0.2500
# 147 utility pred: Y UW0 T IY0 L IH1 T IY0 ref: Y UW0 T IH1 L AH0 T IY0 cer: 0.2500
# 148 norberta pred: N AO1 R B ER0 T AH2 ref: N AO0 R B EH1 R T AH0 cer: 0.5000
# 149 amputated pred: AE1 M P Y UW0 T EY2 T IH0 D ref: AE1 M P Y AH0 T EY2 T IH0 D cer: 0.1000
# 150 pleasanton pred: P L IY1 Z AH0 N T AH0 N ref: P L EH1 Z AH0 N T AH0 N cer: 0.1111
# 151 mollycoddle pred: M OW1 L IY0 K AA2 D AH0 L ref: M AA1 L IY0 K AA2 D AH0 L cer: 0.1111
# 152 lexical pred: L EH1 K S IH0 K AH0 L ref: L EH1 K S IH0 K AH0 L cer: 0.0000
# 153 omnipotent pred: AA1 M N AH0 P AH0 T AH0 N T ref: AA0 M N IH1 P AH0 T AH0 N T cer: 0.2000
# 154 repudiating pred: R IH0 P Y UW1 D IY0 EY2 T IH0 NG ref: R IY0 P Y UW1 D IY0 EY2 T IH0 NG cer: 0.0909
# 155 avant-garde pred: AE0 V AE1 N T G AA2 R D ref: AH0 V AA1 N T G AA1 R D cer: 0.3333
# 156 toldrian pred: T AA1 L D R IY2 AH0 N ref: T OW1 L D R IY0 AH0 N cer: 0.2500
# 157 transformers pred: T R AE1 N S F ER0 M ER0 Z ref: T R AE0 N S F AO1 R M ER0 Z cer: 0.2727
# 158 eurobond pred: Y UW1 R OW0 B OW2 N D ref: Y UW1 R OW0 B AA2 N D cer: 0.1250
# 159 redistributing pred: R EH2 D IH0 S T R IH1 B Y UW0 T IH0 NG ref: R IY2 D IH0 S T R IH1 B Y UW0 T IH0 NG cer: 0.0714
# 160 osmundson pred: AH0 S M AH1 N D S AH0 N ref: AA1 Z M AH0 N D S AH0 N cer: 0.3333
# 161 basements pred: B EY1 S M AH0 N T S ref: B EY1 S M AH0 N T S cer: 0.0000
# 162 securely pred: S IY1 K Y ER0 IH0 L IY0 ref: S IH0 K Y UH1 R L IY0 cer: 0.3750
# 163 unremarked pred: AH0 N R IY0 M AA1 R K IH0 D ref: AH0 N R IH0 M AA1 R K T cer: 0.3333
# 164 comparing pred: K AH0 M T EH1 R IH0 NG ref: K AH0 M P EH1 R IH0 NG cer: 0.1250
# 165 lillibridge pred: L IH1 L AH0 B R IH0 JH ref: L IH1 L IH0 B R IH2 JH cer: 0.2500
# 166 afterimages pred: AH0 F EH1 R AH0 M IH0 JH IH0 Z ref: AE1 F T ER0 IH2 M IH0 JH AH0 Z cer: 0.5000
# 167 supergiant pred: S UW0 P IH1 R JH AH0 N T ref: S UW1 P ER0 JH AY1 AH0 N T cer: 0.4444
# 168 opponent's pred: AA1 P AH0 N AH0 N T S ref: AH0 P OW1 N AH0 N T S cer: 0.2500
# 169 microwaved pred: M AY1 K R AH0 V EY2 D ref: M AY1 K R OW0 W EY2 V D cer: 0.3333
# 170 corinthian pred: K AO2 R IH0 N TH IY1 AH0 N ref: K ER0 IH1 N TH IY0 AH0 N cer: 0.5000
# 171 lipoprotein pred: L IH2 P AH0 P R OW1 T IY0 N ref: L IH2 P AH0 P R OW1 T IY0 N cer: 0.0000
# 172 repositioning pred: R EH2 P AH0 S IH1 SH AH0 N IH0 NG ref: R IY2 P AH0 Z IH1 SH AH0 N IH0 NG cer: 0.1818
# 173 mutilation pred: M Y UW2 T AH0 L EY1 SH AH0 N ref: M Y UW2 T AH0 L EY1 SH AH0 N cer: 0.0000
# 174 meteorologists pred: M EH2 T IY0 AO1 R AH0 L AH0 S T S ref: M IY2 T IY0 ER0 AA1 L AH0 JH IH0 S T S cer: 0.4615
# 175 pierrepont pred: P AY1 R P EH2 P SH AH0 N ref: P IH0 R EY1 P OW0 N T cer: 0.7500
# 176 ecstatic pred: EH0 K S T EY1 T IH0 K ref: EH0 K S T AE1 T IH0 K cer: 0.1250
# 177 branaman pred: B R AE1 N AH0 M AH0 N ref: B R AE1 N AH0 M AH0 N cer: 0.0000
# 178 suffocated pred: S AH1 F AH0 K EY2 T IH0 D ref: S AH1 F AH0 K EY2 T IH0 D cer: 0.0000
# 179 hovnanian pred: HH AH0 V N EY1 N IY0 AH0 N ref: HH AA2 V N EY1 N IY0 AH0 N cer: 0.1111
# 180 criss-cross pred: K R IH1 S K R OW2 S ref: K R IH1 S K R AO1 S cer: 0.1250
# 181 northeast's pred: N AO1 R TH AH0 S T S ref: N AO2 R TH IY1 S T S cer: 0.2500
# 182 disfigurement pred: D IH0 S F IH1 G Y ER0 M AH0 N T ref: D IH0 S F IH1 G Y ER0 M EH0 N T cer: 0.0833
# 183 stapling pred: S T AE1 P L IH0 NG ref: S T EY1 P AH0 L IH0 NG cer: 0.2500
# 184 buttressing pred: B UW0 T R EH1 S IH0 NG ref: B AH1 T R AH0 S IH0 NG cer: 0.2500
# 185 telefonos pred: T EH2 L AH0 F OW1 N Z ref: T EH2 L EH0 F OW1 N OW0 S cer: 0.3333
# 186 reflexivity pred: R IH0 F L EH2 K S IH0 V IH1 T IY0 ref: R IY2 F L EH2 K S IH1 V IH0 T IY0 cer: 0.2500
# 187 profitably pred: P R AA1 F AH0 T AH0 B L IY0 ref: P R AA1 F AH0 T AH0 B L IY0 cer: 0.0000
# 188 grudzinski pred: G R AH0 D IH1 N S K IY0 ref: G R AH0 JH IH1 N S K IY0 cer: 0.1111
# 189 non-poisonous pred: N AA0 N P OY1 Z AH0 N AH0 S ref: N AA0 N P OY1 Z AH0 N AH0 S cer: 0.0000
# 190 tallahassee's pred: T AE1 L AH0 HH AE2 S IH0 Z ref: T AE2 L AH0 HH AE1 S IY0 Z cer: 0.3333
# 191 trombones pred: T R AA1 M B AH0 N Z ref: T R AA0 M B OW1 N Z cer: 0.2500
# 192 rosengrant pred: R OW1 Z AH0 N G R AH0 N T ref: R OW1 Z AH0 N G R AE2 N T cer: 0.1000
# 193 laceration pred: L AE2 S ER0 EY1 SH AH0 N ref: L AE2 S ER0 EY1 SH AH0 N cer: 0.0000
# 194 ricketson pred: R IH1 K AH0 T S AH0 N ref: R IH1 K IH0 T S AH0 N cer: 0.1250
# 195 bankworcester pred: B AE1 NG K W ER2 S T ER0 ref: B AE1 NG K W ER1 CH EH2 S T ER0 cer: 0.2727
# 196 operations pred: AA2 P ER0 EY1 SH AH0 N Z ref: AA2 P ER0 EY1 SH AH0 N Z cer: 0.0000
# 197 subunits pred: S AH0 B Y UW1 N AH0 T S ref: S AH2 B Y UW1 N IH0 T S cer: 0.2222
# 198 yogiisms pred: Y OW0 JH IH1 ZH IH0 N IH2 Z AH0 M Z ref: Y OW0 G IY1 S AH0 M Z cer: 0.8750
# 199 mazziotti pred: M AH0 Z CH IY1 T IY0 ref: M AA0 T S IY0 OW1 T IY0 cer: 0.6250
# 200 dornhens pred: D AO1 R N HH AH0 N S ref: D AO1 R N HH EH0 N Z cer: 0.2500
# 201 crustaceous pred: K R UW1 S T AE2 S AH0 S ref: K R AH0 S T EY1 SH AH0 S cer: 0.3333
# 202 dilenschneider pred: D IH0 L EH1 N SH N IH0 D ER0 ref: D AY1 L AH0 N SH N AY2 D ER0 cer: 0.3000
# 203 innovated pred: IH2 N AO1 V AH0 T IH0 D ref: IH1 N AH0 V EY2 T IH0 D cer: 0.3750
# 204 disseminated pred: D IH0 S EH1 M IH0 N EY2 T IH0 D ref: D IH0 S EH1 M AH0 N EY2 T AH0 D cer: 0.1818
# 205 auxiliary pred: AA2 K S IH0 L IY1 R IY0 ref: AA0 G Z IH1 L Y ER0 IY0 cer: 0.7500
# 206 mississippi's pred: M IH0 S IH0 S IH1 P IY0 Z ref: M IH2 S IH0 S IH1 P IY0 Z cer: 0.1111
# 207 noranda's pred: N AO2 R AH0 N D AA1 Z ref: N AO0 R AE1 N D AH0 Z cer: 0.3750
# 208 altercations pred: AE2 L T ER0 K EY1 SH AH0 N Z ref: AA2 L T ER0 K EY1 SH AH0 N Z cer: 0.1000
# 209 overwhelming pred: OW1 V ER0 W EH2 L M IH0 NG ref: OW2 V ER0 W EH1 L M IH0 NG cer: 0.2222
# 210 enforces pred: EH1 N F AO0 R S IH0 Z ref: EH0 N F AO1 R S IH0 Z cer: 0.2500
# 211 reportedly pred: R IH0 P AO1 R T IH0 D L IY0 ref: R IH0 P AO1 R T AH0 D L IY0 cer: 0.1000
# 212 tricentrol pred: T R IH1 S AH0 N T R OW0 L ref: T R AY2 S EH1 N T R AA0 L cer: 0.3000
# 213 pontifical pred: P AA1 N T IH0 F AH0 K AH0 L ref: P AA0 N T IH1 F AH0 K AH0 L cer: 0.2000
# 214 intermittent pred: IH2 N T ER0 M IH1 T AH0 N T ref: IH2 N T ER0 M IH1 T AH0 N T cer: 0.0000
# 215 reacquired pred: R IY0 AE1 K W ER2 D ref: R IY0 AH0 K W AY1 R D cer: 0.3750
# 216 expropriated pred: IH0 K S P R OW1 P R IY0 EY2 T IH0 D ref: EH0 K S P R OW1 P R IY0 EY2 T IH0 D cer: 0.0769
# 217 autenrieth pred: AO1 T IY0 N R IY2 DH ref: AW1 T IH0 N R IY0 IH0 TH cer: 0.6250
# 218 donaldson's pred: D AA1 N AH0 L D S AH0 N Z ref: D AA1 N AH0 L D S AH0 N Z cer: 0.0000
# 219 amputate pred: AE1 M P Y UW0 T EY2 T ref: AE1 M P Y AH0 T EY2 T cer: 0.1250
# 220 bankcards pred: B AE1 NG K AE2 R D Z ref: B AE1 NG K AA2 R D Z cer: 0.1250
# 221 taliban's pred: T AE1 L AH0 B AH0 N Z ref: T AE1 L IH0 B AE2 N Z cer: 0.2500
# 222 overreacts pred: OW1 V ER0 R IY2 K T S ref: OW1 V ER0 R IY0 AE1 K T S cer: 0.2222
# 223 neutralizing pred: N UW1 T R AH0 L AY2 Z IH0 NG ref: N UW1 T R AH0 L AY2 Z IH0 NG cer: 0.0000
# 224 bighorns pred: B IH1 G ER0 N Z ref: B IH1 G HH AO2 R N Z cer: 0.3750
# 225 marianas pred: M AA0 R IY0 AA1 N AH0 Z ref: M EH2 R IY0 AE1 N AH0 S cer: 0.3750
# 226 obsessions pred: OW0 B S EH1 SH AH0 N Z ref: AH0 B S EH1 SH AH0 N Z cer: 0.1250
# 227 chujitsuya pred: CH UW0 Y UW1 T S UW2 IY0 AH0 ref: CH UW2 JH IY0 T S UW2 Y AA0 cer: 0.5556
# 228 astronautical pred: AE2 S T R AH0 N AA1 T IH0 K AH0 L ref: AE2 S T R AH0 N AA1 T IH0 K AH0 L cer: 0.0000
# 229 wranglings pred: R AA1 R JH L IH0 NG Z ref: R AE1 NG G AH0 L IH0 NG Z cer: 0.4444
# 230 catacosinos pred: K AE2 T AH0 K AA1 S IH0 N Z ref: K AH0 T AE2 K AH0 S IY1 N OW0 S cer: 0.5455
# 231 counteroffers pred: K AW1 N T ER0 AO2 F ER0 Z ref: K AW1 N T ER0 AO2 F ER0 Z cer: 0.0000
# 232 indigenous pred: IH2 N D IH0 G EH1 N AH0 S ref: IH2 N D IH1 JH AH0 N AH0 S cer: 0.3333
# 233 muhabara pred: M UW0 HH AA1 B AA0 R AA0 ref: M UW2 HH AH0 B AA1 R AH0 cer: 0.5000
# 234 disinfection pred: D IH2 S IH0 N F EH1 K SH AH0 N ref: D IH0 S IH0 N F EH1 K SH AH0 N cer: 0.0909
# 235 interlinked pred: IH2 N T ER0 L IH1 NG K ref: IH2 N T ER0 L IH1 NG K T cer: 0.1111
# 236 extensions pred: IH0 K S T EH1 N SH AH0 N Z ref: IH0 K S T EH1 N SH AH0 N Z cer: 0.0000
# 237 adjectives pred: AH0 JH ER1 T IH0 V Z ref: AE1 JH IH0 K T IH0 V Z cer: 0.3750
# 238 yoshimoto pred: Y OW2 SH IH0 M OW1 T OW0 ref: Y OW0 SH IY0 M OW1 T OW0 cer: 0.2500
# 239 instructions pred: IH2 N S T R AH1 K SH AH0 N Z ref: IH2 N S T R AH1 K SH AH0 N Z cer: 0.0000
# 240 kaffenberger pred: K AE1 F AH0 N B ER0 G ER0 ref: K AE1 F AH0 N B ER0 G ER0 cer: 0.0000
# 241 superheroes pred: S UW1 P ER0 HH ER0 OW0 Z ref: S UW2 P ER0 HH IY1 R OW0 Z cer: 0.3333
# 242 wenceslaus pred: W EH1 N S IH0 S W AH0 S ref: W EH1 N S AH0 S L AO2 S cer: 0.3333
# 243 harmoniously pred: HH AA2 R M AH0 N IY1 AH0 S L IY0 ref: HH AA0 R M OW1 N IY0 AH0 S L IY0 cer: 0.2727
# 244 one-sided pred: OW1 N AH0 S AY2 D IH0 D ref: W AH2 N S AY1 D AH0 D cer: 0.6250
# 245 submarine's pred: S AH0 B L AA1 R AH0 N Z ref: S AH1 B M ER0 IY2 N Z cer: 0.6250
# 246 gantenbein pred: G AE1 N T AH0 N B IY2 N ref: G AE1 N T IH0 N B AY0 N cer: 0.2222
# 247 diagnostics pred: D AY2 AH0 JH AA1 N OW0 S T IH0 K S ref: D AY2 AH0 G N AA1 S T IH0 K S cer: 0.2727
# 248 resembles pred: R EH1 Z AH0 M B AH0 L Z ref: R IH0 Z EH1 M B AH0 L Z cer: 0.2222
# 249 kafelnikov pred: K AH0 F EH1 L N IH0 K OW0 V ref: K AH0 F EH1 L N IH0 K AO2 F cer: 0.2000
# 250 infirmity pred: IH2 N F ER1 M AH0 T IY0 ref: IH0 N F ER1 M IH0 T IY0 cer: 0.2500
# 251 mouthparts pred: M AH1 DH P AA2 R T S ref: M AW1 TH P AA2 R T S cer: 0.2500
# 252 manderscheid pred: M AE1 N D ER0 CH IH0 D ref: M AE1 N D ER0 SH AY2 D cer: 0.2500
# 253 conference pred: K AH0 N F ER1 AH0 N S ref: K AA1 N F ER0 AH0 N S cer: 0.2500
# 254 grunewald pred: G R AH1 N W AO2 L D ref: G R AH1 N IH0 W AO0 L D cer: 0.2222
# 255 albritton pred: AE1 L B R AH0 T AA0 N ref: AE1 L B R IH0 T AA0 N cer: 0.1250
# 256 delafuente pred: D IH0 L AE1 F Y UW0 N T ref: D EY0 L AA0 F W EH1 N T EY0 cer: 0.5000
# 257 contadora pred: K AH0 N T EY1 D ER0 AH0 ref: K AA2 N T AH0 D AO1 R AH0 cer: 0.4444
# 258 rekindle pred: R IH0 K IH1 N D AH0 L ref: R IY0 K IH1 N D AH0 L cer: 0.1250
# 259 unglamorous pred: AH0 N JH L AE1 M ER0 AH0 S ref: AH0 N G L AE1 M ER0 AH0 S cer: 0.1111
# 260 augustinians pred: AE2 G UW0 S T IY1 N IY0 AH0 N Z ref: AA2 G AH0 S T IH1 N IY0 AH0 N Z cer: 0.2727
# 261 electricals pred: EH1 L AH0 K T R IH0 K L Z ref: IH0 L EH1 K T R IH0 K AH0 L Z cer: 0.2727
# 262 hamtramck pred: HH AE1 M T R AH0 M K ref: HH AE0 M T R AE1 M IH0 K cer: 0.3333
# 263 detoxification pred: D EH2 T AH0 K S F IH1 K AH0 T EY2 SH AH0 N ref: D IH0 T AA2 K S IH0 F IH0 K EY1 SH AH0 N cer: 0.5000
# 264 misprints pred: M IH0 S P R AY1 N T S ref: M IH1 S P R IH1 N T S cer: 0.2222
# 265 expansive pred: IH0 K S P AE1 N S IH0 V ref: IH0 K S P AE1 N S IH0 V cer: 0.0000
# 266 lithuania pred: L IH2 T UW0 HH EY1 N IY0 AH0 ref: L IH2 TH AH0 W EY1 N IY0 AH0 cer: 0.3333
# 267 arianism pred: AA0 R IY0 AE1 N IH0 Z AH0 M ref: AE1 R IY0 AH0 N IH2 Z AH0 M cer: 0.3333
# 268 dusenbery pred: D UW1 S AH0 N B EH2 R IY0 ref: D AH0 S EH1 N B ER0 IY0 cer: 0.5000
# 269 lekachman pred: L EH1 K AH0 CH M AH0 N ref: L EH1 K AA2 K M AH0 N cer: 0.2500
# 270 militarists pred: M IH1 L AH0 T EH2 R IH0 S T S ref: M IH1 L AH0 T ER0 IH0 S T S cer: 0.2000
# 271 mothershead pred: M AH1 DH ER0 SH AH0 D ref: M AH1 DH ER0 Z HH EH2 D cer: 0.3750
# 272 nonfiction pred: N AA0 N F IH1 K SH AH0 N ref: N AA0 N F IH1 K SH AH0 N cer: 0.0000
# 273 irrational pred: IH2 R AE1 SH AH0 N AH0 L ref: IH2 R AE1 SH AH0 N AH0 L cer: 0.0000
# 274 parachuting pred: P AA1 R AH0 CH UW2 T IH0 NG ref: P EH1 R AH0 SH UW2 T IH0 NG cer: 0.2222
# 275 somaliland pred: S AA1 M AH0 L AY2 L AH0 N D ref: S AH0 M AA1 L IY0 L AE2 N D cer: 0.4000
# 276 graphically pred: G R AE1 F IH0 K L IY0 ref: G R AE1 F IH0 K L IY0 cer: 0.0000
# 277 pendergast pred: P EH1 N D ER0 G AH0 S T ref: P EH1 N D ER0 G AE2 S T cer: 0.1111
# 278 tousignant pred: T UW1 Z IH0 T N AH0 N T ref: T UW1 S IH0 G N AH0 N T cer: 0.2222
# 279 himmelberger pred: HH IH1 M AH0 L B ER0 G ER0 ref: HH IH1 M AH0 L B ER0 G ER0 cer: 0.0000
# 280 analyzing pred: AE1 N AH0 L AY2 Z IH0 NG ref: AE1 N AH0 L AY2 Z IH0 NG cer: 0.0000
# 281 unashamedly pred: AH0 N AE1 SH AH0 M D AH0 L IY0 ref: AH2 N AH0 SH EY1 M AH0 D L IY0 cer: 0.5000
# 282 cyclamen pred: S IH1 K L AH0 M AH0 N ref: S AY1 K L AH0 M EH2 N cer: 0.2500
# 283 demodulates pred: D IH0 M AA1 D AH0 L EY0 T S ref: D IY2 M AA2 JH AH0 L EY1 T S cer: 0.4000
# 284 interoperates pred: IH2 N T ER0 AA1 P ER0 AH0 T S ref: IH2 N T ER0 AO1 P ER0 AH0 T S cer: 0.1000
# 285 handicapper pred: HH AE1 N D IH0 K AH0 P ER0 ref: HH AE1 N D IY0 K AE2 P ER0 cer: 0.2222
# 286 stuyvesant pred: S T UW1 V IH0 S T ref: S T AY1 V AH0 S AH0 N T cer: 0.4444
# 287 mccleary's pred: M AH0 K L EH1 R IY0 Z ref: M AH0 K L IH1 R IY0 Z cer: 0.1250
# 288 proficiency pred: P R AH0 F IH1 SH AH0 N S IY0 ref: P R AH0 F IH1 SH AH0 N S IY0 cer: 0.0000
# 289 gift-horse pred: G IH1 T F AO2 R S ref: G IH1 F T HH AO1 R S cer: 0.3750
# 290 horsemanship pred: HH AO1 R S AH0 M SH AH0 N S IH0 P ref: HH AO1 R S M AH0 N SH IH0 P cer: 0.3000
# 291 protocols pred: P R OW1 T OW0 K AA2 L Z ref: P R OW1 T AH0 K AO2 L Z cer: 0.2222
# 292 templeton's pred: T EH1 M P L AH0 N AH0 S ref: T EH1 M P AH0 L T AH0 N Z cer: 0.4000
# 293 jonbenet's pred: JH OW1 NG AH0 N T S ref: JH AO1 N B AH0 N EY1 S cer: 0.5000
# 294 harbinger pred: HH AA1 R B IH0 NG ER0 ref: HH AA1 R B IH0 N JH ER0 cer: 0.2500
# 295 edification pred: EH2 D AH0 F AH0 K EY1 SH AH0 N ref: EH2 D AH0 F AH0 K EY1 SH AH0 N cer: 0.0000
# 296 cherrystones pred: SH EH1 R IY0 S T OW2 N Z ref: CH EH1 R IY0 S T OW2 N Z cer: 0.1111
# 297 overemphasizes pred: OW2 V ER0 M EH1 M IH0 Z ref: OW1 V ER0 EH1 M F AH0 S AY2 Z IH0 Z cer: 0.5833
# 298 clydesdale pred: K L AY1 D S T EH2 L ref: K L AY1 D Z D EY2 L cer: 0.3750
# 299 goldmark pred: G OW1 L D M AA2 R K ref: G OW1 L D M AA2 R K cer: 0.0000
# 300 drinkwater pred: D R IH1 NG K W AO2 T ER0 ref: D R IH1 NG K W AO2 T ER0 cer: 0.0000
# 301 destructed pred: D IH0 S T R AH1 K T IH0 D ref: D IH0 S T R AH1 K T IH0 D cer: 0.0000
# 302 stockholdings pred: S T AA1 K HH OW2 L D IH0 NG Z ref: S T AA1 K HH OW2 L D IH0 NG Z cer: 0.0000
# 303 friendship pred: F R IY1 N D SH IH2 P ref: F R EH1 N D SH IH0 P cer: 0.2500
# 304 isolated pred: IH1 Z AH0 L EY2 T IH0 D ref: AY1 S AH0 L EY2 T AH0 D cer: 0.3750
# 305 konishiroku pred: K AH0 N IH0 SH IH1 R OW0 K ref: K AA2 N IH2 SH IH0 R OW1 K UW2 cer: 0.5000
# 306 arcement pred: AA1 R K AH0 M AH0 N T ref: AA0 R S EY1 M AH0 N T cer: 0.3750
# 307 crackpots pred: K R AE1 K P OW2 T S ref: K R AE1 K P AA2 T S cer: 0.1250
# 308 tapestry pred: T EY1 P S T R IY0 ref: T AE1 P AH0 S T R IY0 cer: 0.2500
# 309 krogstad pred: K R AA1 NG S T IH0 D ref: K R AA1 G S T AH0 D cer: 0.2500
# 310 peterson's pred: P EH1 T ER0 S AH0 N Z ref: P IY1 T ER0 S AH0 N Z cer: 0.1250
# 311 experimentally pred: EH2 K S P ER0 AH0 M EH1 N T AH0 L IY0 ref: IH0 K S P EH2 R AH0 M EH1 N T AH0 L IY0 cer: 0.2143
# 312 humbarger pred: HH Y UW1 M B AA0 R G ER0 ref: HH AH1 M B AA2 R G ER0 cer: 0.3750
# 313 ragavan's pred: R AE1 G AH0 V AH0 N Z ref: R AA1 G AH0 V AA2 N Z cer: 0.2500
# 314 dedicating pred: D EH1 D AH0 K EY2 T IH0 NG ref: D EH1 D IH0 K EY2 T IH0 NG cer: 0.1111
# 315 legislating pred: L EH1 JH AH0 S L EY2 T IH0 NG ref: L EH1 JH IH0 S L EY2 T IH0 NG cer: 0.1000
# 316 participated pred: P AA1 R T IH0 S IH2 P EY2 T IH0 D ref: P AA0 R T IH1 S AH0 P EY2 T IH0 D cer: 0.2500
# 317 cassandras pred: K AE1 S AH0 N D R AH0 S ref: K AH0 S AE1 N D R AH0 S cer: 0.2222
# 318 mcmillon pred: M AH0 K M IH1 L AH0 N ref: M AH0 K M IH1 L AH0 N cer: 0.0000
# 319 ustrust pred: AH0 S T R AH1 S T ref: Y UW1 EH1 S T R AH1 S T cer: 0.3333
# 320 transnational pred: T R AE2 N Z N EY1 SH AH0 N AH0 L ref: T R AE0 N S N AE1 SH AH0 N AH0 L cer: 0.2500
# 321 mcingvale pred: M AH0 K IH1 NG G W AO2 L ref: M AE1 K IH0 NG V EY2 L cer: 0.6250
# 322 hornstein pred: HH AO1 R N S T AY2 N ref: HH AO1 R N S T AY2 N cer: 0.0000
# 323 rebounded pred: R IH0 B AW1 N D IH0 D ref: R IY0 B AW1 N D IH0 D cer: 0.1250
# 324 prosecuting pred: P R AA1 S IH0 K Y UW0 T IH0 NG ref: P R AA1 S IH0 K Y UW2 T IH0 NG cer: 0.0909
# 325 richmond's pred: R IH1 K M AH0 N D Z ref: R IH1 CH M AH0 N D Z cer: 0.1250
# 326 pentagons pred: P EH1 N T AH0 G AH0 N Z ref: P EH1 N T IH0 G AA2 N Z cer: 0.2222
# 327 cywinski pred: S W IH1 N S K IY0 ref: K IH0 V IH1 N S K IY0 cer: 0.3750
# 328 waldheim's pred: W AO1 L D HH AY2 M Z ref: W AO1 L D HH AY2 M Z cer: 0.0000
# 329 forfeiting pred: F AO1 R F AH0 T IH0 NG ref: F AO1 R F AH0 T IH0 NG cer: 0.0000
# 330 forgettable pred: F AO1 R G AH0 T AH0 B AH0 L ref: F AO0 R G EH1 T AH0 B AH0 L cer: 0.2000
# 331 interpreted pred: IH2 N T ER0 P R EH1 T IH0 D ref: IH2 N T ER1 P R AH0 T AH0 D cer: 0.3000
# 332 advisedly pred: AH0 D V IH1 Z AH0 L IY0 ref: AE0 D V AY1 Z AH0 D L IY0 cer: 0.3333
# 333 ukrainians pred: Y UW0 K R EY1 N IY0 AH0 N Z ref: Y UW0 K R EY1 N IY0 AH0 N Z cer: 0.0000
# 334 pornographic pred: P AO2 R N AH0 G R AE1 F IH0 K ref: P AO2 R N AH0 G R AE1 F IH0 K cer: 0.0000
# 335 cardiologist pred: K AA0 R D IY0 OW1 L AH0 JH IH0 S T ref: K AA2 R D IY0 AA1 L AH0 JH IH0 S T cer: 0.1667
# 336 mcelravy pred: M AH0 K EH1 L R AH0 V IY0 ref: M AE1 K AH0 L R EY2 V IY0 cer: 0.3333
# 337 bottenfield pred: B AA1 T AH0 N F IY0 L D ref: B AH0 T EH1 N F IY0 L D cer: 0.2222
# 338 allegis's pred: AE1 L AH0 G IH0 S IH0 Z ref: AE2 L EY1 JH IH0 S IH0 Z cer: 0.3750
# 339 omnibank pred: AA1 M N AH0 B AE0 NG K ref: AA1 M N IH0 B AE2 NG K cer: 0.2500
# 340 uncovering pred: AH0 N K AH1 V ER0 IH0 NG ref: AH0 N K AH1 V ER0 IH0 NG cer: 0.0000
# 341 humidity pred: HH Y UW0 M IH1 D AH0 T IY0 ref: HH Y UW0 M IH1 D AH0 T IY0 cer: 0.0000
# 342 newslink's pred: N UW1 Z L AY2 K S ref: N UW1 Z L IH0 NG K S cer: 0.2500
# 343 littlest pred: L IH1 T AH0 L S T ref: L IH1 T AH0 L AH0 S T cer: 0.1250
# 344 quantifying pred: K W AA1 N T IH0 F AY2 IH0 NG ref: K W AA1 N T IH0 F AY2 IH0 NG cer: 0.0000
# 345 thorniest pred: TH AO1 R N IY0 AH0 S T ref: TH AO1 R N IY0 AH0 S T cer: 0.0000
# 346 lomonaco pred: L AA0 M OW0 N AA1 T OW0 ref: L OW0 M OW0 N AA1 K OW0 cer: 0.2500
# 347 spectrograph pred: S P EH1 K T R AH0 G R AE0 F ref: S P EH1 K T R AH0 G R AE2 F cer: 0.0909
# 348 nonvolatile pred: N AA0 N V OW1 L EY0 T IY0 ref: N AA0 N V AA1 L AH0 T AH0 L cer: 0.4000
# 349 ljubljana pred: L UW0 B L G AA1 N AA0 ref: L Y UW1 B L Y AA0 N AH0 cer: 0.5556
# 350 likeliest pred: L IH1 K AH0 L AY2 S T ref: L AY1 K L IY0 AH0 S T cer: 0.5000
# 351 angleton pred: AE1 NG L AH0 T AH0 N ref: AE1 NG G AH0 L T AH0 N cer: 0.2500
# 352 polakowski pred: P AA2 L AH0 K AO1 F S K IY0 ref: P AH0 L AH0 K AO1 F S K IY0 cer: 0.1000
# 353 entomologist pred: EH2 N T AH0 M AA1 L AH0 JH IH0 S T ref: EH2 N T AH0 M AA1 L AH0 JH AH0 S T cer: 0.0833
# 354 longstreth pred: L AO1 NG S T R AH0 TH ref: L AA1 NG S T R EH0 TH cer: 0.2500
# 355 steinbrink pred: S T AY1 N B R IH0 NG K ref: S T AY1 N B R IH2 NG K cer: 0.1111
# 356 mormonism pred: M AO1 R M AH0 N IH2 Z AH0 M ref: M AO1 R M AH0 N IH0 Z M cer: 0.2222
# 357 assailants pred: AH0 S EY1 L AH0 N T S ref: AH0 S EY1 L AH0 N T S cer: 0.0000
# 358 attributable pred: AH0 T R IH1 B Y UW0 T AE2 B AH0 L ref: AH0 T R IH1 B Y AH0 T AH0 B AH0 L cer: 0.1667
# 359 rotational pred: R OW0 T EY1 SH AH0 N AH0 L ref: R OW0 T EY1 SH AH0 N AH0 L cer: 0.0000
# 360 repetitious pred: R EH2 P AH0 T IH1 SH AH0 S ref: R EH2 P AH0 T IH1 SH AH0 S cer: 0.0000
# 361 hawkinson pred: HH AO1 K IH0 N S AH0 N ref: HH AO1 K IH0 N S AH0 N cer: 0.0000
# 362 subordination pred: S UW0 B AO2 R D IH0 N EY1 SH AH0 N ref: S AH0 B AO2 R D AH0 N EY1 SH AH0 N cer: 0.1667
# 363 transitory pred: T R AE0 N Z IH1 T ER0 IY0 ref: T R AE1 N Z AH0 T AO2 R IY0 cer: 0.4000
# 364 incomparable pred: IH2 N K AA1 M P AA2 R AH0 B AH0 L ref: IH2 N K AA1 M P ER0 AH0 B AH0 L cer: 0.1818
# 365 ferguson's pred: F EH1 R G AH2 S AH0 N Z ref: F ER1 G AH0 S AH0 N Z cer: 0.3750
# 366 sandhogs pred: S AE1 N D HH AO2 G Z ref: S AE1 N D HH AO2 G Z cer: 0.0000
# 367 schoolgirls pred: L AH1 L G IH0 L Z ref: S K UW1 L G ER2 L Z cer: 0.5000
# 368 metrically pred: M EH1 T R AH0 K AH0 L IY0 ref: M EH1 T R IH0 K AH0 L IY0 cer: 0.1111
# 369 castration pred: K AA0 S T R EY1 SH AH0 N ref: K AE2 S T R EY1 SH AH0 N cer: 0.1111
# 370 liberalism's pred: L AY1 B ER2 AH0 L IH2 Z AH0 M Z ref: L IH1 B ER2 AH0 L IH2 Z AH0 M Z cer: 0.0909
# 371 introduce pred: IH2 N T R AA1 D AH0 S ref: IH2 N T R AH0 D UW1 S cer: 0.2500
# 372 alleviating pred: AE2 L AH0 V IY1 AH0 T IH0 NG ref: AH0 L IY1 V IY0 EY2 T IH0 NG cer: 0.4444
# 373 refurbishment pred: R IH0 F ER1 B IH0 SH M AH0 N T ref: R IY0 F ER1 B IH0 SH M AH0 N T cer: 0.0909
# 374 closeted pred: K L OW1 S T EH2 D ref: K L AA1 Z AH0 T IH0 D cer: 0.5000
# 375 linguists pred: L IH1 NG G Y UW0 S T S ref: L IH1 NG G W IH0 S T S cer: 0.2222
# 376 adoptions pred: AH0 D AA1 P SH AH0 N Z ref: AH0 D AA1 P SH AH0 N Z cer: 0.0000
# 377 unadorned pred: AH0 N EY1 D AO0 R N IH0 D ref: AH2 N AH0 D AO1 R N D cer: 0.5000
# 378 snowboards pred: S N OW1 B AO2 R D Z ref: S N OW1 B AO2 R D Z cer: 0.0000
# 379 perquisite pred: P ER0 K W IH1 Z IH0 T ref: P ER1 K W AH0 Z IH0 T cer: 0.2500
# 380 transparently pred: T R AE1 N S P AA2 R AH0 L IY0 ref: T R AE0 N S P EH1 R AH0 N T L IY0 cer: 0.3077
# 381 cross-pollinate pred: K R AO1 S P OW2 L AH0 N EY2 T ref: K R AO1 S P AA2 L AH0 N EY2 T cer: 0.0909
# 382 children's pred: CH AY1 L D R AH0 N Z ref: CH IH1 L D R AH0 N Z cer: 0.1250
# 383 semolina pred: S EH2 M OW0 L IH1 N AH0 ref: S EH2 M AH0 L IY1 N AH0 cer: 0.2500
# 384 buthelezi pred: B AH1 DH AH0 L AH0 Z AY2 ref: B UW2 T AH0 L EY1 Z IY0 cer: 0.5000
# 385 sympathized pred: S IH1 M P AH0 TH AY2 Z D ref: S IH1 M P AH0 TH AY2 Z D cer: 0.0000
# 386 morganti pred: M AO0 R G AE1 N T IY0 ref: M AO0 R G AA1 N T IY0 cer: 0.1250
# 387 amalgams pred: AE1 M AH0 L G AA0 M Z ref: AH0 M AE1 L G AH0 M Z cer: 0.3750
# 388 loeffelholz pred: L OW1 F AH0 L HH OW0 L Z ref: L OW1 F IH0 L HH OW0 L Z cer: 0.1111
# 389 hallenbeck pred: HH AO1 L AH0 N B EH0 K ref: HH AO1 L AH0 N B EH2 K cer: 0.1250
# 390 agrivisor pred: AE1 G R IH0 V IH2 R ER0 ref: AE1 G R AH0 V AY2 Z ER0 cer: 0.3750
# 391 montezuma pred: M OW0 N T EH1 T AH0 M AH0 ref: M AA2 N T IH0 Z UW1 M AH0 cer: 0.4444
# 392 convention's pred: K AH0 N V IY1 N SH AH0 N Z ref: K AH0 N V EH1 N SH AH0 N Z cer: 0.1000
# 393 unjustified pred: AH0 N JH AH1 S T IH0 F AY2 D ref: AH0 N JH AH1 S T AH0 F AY2 D cer: 0.1000
# 394 marketscope pred: M AA1 R K AH0 T S AA2 P ref: M AA1 R K AH0 T S K OW2 P cer: 0.2000
# 395 interdigital pred: IH2 N T ER0 D IH1 JH AH0 T AH0 L ref: IH2 N T ER0 D IH1 JH AH0 T AH0 L cer: 0.0000
# 396 swartzentruber pred: S W AO1 R T S AH0 N T R ref: S W AO1 R T S AH0 N T R UW0 B ER0 cer: 0.2308
# 397 incidents pred: IH1 N S AH0 D AH0 N T S ref: IH1 N S AH0 D AH0 N T S cer: 0.0000
# 398 non-proliferation pred: N AA2 N P R AH0 L IH1 F ER0 EY2 SH AH0 N ref: N AA0 N P R AO0 L IH2 F ER0 EY1 SH AH0 N cer: 0.2857
# 399 gorczynski pred: G AO1 R CH AY2 N S K IY0 ref: G ER0 CH IH1 N S K IY0 cer: 0.3750
# 400 directorships pred: D ER0 EH1 K T ER0 SH IH2 P S ref: D ER0 EH1 K T ER0 SH IH2 P S cer: 0.0000
# 401 homeland's pred: HH OW1 M L AH0 N D Z ref: HH OW1 M L AE2 N D Z cer: 0.1250
# 402 mantione pred: M AA0 N T IY0 OW1 N IY0 ref: M AA0 N T IY0 OW1 N IY0 cer: 0.0000
# 403 companies's pred: K AH0 M AE1 N IY0 Z ref: K AH1 M P AH0 N IY0 Z IH0 Z cer: 0.5000
# 404 quietness pred: K W IY1 T N AH0 S ref: K W AY1 AH0 T N AH0 S cer: 0.2500
# 405 distinctiveness pred: D IH0 S T IH1 NG K T IH0 V N AH0 S ref: D IH0 S T IH1 NG K T IH0 V N AH0 S cer: 0.0000
# 406 solidarity pred: S AH0 L IH1 D AH0 T IY0 ref: S AA2 L AH0 D EH1 R AH0 T IY0 cer: 0.4000
# 407 stellmacher pred: S T EH1 L M EY2 K ER0 ref: S T EH1 L M AH0 K ER0 cer: 0.1250
# 408 milliseconds pred: M IH1 L AH0 S EH2 K N D Z ref: M IH1 L IH0 S EH2 K AH0 N D Z cer: 0.1818
# 409 parchment pred: P AA1 R K M AH0 N T ref: P AA1 R CH M AH0 N T cer: 0.1250
# 410 schulenberg pred: SH UH1 L AH0 N B ER0 G ref: SH UW1 L AH0 N B ER0 G cer: 0.1250
# 411 facility pred: F AH0 S IH1 L AH0 T IY0 ref: F AH0 S IH1 L IH0 T IY0 cer: 0.1250
# 412 dyslexic pred: D AY1 S L EH2 K S IH0 K ref: D IH0 S L EH1 K S IH0 K cer: 0.2222
# 413 stadium's pred: S T EY1 D IY0 AH0 M Z ref: S T EY1 D IY0 AH0 M Z cer: 0.0000
# 414 beleaguering pred: B EH1 L AH0 G Y UH0 R IH0 NG ref: B IH0 L IY1 G ER0 IH0 NG cer: 0.6250
# 415 investigation pred: IH2 N V EH2 S T AH0 G EY1 SH AH0 N ref: IH2 N V EH2 S T AH0 G EY1 SH AH0 N cer: 0.0000
# 416 granada's pred: G R AE1 N AH0 D AH0 Z ref: G R AH0 N AA1 D AH0 Z cer: 0.2500
# 417 permeating pred: P ER0 M EY1 T IH0 NG ref: P ER1 M IY0 EY2 T IH0 NG cer: 0.3750
# 418 discounters pred: D IH0 S K AH1 N T ER0 Z ref: D IH0 S K AW1 N T ER0 Z cer: 0.1111
# 419 whimsical pred: W IH1 M S IH0 K AH0 L ref: W IH1 M Z IH0 K AH0 L cer: 0.1250
# 420 portraying pred: P AO1 R T R IY2 IH0 NG ref: P AO0 R T R EY1 IH0 NG cer: 0.2500
# 421 religione pred: R IH0 L IH1 JH AH0 N ref: R IH0 L IH2 JH IY0 OW1 N IY0 cer: 0.4444
# 422 verizons pred: V EH1 R IH0 Z AH0 N Z ref: V EH2 R AY1 Z AH0 N Z cer: 0.2500
# 423 macedonian pred: M AH0 S EH1 D AH0 N IY0 AH0 N ref: M AE2 S AH0 D OW1 N Y AH0 N cer: 0.4000
# 424 afrocentric pred: AE2 F R OW0 S EH1 N T R IH0 K ref: AE1 F R OW0 S EH1 N T R IH0 K cer: 0.0909
# 425 self-governing pred: S EH1 L F G AA2 V ER0 IH0 NG ref: S EH1 L F G AH1 V ER0 N IH0 NG cer: 0.1818
# 426 red-herrings pred: R EH1 D HH R AY2 N JH Z ref: R EH1 D HH EH1 R IH0 NG Z cer: 0.4444
# 427 underscoring pred: AH2 N D ER0 S K AO1 R IH0 NG ref: AH2 N D ER0 S K AO1 R IH0 NG cer: 0.0000
# 428 mcgarrigle pred: M AH0 G AE1 R IH0 G L ref: M AH0 G AE1 R AH0 G AH0 L cer: 0.2222
# 429 globetrotter pred: G L AO1 B IH0 T R OW0 T ER0 ref: G L OW1 B T R AO0 T ER0 cer: 0.3333
# 430 melodious pred: M AH0 L AA1 D IY0 AH0 S ref: M AH0 L OW1 D IY0 AH0 S cer: 0.1250
# 431 westwards pred: W EH1 S T W AO2 R D Z ref: W EH1 S T W ER0 D Z cer: 0.2500
# 432 mutagens pred: M Y UW1 T AH0 JH AH0 N Z ref: M Y UW1 T AH0 JH EH0 N Z cer: 0.1111
# 433 shipbuilder pred: SH IH1 P B AY2 L D ER0 ref: SH IH1 P B IH2 L D ER0 cer: 0.1250
# 434 religiously pred: R IH0 L IH1 JH AH0 S L IY0 ref: R IH0 L IH1 JH AH0 S L IY0 cer: 0.0000
# 435 exhaustive pred: IH0 G Z AO1 S T IH0 V ref: IH0 G Z AO1 S T IH0 V cer: 0.0000
# 436 accompanying pred: AH0 K AA1 M P AH0 N IH0 NG ref: AH0 K AH1 M P AH0 N IY0 IH0 NG cer: 0.2000
# 437 aramaic pred: AA0 R AA0 M EY1 K ref: AA2 R AA0 M EH1 Y IH0 K cer: 0.5000
# 438 collinson pred: K AH0 L IH1 N S AH0 N ref: K AA1 L IH0 N S AH0 N cer: 0.2500
# 439 disorders pred: D IH0 S AO1 R D ER0 Z ref: D IH0 S AO1 R D ER0 Z cer: 0.0000
# 440 seminoles pred: S EH1 M IH0 N AH0 L Z ref: S EH1 M IH0 N OW2 L Z cer: 0.1250
# 441 standalone pred: S T AE1 N D AH0 L AH0 N ref: S T AE1 N D AH0 L OW2 N cer: 0.1111
# 442 negligence pred: N EH1 G L AH0 JH AH0 N S ref: N EH1 G L AH0 JH AH0 N S cer: 0.0000
# 443 fresenius pred: F R EH1 S AH0 N Y AH0 S ref: F R AH0 S IY1 N IY0 AH0 S cer: 0.3333
# 444 speechwriters pred: S P IY1 CH R AY2 T ER0 Z ref: S P IY1 CH R AY2 T ER0 Z cer: 0.0000
# 445 persevering pred: P ER0 S EH1 V ER0 IH0 NG ref: P ER0 S AH0 V IH1 R IH0 NG cer: 0.3333
# 446 inflexibility pred: IH2 N F L EH2 K S AH0 B IH1 L IH0 T IY0 ref: IH2 N F L EH2 K S IH0 B IH1 L IH0 T IY0 cer: 0.0714
# 447 guantanamo pred: G W AA2 N T AH0 N AA1 M OW0 ref: G W AA2 N T AA1 N AH0 M OW2 cer: 0.3000
# 448 hardison pred: HH AA1 R D IH0 S AH0 N ref: HH AA1 R D IH0 S AH0 N cer: 0.0000
# 449 podcaster pred: P AA1 D K AE2 S T ER0 ref: P AO1 D K AE2 S T ER0 cer: 0.1250
# 450 dissipation pred: D IH2 S IH0 P AE1 SH AH0 N ref: D IH2 S IH0 P EY1 SH AH0 N cer: 0.1111
# 451 josephine's pred: JH AA1 S HH EH2 N Z ref: JH OW1 S AH0 F IY2 N Z cer: 0.5000
# 452 contemporaneous pred: K AA2 N T AH0 M P AO1 R AH0 N IY0 AH0 S ref: K AH0 N T EH2 M P ER0 EY1 N IY0 AH0 S cer: 0.3846
# 453 desensitize pred: D EH1 Z AH0 N S IH0 T IH0 Z ref: D IH0 S EH1 N S AH0 T AY2 Z cer: 0.5000
# 454 presumptuous pred: P R EH1 ZH AH0 M P CH UW0 AH0 S ref: P R IH0 Z AH1 M P CH AH0 W AH0 S cer: 0.4167
# 455 lysistrata pred: L IH1 S IH0 S T R EY2 T AH0 ref: L AY2 S IH0 S T R AA1 T AH0 cer: 0.2000
# 456 jonassaint pred: JH AA1 N AH0 S EY2 N T ref: JH OW2 N AH0 S EY1 N T cer: 0.2500
# 457 desiderata pred: D EH2 Z AH0 D IH1 R AH0 T AH0 ref: D EY2 Z IH0 D ER0 AA1 T AH0 cer: 0.5556
# 458 tapestries pred: T EY1 P S T R IY2 Z ref: T AE1 P AH0 S T R IY0 Z cer: 0.3333
# 459 templates pred: T EH1 M P L EY2 T S ref: T EH1 M P L AH0 T S cer: 0.1250
# 460 superlative pred: S UW1 P ER0 L EY2 T IH0 V ref: S UH0 P ER1 L AH0 T IH0 V cer: 0.3333
# 461 deflection pred: D IH0 F L EH1 K SH AH0 N ref: D IH0 F L EH1 K SH AH0 N cer: 0.0000
# 462 excluding pred: IH0 K S K L UW1 D IH0 NG ref: IH0 K S K L UW1 D IH0 NG cer: 0.0000
# 463 trivialized pred: T R AY1 V IY0 AH0 L AY2 Z D ref: T R IH1 V IY0 AH0 L AY2 Z D cer: 0.1000
# 464 stanislav pred: S T AE1 N IH0 L AH0 V ref: S T AE1 N IH0 S L AA0 V cer: 0.2222
# 465 vacuuming pred: V AH0 K Y UW1 M IH0 NG ref: V AE1 K Y UW0 M IH0 NG cer: 0.2500
# 466 recruitment pred: R IY0 K R UW1 T M AH0 N T ref: R AH0 K R UW1 T M AH0 N T cer: 0.1000
# 467 immiscible pred: IH2 M IH1 S IH0 B AH0 L ref: IH2 M IH1 S AH0 B AH0 L cer: 0.1250
# 468 overstaffed pred: OW1 V ER0 S T AE2 F T ref: OW1 V ER0 S T AE2 F T cer: 0.0000
# 469 cadences pred: K EY1 D AH0 N S IH0 Z ref: K EY1 D AH0 N S IH0 Z cer: 0.0000
# 470 blankinship pred: B L AE1 NG K IH0 SH N IH0 P ref: B L AE1 NG K IH0 N SH IH0 P cer: 0.2000
# 471 circulatory pred: S ER1 K Y AH0 L EY2 T ER0 IY0 ref: S ER1 K Y AH0 L AH0 T AO2 R IY0 cer: 0.2727
# 472 congruent pred: K AA1 NG G R AH0 N T ref: K AO1 N G R UW0 EH2 N T cer: 0.4444
# 473 gruenhagen pred: G R UW1 N HH AE2 G AH0 N ref: G R UH1 N HH AH0 G AH0 N cer: 0.2222
# 474 vehicle's pred: V EH1 V IH0 K AH0 L Z ref: V IY1 HH IH0 K AH0 L Z cer: 0.2500
# 475 canonization pred: K AE2 N AH0 N AH0 Z EY1 SH AH0 N ref: K AE2 N AH0 N AH0 Z EY1 SH AH0 N cer: 0.0000
# 476 transcribed pred: T R AE1 N Z K R AY2 B D ref: T R AE0 N S K R AY1 B D cer: 0.3000
# 477 graceland pred: G R EY1 S L AH0 N D ref: G R EY1 S L AE0 N D cer: 0.1250
# 478 apartment pred: AH0 P EH1 R T M AH0 N T ref: AH0 P AA1 R T M AH0 N T cer: 0.1111
# 479 watermarks pred: W AO1 T ER0 M AA2 R K S ref: W AO1 T ER0 M AA2 R K S cer: 0.0000
# 480 surprising pred: S ER0 P R IH1 Z IH0 NG ref: S ER0 P R AY1 Z IH0 NG cer: 0.1250
# 481 flagofficer pred: F L AE1 G AH0 F IH2 K ER0 ref: F L AE1 G AO0 F AH0 S ER0 cer: 0.3333
# 482 morihiro pred: M AO0 R IY0 HH IH1 R OW0 ref: M AO0 R IY0 HH IH1 R OW0 cer: 0.0000
# 483 daigrepont pred: D EY1 G R AH0 P SH AH0 N T ref: D EY1 G R IH0 P AA0 N T cer: 0.3333
# 484 granddaughter's pred: G R AE1 N D AH0 T ER2 Z ref: G R AE1 N D AO2 T ER0 Z cer: 0.2222
# 485 nobility pred: N OW0 B IH1 L AH0 T IY0 ref: N OW0 B IH1 L AH0 T IY0 cer: 0.0000
# 486 transits pred: T R AE1 N Z IH0 T S ref: T R AE1 N Z IH0 T S cer: 0.0000
# 487 infraction pred: IH2 N F R AE1 K SH AH0 N ref: IH2 N F R AE1 K SH AH0 N cer: 0.0000
# 488 amusingly pred: AH0 M Y UW1 Z IH0 NG L IY0 ref: AH0 M Y UW1 Z IH0 NG L IY0 cer: 0.0000
# 489 residency pred: R IH0 Z IH1 D AH0 N S IY0 ref: R EH1 Z IH0 D AH0 N S IY0 cer: 0.2222
# 490 nutcracker pred: N UW0 T K AE1 K ER0 ref: N AH1 T K R AE2 K ER0 cer: 0.3750
# 491 biologically pred: B IY0 OW0 L AA1 JH IH0 K L IY0 ref: B AY0 AH0 L AA1 JH IH0 K L IY0 cer: 0.2000
# 492 scaleatron pred: S K AE1 L AH0 T R AA0 N S ref: S K EY1 L IY0 AH0 T R AA0 N cer: 0.3000
# 493 byelorussia pred: B IY0 L AO2 R AH0 S IH1 SH AH0 ref: B AY2 AH0 L OW0 R AH1 SH AH0 cer: 0.6667
# 494 delbarco's pred: D EH1 L B AA0 R K OW0 Z ref: D EH0 L B AA1 R K OW0 Z cer: 0.2222
# 495 tamburrino pred: T AA0 M B ER0 IH1 N OW0 ref: T AA0 M B UH0 R IY1 N OW0 cer: 0.3333
# 496 landscaping pred: L AE1 N D S K EY2 P IH0 NG ref: L AE1 N D S K EY2 P IH0 NG cer: 0.0000
# 497 lowdermilk pred: L AO1 D ER0 M IH2 L K ref: L OW0 D ER1 M IH0 L K cer: 0.3750
# 498 amphitheaters pred: AE1 M F AH0 T IH1 T ER0 Z ref: AE1 M F AH0 TH IY0 EY1 T ER0 Z cer: 0.3000
# 499 refrigerator pred: R IH0 F R IH1 JH ER0 EY2 T ER0 ref: R AH0 F R IH1 JH ER0 EY2 T ER0 cer: 0.1000
# 500 landmark pred: L AE1 N D M AA2 R K ref: L AE1 N D M AA2 R K cer: 0.0000
# 501 artichokes pred: AA1 R T IH0 K OW0 K S ref: AA1 R T IH0 CH OW2 K S cer: 0.2500
# 502 zamarripa pred: R AA0 M AA0 R IY1 P AH0 ref: Z AA2 M AA0 R IY1 P AA0 cer: 0.3750
# 503 prospectus pred: P R AA1 S P EH2 K CH IH0 S ref: P R AH0 S P EH1 K T AH0 S cer: 0.4000
# 504 pagliuca's pred: P AE2 G L IY0 K AA1 K AH0 Z ref: P AE2 G L IY0 UW1 K AH0 Z cer: 0.2222
# 505 salveson pred: S AE1 L V AH0 S N AA0 N ref: S AA0 L V EY1 S AH0 N cer: 0.5000
# 506 activism pred: AE1 K T AH0 V IH2 Z AH0 M ref: AE1 K T IH0 V IH2 Z AH0 M cer: 0.1111
# 507 galactose pred: G AH0 L AE1 K T AH0 S ref: G AH0 L AE1 K T OW0 S cer: 0.1250
# 508 kurumizowa pred: K W UH1 R AH0 M AY2 Z W AH0 ref: K UH2 R UW0 M IY0 Z OW1 AH0 cer: 0.5556
# 509 plumages pred: P L AH1 M AH0 JH IH0 Z ref: P L UW1 M AH0 JH AH0 Z cer: 0.2500
# 510 helmsburton pred: HH EH1 L M S B ER0 T AH0 N ref: HH EH1 L M Z B ER0 T AH0 N cer: 0.1000
# 511 longitudes pred: L AO1 NG G IH0 T AH2 D Z ref: L AA1 N JH AH0 T UW2 D Z cer: 0.5556
# 512 spelunked pred: S P EH1 L AH0 NG K IH0 D ref: S P AH0 L AH1 NG K T cer: 0.5000
# 513 poparelli pred: P OW0 P AA0 R EH1 L IY0 ref: P OW2 P AH0 R EH1 L IY0 cer: 0.2500
# 514 newsmakers pred: N UW1 Z M EY2 K ER0 Z ref: N UW1 Z M EY2 K ER0 Z cer: 0.0000
# 515 eradication pred: EH2 R AH0 D IH1 K AH0 N ref: IH0 R AE2 D AH0 K EY1 SH AH0 N cer: 0.5000
# 516 qualifies pred: K W AA1 L IH0 F AY2 Z ref: K W AA1 L AH0 F AY2 Z cer: 0.1250
# 517 zuchowski pred: Z AH0 CH AO1 F S K IY0 ref: Z AH0 HH AO1 F S K IY0 cer: 0.1250
# 518 nonaligned pred: N AA1 N AH0 L IH0 N D ref: N AA1 N AH0 L AY2 N D cer: 0.1250
# 519 childminder pred: CH AY1 L D M IH2 N D ER0 ref: CH AY1 L D M AY2 N D ER0 cer: 0.1111
# 520 diuretics pred: D AY0 V EH1 T IH0 K S ref: D AY2 UW0 R EH1 T IH0 K S cer: 0.3333
# 521 wagnerian pred: V AA0 G N ER0 IY1 AH0 N ref: W AE2 G N EH1 R IY0 AH0 N cer: 0.5556
# 522 vanwieren pred: V AE0 N W IH1 R AH0 N ref: V AE0 N W IH1 R AH0 N cer: 0.0000
# 523 savagery pred: S AH0 V EY1 JH ER0 IY0 ref: S AE1 V IH0 JH EH2 R IY0 cer: 0.5000
# 524 vartanian pred: V AA0 R T EY1 N IY0 AH0 N ref: V AA0 R T EY1 N IY0 AH0 N cer: 0.0000
# 525 religion's pred: R IH0 L IH1 JH AH0 N Z ref: R IH0 L IH1 JH AH0 N Z cer: 0.0000
# 526 sulfurophane pred: S UW0 L F ER1 AH0 F AH0 N ref: S AH1 L F ER0 AH0 F EY2 N cer: 0.3333
# 527 thomasina pred: TH AA0 M AA1 S AH0 N AH0 ref: TH OW0 M AA0 S IY1 N AH0 cer: 0.3750
# 528 haakenson pred: HH EY1 K AH0 N S AH0 N ref: HH AA1 K IH0 N S AH0 N cer: 0.2500
# 529 jetliners pred: JH EH1 T L AY2 N ER0 Z ref: JH EH1 T L AY2 N ER0 Z cer: 0.0000
# 530 artifacts pred: AE1 R T AH0 F AE0 K T S ref: AA1 R T AH0 F AE2 K T S cer: 0.2222
# 531 unwieldiness pred: AH0 N W IY1 L D AH0 N AH0 S ref: AH0 N W IY1 L D IY0 N AH0 S cer: 0.1000
# 532 delcastillo pred: D EH2 L K AH0 S T IY1 L OW0 ref: D EH0 L K AA0 S T IH1 L OW0 cer: 0.3000
# 533 ruthenberg pred: R UW1 TH AH0 N B ER0 G ref: R AH1 TH AH0 N B ER0 G cer: 0.1250
# 534 landolfi pred: L AE1 N D AH0 L F IY0 ref: L AA0 N D OW1 L F IY0 cer: 0.2500
# 535 shriveling pred: SH R AY1 V L IH0 NG ref: SH R IH1 V AH0 L IH0 NG cer: 0.2500
# ...
# 4825 underemployment pred: AH2 N D ER0 M AE1 P L IY0 M AH0 N T ref: AH2 N D ER0 IH0 M P L OY1 M AH0 N T cer: 0.2308
# 4826 abnormalities pred: AH0 B N AO1 R M AH0 L IH0 T IY0 Z ref: AE2 B N AO0 R M AE1 L AH0 T IY0 Z cer: 0.3333
# 4827 motorola's pred: M OW0 T AO1 R AH0 L AH0 Z ref: M OW2 T ER0 OW1 L AH0 Z cer: 0.5000
# 4828 freshwater pred: F R EH1 SH W AO2 T ER0 ref: F R EH1 SH W AO2 T ER0 cer: 0.0000
# 4829 bankowski pred: B AH0 NG K AO1 F S K IY0 ref: B AH0 NG K AO1 F S K IY0 cer: 0.0000
# 4830 disinform pred: D IH0 S IH1 N F ER0 M ref: D IH0 S IH0 N F AO1 R M cer: 0.3333
# 4831 decimals pred: D IH0 S IH1 M AH0 L Z ref: D EH1 S AH0 M AH0 L Z cer: 0.2500
# 4832 cellular's pred: K EH1 L Y AH0 L ER0 Z ref: S EH1 L Y AH0 L ER0 Z cer: 0.1250
# 4833 disclaimer pred: D IH0 S K L EY1 M ER0 ref: D IH0 S K L EY1 M ER0 cer: 0.0000
# 4834 requesting pred: R EH1 K W EH2 S T IH0 NG ref: R IH0 K W EH1 S T IH0 NG cer: 0.2222
# 4835 luncheonette pred: L AH1 N CH AH0 N EH2 T ref: L AH2 N CH IH0 N EH1 T cer: 0.3750
# 4836 eventful pred: EH1 V AH0 N T F L AH2 L ref: IH0 V EH1 N T F AH0 L cer: 0.5000
# 4837 hallelujah pred: HH AE2 L IH0 L UW1 JH ref: HH AE2 L AH0 L UW1 Y AH0 cer: 0.3750
# 4838 rostropovich pred: R OW0 S T R OW1 P AH0 V IH0 CH ref: R AO2 S T R AH0 P OW1 V IH0 CH cer: 0.2727
# 4839 hamanaka pred: HH AE2 M AH0 N AA1 K AH0 ref: HH AH0 M AH0 N AA1 K AH0 cer: 0.1250
# 4840 prillaman pred: P R IH1 L AH0 M AH0 N ref: P R IH1 L AH0 M AH0 N cer: 0.0000
# 4841 parliamentary pred: P AA2 R L IY0 AE1 M AH0 N T EH2 R IY0 ref: P AA2 R L AH0 M EH1 N T ER0 IY0 cer: 0.4545
# 4842 wonderfulness pred: W UH1 N D ER0 F L AH0 S ref: W AH1 N D ER0 F AH0 L N AH0 S cer: 0.2727
# 4843 thunderbolt pred: TH AH1 N D ER0 B AO2 L T ref: TH AH1 N D ER0 B AO2 L T cer: 0.0000
# 4844 diagnosed pred: D AY1 AH0 G N OW2 S D ref: D AY2 AH0 G N OW1 S T cer: 0.3750
# 4845 flavorings pred: F L EY1 V ER0 IH0 NG Z ref: F L EY1 V ER0 IH0 NG Z cer: 0.0000
# 4846 boguslavskaya pred: B AA2 G UW0 S L AA1 V AH0 S K IY0 ref: B OW0 G AH2 S L AH0 V S K AY1 AH0 cer: 0.5000
# 4847 iconography pred: IH2 K AA2 N AH0 G R AE1 F IY0 ref: AY2 K AH0 N AA1 G R AH0 F IY0 cer: 0.4000
# 4848 milkovich pred: M IH1 L K AH0 V IH0 K ref: M IH1 L K AH0 V IH0 CH cer: 0.1250
# 4849 giroldi's pred: JH AY1 R AH0 L D IY0 Z ref: G IH0 R OW1 L D IY0 Z cer: 0.3750
# 4850 hershkowitz pred: HH ER1 SH K AH0 T S ref: HH ER1 SH K AH0 W IH0 T S cer: 0.2222
# 4851 clarifications pred: K L EH2 R AH0 F AH0 K EY1 SH AH0 N Z ref: K L EH2 R IH0 F IH0 K EY1 SH AH0 N Z cer: 0.1538
# 4852 handholding pred: HH AE1 N D HH OW2 L D IH0 NG ref: HH AE1 N D HH OW2 L D IH0 NG cer: 0.0000
# 4853 picaresque pred: P IH1 K ER0 Z K ref: P IH2 K AH0 R EH1 S K cer: 0.6250
# 4854 confirmation pred: K AH0 N F ER1 M AH0 T AH0 N ref: K AA2 N F ER0 M EY1 SH AH0 N cer: 0.4000
# 4855 institutionalized pred: IH2 N S T IH0 T UW1 SH AH0 N AH0 L AY2 Z D ref: IH2 N S T IH0 T UW1 SH AH0 N AH0 L AY2 Z D cer: 0.0000
# 4856 espinoza pred: EH0 S P IY0 N AA1 T AH0 Z EY2 ref: EY0 S P IY0 N OW1 Z AH0 cer: 0.6250
# 4857 lufthansa pred: L AH1 F TH AH0 N S AA2 ref: L AH0 F T AE1 N Z AH0 cer: 0.6250
# 4858 stepdaughters pred: S T EH1 P D AW0 TH ER0 Z ref: S T EH1 P D AO2 T ER0 Z cer: 0.2222
# 4859 grandfield pred: G R AE1 N D F IY2 L D ref: G R AE1 N D F IY2 L D cer: 0.0000
# 4860 pleasants pred: P L IY1 Z AH0 N T S ref: P L EH1 Z AH0 N T S cer: 0.1250
# 4861 sandbox pred: S AE1 N D B AA2 K S ref: S AE1 N D B AA2 K S cer: 0.0000
# 4862 dimorphic pred: D AY1 M ER0 F IH2 K ref: D AY0 M AO1 R F IH0 K cer: 0.5000
# 4863 restaino pred: R IH0 S T EY1 N OW0 ref: R EH0 S T AA0 IY1 N OW0 cer: 0.3750
# 4864 steffensmeier pred: S T EH1 F IH0 N S M IY0 ER0 ref: S T EH1 F IH0 N S M AY0 ER0 cer: 0.1000
# 4865 gencarelli pred: JH AH0 N K AA1 R L IY0 ref: JH EH0 N K AA0 R EH1 L IY0 cer: 0.3333
# 4866 memorialized pred: M EH1 M ER0 IY0 AH0 L AY2 Z D ref: M AH0 M AO1 R IY0 AH0 L AY2 Z D cer: 0.2727
# 4867 pharmacia pred: F AA0 R M EY1 SH IY0 AH0 ref: F AA0 R M EY1 S IY0 AH0 cer: 0.1250
# 4868 assuredly pred: AH0 S UW1 R D AH0 L IY0 ref: AH0 SH UH1 R AH0 D L IY0 cer: 0.5000
# 4869 tempelsman pred: T EH1 M P AH0 L S M AH0 N ref: T EH1 M P AH0 L Z M AH0 N cer: 0.1000
# 4870 quartets pred: K W AO1 R T IH0 T S ref: K W AO0 R T EH1 T S cer: 0.2500
# 4871 cartland pred: K AA1 R T AH0 N D ref: K AA1 R T L AH0 N D cer: 0.1250
# 4872 sprogus's pred: S P R OW1 G AH0 S IH0 Z ref: S P R OW1 G AH0 S IH0 Z cer: 0.0000
# 4873 introduction pred: IH2 N T R AH0 D AH1 K SH AH0 N ref: IH2 N T R AH0 D AH1 K SH AH0 N cer: 0.0000
# 4874 carberry's pred: K EH1 R B ER0 R IY0 Z ref: K AA1 R B EH2 R IY0 Z cer: 0.2500
# 4875 horticulture pred: HH AO1 R T IH0 K AH2 L T ER0 ref: HH AO1 R T IH0 K AH2 L CH ER0 cer: 0.1000
# 4876 reforestation pred: R EH2 F ER0 EH1 S T EY0 SH AH0 N ref: R IY2 F AO0 R AH0 S T EY1 SH AH0 N cer: 0.4167
# 4877 stivoric pred: S T IH1 V ER0 IH0 K ref: S T IH0 V AO1 R IH0 K cer: 0.3750
# 4878 addidases pred: AE1 D IH0 D AH0 S IH0 Z ref: AH0 D IY1 D AH0 S IH0 Z cer: 0.2500
# 4879 proponent pred: P R AA1 P AH0 N AH0 N T ref: P R AH0 P OW1 N AH0 N T cer: 0.2222
# 4880 obligations pred: AA2 B L AH0 G EY1 SH AH0 N Z ref: AA2 B L AH0 G EY1 SH AH0 N Z cer: 0.0000
# 4881 medtronic pred: M EH1 D T R AH0 N IH0 K ref: M EH0 D T R AA1 N IH0 K cer: 0.2222
# 4882 filippello pred: F IH2 L AH0 P EH1 L OW0 ref: F IY2 L IH0 P EH1 L OW0 cer: 0.2500
# 4883 papier-mache pred: P AE1 P AH0 R M AE0 K ref: P EY1 P ER0 M AH0 SH EY1 cer: 0.7500
# 4884 lionheart pred: L AY1 AH0 N HH AA0 R T ref: L AY1 AH0 N HH AA2 R T cer: 0.1250
# 4885 ferromagnetism pred: F ER0 AO1 M AH0 JH N AH0 T IH2 Z AH0 M ref: F EH2 R OW0 M AE1 G N AH0 T IH2 Z AH0 M cer: 0.3571
# 4886 bilingual pred: B IH1 L IH0 NG G W AH0 L ref: B AY0 L IH1 NG G W AH0 L cer: 0.2222
# 4887 thunderstorm pred: TH AH1 N D S T AO2 R M ref: TH AH1 N D ER0 S T AO2 R M cer: 0.1000
# 4888 hollenbach pred: HH OW1 L AH0 N B AO2 K ref: HH AA1 L IH0 N B AA0 K cer: 0.3750
# 4889 overfunded pred: OW1 V ER0 F AH2 N D IH0 D ref: OW1 V ER0 F AH2 N D IH0 D cer: 0.0000
# 4890 skenandore pred: S EH0 N AE1 N D AO0 R ref: S K IH0 N AE1 N D ER0 cer: 0.5000
# 4891 burgundy's pred: B ER1 G AH0 N D IY0 Z ref: B ER1 G AH0 N D IY0 Z cer: 0.0000
# 4892 dressmaking pred: D R EH1 S M AH0 K IH0 NG ref: D R EH1 S M EY2 K IH0 NG cer: 0.1111
# 4893 polysaccharide pred: P AA2 L IY2 S AA1 K ER0 AY2 D ref: P AA2 L IY2 S AE1 K ER0 AY2 D cer: 0.1000
# 4894 irrevocably pred: IH2 R EH1 V AH0 K AH0 L L IY0 ref: IH2 R EH1 V AH0 K AH0 B L IY0 cer: 0.1000
# 4895 arianespace pred: AA2 R IY0 AE1 N S P AH0 S ref: EH2 R IY0 AE1 N S P EY1 S cer: 0.2222
# 4896 unconstitutionally pred: AH0 N K AH0 N S T IH1 T UW0 AH0 L EY0 L IY0 ref: AH2 N K AA2 N S T AH0 T UW1 SH AH0 N AH0 L IY0 cer: 0.4375
# 4897 americorps pred: AH0 M EH1 R OW0 K AO2 R P S ref: AH0 M EH1 R IH0 K AO2 R cer: 0.3750
# 4898 wannemacher pred: V AE1 N AH0 M EY2 K ER0 ref: W AA1 N AH0 M AA0 K ER0 cer: 0.3750
# 4899 comprising pred: K AH0 M P R IH1 Z IH0 NG ref: K AH0 M P R AY1 Z IH0 NG cer: 0.1111
# 4900 almendarez pred: AE1 L M AH0 N D AA2 R Z ref: AA0 L M EY0 N D AA1 R EH0 Z cer: 0.4000
# 4901 january pred: JH AE0 N Y HH AA1 R IY0 ref: JH AE1 N Y UW0 EH2 R IY0 cer: 0.3750
# 4902 revolvers pred: R IY0 V OW1 L ER0 Z ref: R IH0 V AA1 L V ER0 Z cer: 0.3750
# 4903 islamabad's pred: IH2 S L AE1 M AH0 B AH0 D Z ref: IH2 S L AE1 M AH0 B AE0 D Z cer: 0.1000
# 4904 universities' pred: AH0 N IH0 V ER1 S IH0 T IY0 Z ref: Y UW2 N IH0 V ER1 S IH0 T IY0 Z cer: 0.1818
# 4905 detriment pred: D EH1 T R IY0 M AH0 N T ref: D EH1 T R AH0 M AH0 N T cer: 0.1111
# 4906 conducted pred: K AH0 N D AH1 K T IH0 D ref: K AH0 N D AH1 K T AH0 D cer: 0.1111
# 4907 minisupercomputer pred: M AY2 N IH0 S UW1 P ER0 AH0 K Y UW2 T ER0 ref: M IH2 N IY0 S UW1 P ER0 K AH2 M P Y UW2 T ER0 cer: 0.3750
# 4908 graziano pred: G R AE2 Z IY0 AA1 N OW0 ref: G R AA0 T S IY0 AA1 N OW0 cer: 0.3333
# 4909 decommissioning pred: D IH0 K AH0 M IH1 S IH0 N IH0 NG ref: D IY0 K AH0 M IH1 SH AH0 N IH0 NG cer: 0.2727
# 4910 padmanabhan pred: P AE1 D M AH0 N AH0 TH AE0 N ref: P AE0 D M AE1 N AH0 B AE2 N cer: 0.4000
# 4911 americare pred: AH0 M EH1 R AH0 K AA2 R ref: AH0 M EH1 R IH0 K EH2 R cer: 0.2500
# 4912 monteverde pred: M AA1 N T AH0 V ER2 D ref: M OW0 N T EH0 V EH1 R D IY0 cer: 0.5000
# 4913 estimating pred: EH1 S T AH0 M AH0 T IH0 NG ref: EH1 S T AH0 M EY2 T IH0 NG cer: 0.1111
# 4914 bollettieri pred: B AH0 L EH1 T R IY0 ref: B AH0 L EH2 T IY0 EH1 R IY0 cer: 0.3333
# 4915 textbooks pred: T EH1 K S T B AO2 K S ref: T EH1 K S T B UH2 K S cer: 0.1111
# 4916 mischievous pred: M IH0 S K AY1 V AH0 S ref: M IH1 S CH AH0 V AH0 S cer: 0.3750
# 4917 vanblaricom pred: V AE2 N B L EH1 R IH0 K AA2 M ref: V AE2 N B L AE1 R IH0 K AH0 M cer: 0.1818
# 4918 carbonized pred: K AA1 R B AH0 N AY2 Z D ref: K AA1 R B AH0 N AY2 Z D cer: 0.0000
# 4919 deforest pred: D IH0 F AO1 R S T ref: D IH0 F AO1 R AH0 S T cer: 0.1250
# 4920 feedstocks pred: F EH1 V S T OW2 K S ref: F IY1 D S T AA2 K S cer: 0.3750
# 4921 undernourished pred: AH2 N D ER0 N AO1 R IH0 SH T ref: AH2 N D ER0 N ER1 IH0 SH T cer: 0.2222
# 4922 exonerated pred: IH0 K S AA1 N ER0 EY2 T IH0 D ref: IH0 G Z AA1 N ER0 EY2 T IH0 D cer: 0.2000
# 4923 vagabonds pred: V EY1 G AH0 B AH0 N D Z ref: V AE1 G AH0 B AA0 N D Z cer: 0.2222
# 4924 itinerant pred: IH2 T IH1 N ER0 AH0 N T ref: AY0 T IH1 N ER0 AH0 N T cer: 0.1250
# 4925 mcevilly pred: M AH0 V EH1 L AH0 L IY0 ref: M AH0 K EH1 V AH0 L IY0 cer: 0.2500
# 4926 copperfields' pred: K AA1 P ER0 F IY2 L D Z ref: K AA1 P ER0 F IY2 L D Z cer: 0.0000
# 4927 cleaveland pred: K L IY1 V L AH0 N D ref: K L IY1 V L AH0 N D cer: 0.0000
# 4928 telescopic pred: T EH2 L AH0 S K AA1 P IH0 K ref: T EH2 L AH0 S K AO1 P IH0 K cer: 0.1000
# 4929 beverages pred: B EH1 V ER0 AH0 JH IH0 Z ref: B EH1 V R IH0 JH IH0 Z cer: 0.2500
# 4930 telesciences pred: T EH1 L AH0 S K IY2 N S IH0 Z ref: T EH1 L AH0 S AY2 AH0 N S IH0 Z cer: 0.1818
# 4931 islamist pred: IH2 S L AE1 M IH0 S T ref: IH1 S L AH0 M IH0 S T cer: 0.2500
# 4932 ornamented pred: AA1 R N AH0 M AH0 N T IH0 D ref: AO1 R N AH0 M EH2 N T IH0 D cer: 0.2000
# 4933 aganbegyan pred: AE2 G AH0 N B EH1 G IY0 AH0 N ref: AE2 G AH0 N B EH1 G Y AH0 N cer: 0.1000
# 4934 ferryboats pred: F EH1 R IY0 B OW2 T S ref: F EH1 R IY0 B OW2 T S cer: 0.0000
# 4935 disapprove pred: D IH0 S AE1 P R AH0 V ref: D IH2 S AH0 P R UW1 V cer: 0.3750
# 4936 uniondale pred: Y UW0 N IY0 OW1 N D AH0 L ref: Y UW1 N Y AH0 N D EY2 L cer: 0.4444
# 4937 accessibility pred: AH0 S EH2 S AH0 B IH1 L IH0 T IY0 ref: AE2 K S EH0 S AH0 B IH1 L IH0 T IY0 cer: 0.2500
# 4938 nawrocki pred: K AA0 R OW1 K AH0 K IY0 ref: N AA0 V R OW1 T S K IY0 cer: 0.4444
# 4939 competitors pred: K AH0 M T EH1 T IH0 R S ref: K AH0 M P EH1 T AH0 T ER0 Z cer: 0.5000
# 4940 kendavis pred: K EH1 N D AH0 V IH0 S ref: K EH1 N D EY1 V IH0 S cer: 0.1250
# 4941 dockendorf pred: D AA1 K AH0 N D AO2 R F ref: D AA1 K IH0 N D AO0 R F cer: 0.2222
# 4942 redecorated pred: R IY0 D EH1 K ER0 EY2 T IH0 D ref: R IY0 D EH1 K ER0 EY2 T IH0 D cer: 0.0000
# 4943 prototypes pred: P R OW1 T OW0 T AY2 P S ref: P R OW1 T AH0 T AY2 P S cer: 0.1111
# 4944 first-class pred: S ER1 S T L AA2 S ref: F ER2 S T K L AE1 S cer: 0.5000
# 4945 insemination pred: IH2 N S AH0 M IH1 N AH0 T IY0 ref: IH2 N S EH2 M AH0 N EY1 SH AH0 N cer: 0.5455
# 4946 cara'veras pred: K AA0 R AA0 V EH1 R ER0 Z ref: K AA2 R AH0 V EH1 R AH0 Z cer: 0.3333
# 4947 excepting pred: IH0 K S EH1 P T IH0 NG ref: EH2 K S EH1 P T IH0 NG cer: 0.1250
# 4948 coventry pred: K AH0 V EH1 N T R IY0 ref: K AH1 V AH0 N T R IY0 cer: 0.2500
# 4949 unmistakably pred: AH0 N M IH1 S T AH0 K AH0 B L IY0 ref: AH2 N M IH0 S T EY1 K AH0 B L IY0 cer: 0.2500
# 4950 geometrically pred: JH IY2 AA1 M T R IH0 K L IY0 ref: JH IY2 AH0 M EH1 T R IH0 K L IY0 cer: 0.1818
# 4951 pediatricians pred: P EH2 D IY0 AE1 T R IH0 S AH0 N Z ref: P IY2 D IY0 AH0 T R IH1 SH AH0 N Z cer: 0.3333
# 4952 stability pred: S T EY1 B AH0 L IH0 T IY0 ref: S T AH0 B IH1 L IH0 T IY0 cer: 0.2222
# 4953 headrests pred: HH EH1 D R AH0 S T S ref: HH EH1 D R EH2 S T S cer: 0.1250
# 4954 overuses pred: OW1 V ER0 Y UW0 S IH0 Z ref: OW2 V ER0 Y UW1 Z IH0 Z cer: 0.3750
# 4955 finstrom pred: F IH1 N S T R AH0 M ref: F IH1 N S T R AH0 M cer: 0.0000
# 4956 lindstrand pred: L IH1 N D S T R AH0 N D ref: L IH1 N D S T R AH0 N D cer: 0.0000
# 4957 intently pred: IH2 N T EH1 N L AH0 ref: IH2 N T EH1 N T L IY0 cer: 0.2500
# 4958 francisco's pred: F R AA0 N K IH0 S K OW1 Z ref: F R AE0 N S IH1 S K OW0 Z cer: 0.4000
# 4959 angelino pred: AE2 NG G IH0 L IY1 N OW0 ref: AE2 N JH AH0 L IY1 N OW0 cer: 0.3750
# 4960 dobrynin pred: D AA1 B R IY0 N IH0 N ref: D AA1 B R IH0 N IH0 N cer: 0.1250
# 4961 bankable pred: B AE1 NG K AH0 B AH0 L ref: B AE1 NG K AH0 B AH0 L cer: 0.0000
# 4962 cypriots pred: S IH1 P R IY0 AH0 T S ref: S IH1 P R IY0 AH0 T S cer: 0.0000
# 4963 extracted pred: EH1 K S T R AE0 K T IH0 D ref: EH0 K S T R AE1 K T IH0 D cer: 0.2000
# 4964 definable pred: D IH0 F IH1 N AH0 B AH0 L ref: D IH0 F AY1 N AH0 B AH0 L cer: 0.1111
# 4965 aluminum pred: AH0 L AH1 M AH0 N AH0 M ref: AH0 L UW1 M AH0 N AH0 M cer: 0.1250
# 4966 misconstrue pred: M IH0 S K AA1 N S T R AH0 ref: M IH0 S K AH0 N S T R UW1 cer: 0.2000
# 4967 embellishes pred: IH0 M B EH1 L IH0 SH AH0 Z ref: EH0 M B EH1 L IH0 SH AH0 Z cer: 0.1111
# 4968 westchester's pred: W EH1 S T HH EH2 S T ER0 Z ref: W EH1 S T CH EH2 S T ER0 Z cer: 0.1000
# 4969 unsatisfied pred: AH0 N S AE1 T IH0 S F AY2 D ref: AH0 N S AE1 T IH0 S F AY2 D cer: 0.0000
# 4970 surmounted pred: S ER0 M AW1 N T IH0 D ref: S ER0 M AW1 N T IH0 D cer: 0.0000
# 4971 fredericksen pred: F R EH1 D ER0 IH0 K S AH0 N ref: F R EH1 D ER0 IH0 K S AH0 N cer: 0.0000
# 4972 raudenbush pred: R UW1 D IH0 N B AH0 SH ref: R AW1 D IH0 N B UH0 SH cer: 0.2500
# 4973 disequilibrium pred: D IH2 S IH0 K W IH1 L Y AH0 M IH0 L ref: D IH0 S IY2 K W AH0 L IH1 B R IY0 AH0 M cer: 0.6429
# 4974 staffordshire's pred: S T AE1 F R D ER2 F ER0 Z ref: S T AE1 F ER0 D SH ER0 Z cer: 0.3333
# 4975 hospices pred: HH AA1 S P IH0 S IH0 Z ref: HH AA1 S P AH0 S IH0 Z cer: 0.1250
# 4976 mcmasters pred: M AH0 K M AE1 S T ER0 Z ref: M AH0 K M AE1 S T ER0 Z cer: 0.0000
# 4977 albumin pred: AH0 L B AH1 M AH0 N ref: AE0 L B Y UW1 M AH0 N cer: 0.3750
# 4978 revelation pred: R IY0 V EH1 L AH0 T IY0 N ref: R EH2 V AH0 L EY1 SH AH0 N cer: 0.5556
# 4979 poinsettias pred: P AY2 N S T EH1 SH AH0 Z ref: P OY2 N S EH1 T IY2 AH0 Z cer: 0.4444
# 4980 controlling pred: K AH0 N T R OW1 L IH0 NG ref: K AH0 N T R OW1 L IH0 NG cer: 0.0000
# 4981 laboratory's pred: L AA0 B AA1 R AH0 T AO2 R IY0 Z ref: L AE1 B R AH0 T AO2 R IY0 Z cer: 0.2000
# 4982 bensinger pred: B EH1 N S IH0 N JH ER0 ref: B EH1 N S IH0 N JH ER0 cer: 0.0000
# 4983 interstitial pred: IH2 N T ER0 S T IH1 T IY0 AH0 L ref: IH2 N T ER0 S T IH1 SH AH0 L cer: 0.2000
# 4984 st-mary pred: S T N T M AA1 R IY0 ref: S EY1 N T M EH1 R IY0 cer: 0.2500
# 4985 protruding pred: P R UW0 T R UW1 D IH0 NG ref: P R OW0 T R UW1 D IH0 NG cer: 0.1111
# 4986 marchesano pred: M AA0 R K EH1 S AH0 N OW0 ref: M AA0 R K EH0 S AA1 N OW0 cer: 0.2222
# 4987 subordinate pred: S AH0 B AO1 R D AH0 N AH0 T ref: S AH0 B AO1 R D AH0 N EY2 T cer: 0.1000
# 4988 impoverishing pred: IH2 M P OW0 V ER1 IH0 SH IH0 NG ref: IH2 M P AA1 V R IH0 SH IH0 NG cer: 0.2000
# 4989 riskiest pred: R IH0 S K AY1 AH0 S T ref: R IH1 S K IY0 AH0 S T cer: 0.2500
# 4990 probationary pred: P R AA2 B AH0 T EY1 N ER0 IY0 ref: P R OW0 B EY1 SH AH0 N EH2 R IY2 cer: 0.6364
# 4991 nonchalantly pred: N AA0 N K AE1 L AH0 N T L IY0 ref: N AA1 N SH AH0 L AA1 N T L IY0 cer: 0.3636
# 4992 tangibly pred: T AE1 N JH AH0 B L IY0 ref: T AE1 N JH AH0 B L IY0 cer: 0.0000
# 4993 serological pred: S EH2 R AH0 L AA1 JH IH0 K AH0 L ref: S EH0 R AH0 L AO1 JH IH0 K AH0 L cer: 0.1818
# 4994 brentanos pred: B R EH1 N T AH0 N OW0 S ref: B R EH2 N T AA1 N OW0 Z cer: 0.3333
# 4995 jukeboxes pred: JH UW1 K B AO2 K S IH0 Z ref: JH UW1 K B AA2 K S IH0 Z cer: 0.1111
# 4996 entertainer pred: EH1 N T ER0 T EY2 N ER0 ref: EH2 N T ER0 T EY1 N ER0 cer: 0.2500
# 4997 profanity pred: P R AH0 F AA1 N IH0 T IY0 ref: P R OW0 F AE1 N AH0 T IY0 cer: 0.3333
# 4998 kalinske pred: K AH0 L IH1 N S K IY0 ref: K AH0 L IH1 N S K IY0 cer: 0.0000
# 4999 aromatic pred: AA0 R OW0 M EY1 T IH0 K ref: EH2 R AH0 M AE1 T IH0 K cer: 0.3750
# Avg CER: 0.2185
