# %% [markdown]
# ### Problem 1
#
# Load "the original dataset" from https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html into a pandas dataframe. (Hints: pandas.read_csv can read in a tab-separated file and information on the columns can be obtained from the brief description through the link above)
# 1. What is the output variable for this dataset? (i.e. which variable is the one that a data scientist would predict, using this dataset?)
# 2. All the other columns in the dataset are the attributes. For each attribute: compute the mean and the standard deviation. For all of the attributes together, create a correlation matrix (Using Pearson correlation coefficients). Please use numpy and scipy methods. Next, calculate a correlation matrix using the pandas method (your dataframe variable name).corr. Did you get the same values?
# 3. Does it make sense to calculate the mean and standard deviation for all of the columns? Is the correlation meaningful? Why or why not?
# 4. Why is the main diagonal of the correlation coefficient equal to a vector of ones? Justify your answer

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
from sklearn import preprocessing

df = pd.read_csv("E:\dataset.txt", sep = '\t')
output = df.columns[10]
mean = df.mean()
mean[:10]
df
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
i = 0
for id1 in df:
        X = df[id1]
        
        d1 = np.sum( (X-mean[i])**2 ) /(len(X)-1)
        sd1 = np.sqrt(d1)
        i+=1
        print("sd of col %s is: %f" % (id1, sd1))
# Out:
# sd of col AGE is: 13.109028
# sd of col SEX is: 0.499561
# sd of col BMI is: 4.418122
# sd of col BP is: 13.831283
# sd of col S1 is: 34.608052
# sd of col S2 is: 30.413081
# sd of col S3 is: 12.934202
# sd of col S4 is: 1.290450
# sd of col S5 is: 0.522391
# sd of col S6 is: 11.496335
# sd of col Y is: 77.093005

# %%
from scipy.stats import pearsonr

# calculate covariance matrix
matrix = {}
cor = []
i = 0
j = 0
for id1 in df:
        for id2 in df:
            X = df[id1]
            #rint(X)
            Y = df[id2]
            covariance = np.cov(X, Y)
            #print('covariance: %.5f' % covariance[0,1])

            # calculate Pearson's correlation
            corr = np.corrcoef(X, Y)
            #print('Pearsons correlation: %.5f' % corr[0,1])
            matrix[X.name,Y.name] = corr[0,1]
matrix
# Out:
# {('AGE', 'AGE'): 0.9999999999999999,
#  ('AGE', 'SEX'): 0.1737371005636608,
#  ('AGE', 'BMI'): 0.18508466614655544,
#  ('AGE', 'BP'): 0.33542758706707276,
#  ('AGE', 'S1'): 0.26006082015026155,
#  ('AGE', 'S2'): 0.21924313984750804,
#  ('AGE', 'S3'): -0.07518097487514623,
#  ('AGE', 'S4'): 0.20384089972875538,
#  ('AGE', 'S5'): 0.27077424141816653,
#  ('AGE', 'S6'): 0.30173100763283783,
#  ('AGE', 'Y'): 0.18788875071891978,
#  ('SEX', 'AGE'): 0.1737371005636608,
#  ('SEX', 'SEX'): 1.0,
#  ('SEX', 'BMI'): 0.08816139902276232,
#  ('SEX', 'BP'): 0.2410104866490492,
#  ('SEX', 'S1'): 0.03527681917552952,
#  ('SEX', 'S2'): 0.14263725703350014,
#  ('SEX', 'S3'): -0.37908962922733186,
#  ('SEX', 'S4'): 0.3321150930829641,
#  ('SEX', 'S5'): 0.14991613649583818,
#  ('SEX', 'S6'): 0.20813321620038908,
#  ('SEX', 'Y'): 0.0430619984516054,
#  ('BMI', 'AGE'): 0.18508466614655544,
#  ('BMI', 'SEX'): 0.08816139902276232,
#  ('BMI', 'BMI'): 1.0,
#  ('BMI', 'BP'): 0.3954108987177126,
#  ('BMI', 'S1'): 0.2497774217424125,
#  ('BMI', 'S2'): 0.2611699111644256,
#  ('BMI', 'S3'): -0.36681097840502946,
#  ('BMI', 'S4'): 0.4138066018314404,
#  ('BMI', 'S5'): 0.4461565385732522,
#  ('BMI', 'S6'): 0.38867999390003916,
#  ('BMI', 'Y'): 0.5864501344746885,
#  ('BP', 'AGE'): 0.33542758706707276,
#  ('BP', 'SEX'): 0.2410104866490492,
#  ('BP', 'BMI'): 0.3954108987177127,
#  ('BP', 'BP'): 1.0,
#  ('BP', 'S1'): 0.24246402270704157,
#  ('BP', 'S2'): 0.18554846261290067,
#  ('BP', 'S3'): -0.1787616312256429,
#  ('BP', 'S4'): 0.25765005328351526,
#  ('BP', 'S5'): 0.3934801090448324,
#  ('BP', 'S6'): 0.39043002311603703,
#  ('BP', 'Y'): 0.44148175856257116,
#  ('S1', 'AGE'): 0.26006082015026155,
#  ('S1', 'SEX'): 0.03527681917552952,
#  ('S1', 'BMI'): 0.24977742174241246,
#  ('S1', 'BP'): 0.24246402270704157,
#  ('S1', 'S1'): 1.0,
#  ('S1', 'S2'): 0.8966629578104898,
#  ('S1', 'S3'): 0.05151936431482048,
#  ('S1', 'S4'): 0.5422072805232406,
#  ('S1', 'S5'): 0.5155029243689462,
#  ('S1', 'S6'): 0.32571675306070913,
#  ('S1', 'Y'): 0.21202248101455073,
#  ('S2', 'AGE'): 0.21924313984750804,
#  ('S2', 'SEX'): 0.14263725703350014,
#  ('S2', 'BMI'): 0.26116991116442556,
#  ('S2', 'BP'): 0.18554846261290064,
#  ('S2', 'S1'): 0.8966629578104898,
#  ('S2', 'S2'): 1.0,
#  ('S2', 'S3'): -0.19645512374417923,
#  ('S2', 'S4'): 0.6598168886666438,
#  ('S2', 'S5'): 0.31835666514156175,
#  ('S2', 'S6'): 0.2906003754970444,
#  ('S2', 'Y'): 0.1740535869687426,
#  ('S3', 'AGE'): -0.07518097487514623,
#  ('S3', 'SEX'): -0.37908962922733186,
#  ('S3', 'BMI'): -0.36681097840502946,
#  ('S3', 'BP'): -0.1787616312256429,
#  ('S3', 'S1'): 0.05151936431482048,
#  ('S3', 'S2'): -0.19645512374417926,
#  ('S3', 'S3'): 0.9999999999999999,
#  ('S3', 'S4'): -0.7384927292583825,
#  ('S3', 'S5'): -0.39857729342870984,
#  ('S3', 'S6'): -0.2736973014758415,
#  ('S3', 'Y'): -0.39478925067091836,
#  ('S4', 'AGE'): 0.20384089972875533,
#  ('S4', 'SEX'): 0.33211509308296416,
#  ('S4', 'BMI'): 0.41380660183144047,
#  ('S4', 'BP'): 0.25765005328351526,
#  ('S4', 'S1'): 0.5422072805232405,
#  ('S4', 'S2'): 0.6598168886666439,
#  ('S4', 'S3'): -0.7384927292583825,
#  ('S4', 'S4'): 1.0,
#  ('S4', 'S5'): 0.6178589739937285,
#  ('S4', 'S6'): 0.4172121137122002,
#  ('S4', 'Y'): 0.43045288474477295,
#  ('S5', 'AGE'): 0.27077424141816653,
#  ('S5', 'SEX'): 0.14991613649583818,
#  ('S5', 'BMI'): 0.44615653857325227,
#  ('S5', 'BP'): 0.39348010904483244,
#  ('S5', 'S1'): 0.5155029243689462,
#  ('S5', 'S2'): 0.3183566651415618,
#  ('S5', 'S3'): -0.3985772934287099,
#  ('S5', 'S4'): 0.6178589739937285,
#  ('S5', 'S5'): 0.9999999999999998,
#  ('S5', 'S6'): 0.46466884669136793,
#  ('S5', 'Y'): 0.5658825924427441,
#  ('S6', 'AGE'): 0.30173100763283783,
#  ('S6', 'SEX'): 0.20813321620038908,
#  ('S6', 'BMI'): 0.38867999390003916,
#  ('S6', 'BP'): 0.39043002311603703,
#  ('S6', 'S1'): 0.3257167530607091,
#  ('S6', 'S2'): 0.2906003754970444,
#  ('S6', 'S3'): -0.2736973014758415,
#  ('S6', 'S4'): 0.41721211371220024,
#  ('S6', 'S5'): 0.46466884669136793,
#  ('S6', 'S6'): 0.9999999999999999,
#  ('S6', 'Y'): 0.38248348424858103,
#  ('Y', 'AGE'): 0.1878887507189198,
#  ('Y', 'SEX'): 0.0430619984516054,
#  ('Y', 'BMI'): 0.5864501344746885,
#  ('Y', 'BP'): 0.44148175856257105,
#  ('Y', 'S1'): 0.2120224810145507,
#  ('Y', 'S2'): 0.1740535869687426,
#  ('Y', 'S3'): -0.39478925067091836,
#  ('Y', 'S4'): 0.4304528847447729,
#  ('Y', 'S5'): 0.5658825924427441,
#  ('Y', 'S6'): 0.382483484248581,
#  ('Y', 'Y'): 1.0}

# %%
cor = []
l1 = []
for k,v in matrix.items():

    l1.append(v)
    #print(l1)
    if v == 1.0:
        cor.append([l1])
        l1 = []
cor
# Out:
# [[[0.9999999999999999,
#    0.1737371005636608,
#    0.18508466614655544,
#    0.33542758706707276,
#    0.26006082015026155,
#    0.21924313984750804,
#    -0.07518097487514623,
#    0.20384089972875538,
#    0.27077424141816653,
#    0.30173100763283783,
#    0.18788875071891978,
#    0.1737371005636608,
#    1.0]],
#  [[0.08816139902276232,
#    0.2410104866490492,
#    0.03527681917552952,
#    0.14263725703350014,
#    -0.37908962922733186,
#    0.3321150930829641,
#    0.14991613649583818,
#    0.20813321620038908,
#    0.0430619984516054,
#    0.18508466614655544,
#    0.08816139902276232,
#    1.0]],
#  [[0.3954108987177126,
#    0.2497774217424125,
#    0.2611699111644256,
#    -0.36681097840502946,
#    0.4138066018314404,
#    0.4461565385732522,
#    0.38867999390003916,
#    0.5864501344746885,
#    0.33542758706707276,
#    0.2410104866490492,
#    0.3954108987177127,
#    1.0]],
#  [[0.24246402270704157,
#    0.18554846261290067,
#    -0.1787616312256429,
#    0.25765005328351526,
#    0.3934801090448324,
#    0.39043002311603703,
#    0.44148175856257116,
#    0.26006082015026155,
#    0.03527681917552952,
#    0.24977742174241246,
#    0.24246402270704157,
#    1.0]],
#  [[0.8966629578104898,
#    0.05151936431482048,
#    0.5422072805232406,
#    0.5155029243689462,
#    0.32571675306070913,
#    0.21202248101455073,
#    0.21924313984750804,
#    0.14263725703350014,
#    0.26116991116442556,
#    0.18554846261290064,
#    0.8966629578104898,
#    1.0]],
#  [[-0.19645512374417923,
#    0.6598168886666438,
#    0.31835666514156175,
#    0.2906003754970444,
#    0.1740535869687426,
#    -0.07518097487514623,
#    -0.37908962922733186,
#    -0.36681097840502946,
#    -0.1787616312256429,
#    0.05151936431482048,
#    -0.19645512374417926,
#    0.9999999999999999,
#    -0.7384927292583825,
#    -0.39857729342870984,
#    -0.2736973014758415,
#    -0.39478925067091836,
#    0.20384089972875533,
#    0.33211509308296416,
#    0.41380660183144047,
#    0.25765005328351526,
#    0.5422072805232405,
#    0.6598168886666439,
#    -0.7384927292583825,
#    1.0]],
#  [[0.6178589739937285,
#    0.4172121137122002,
#    0.43045288474477295,
#    0.27077424141816653,
#    0.14991613649583818,
#    0.44615653857325227,
#    0.39348010904483244,
#    0.5155029243689462,
#    0.3183566651415618,
#    -0.3985772934287099,
#    0.6178589739937285,
#    0.9999999999999998,
#    0.46466884669136793,
#    0.5658825924427441,
#    0.30173100763283783,
#    0.20813321620038908,
#    0.38867999390003916,
#    0.39043002311603703,
#    0.3257167530607091,
#    0.2906003754970444,
#    -0.2736973014758415,
#    0.41721211371220024,
#    0.46466884669136793,
#    0.9999999999999999,
#    0.38248348424858103,
#    0.1878887507189198,
#    0.0430619984516054,
#    0.5864501344746885,
#    0.44148175856257105,
#    0.2120224810145507,
#    0.1740535869687426,
#    -0.39478925067091836,
#    0.4304528847447729,
#    0.5658825924427441,
#    0.382483484248581,
#    1.0]]]

# %%
df.corr()
# Out:
#           AGE       SEX       BMI        BP        S1        S2        S3  \
# AGE  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# SEX  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# BMI  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# BP   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# S1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# S2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# S3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# S4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# S5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# S6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Y    0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#            S4        S5        S6         Y
# AGE  0.203841  0.270774  0.301731  0.187889
# SEX  0.332115  0.149916  0.208133  0.043062
# BMI  0.413807  0.446157  0.388680  0.586450
# BP   0.257650  0.393480  0.390430  0.441482
# S1   0.542207  0.515503  0.325717  0.212022
# S2   0.659817  0.318357  0.290600  0.174054
# S3  -0.738493 -0.398577 -0.273697 -0.394789
# S4   1.000000  0.617859  0.417212  0.430453
# S5   0.617859  1.000000  0.464669  0.565883
# S6   0.417212  0.464669  1.000000  0.382483
# Y    0.430453  0.565883  0.382483  1.000000

# %% [markdown]
# ### Problem 2

# %% [markdown]
# ###### Part 1: Predict the values of the output variable you identified above.
# 1. Normalize all columns which it makes sense to normalize
# 2. Separate the entries into train and test segments randomly. Have the train segment contain 80%, about 354 entries. Let the test segment contain the remaining entries.
# 3. Use scikit-learn's linear regression algorithm to train on two columns of the train set, and test on the test set.
# 4. Use the linear regression algorithm to train on all the columns of the train set, and test on the test set.
# 5. Try different combinations of columns. See if you can find any combination that is better than using all of the columns.
# 6. Based on the values of MSE or R-squared of the train set and test set, what combination do you think is the best?

# %%
mean = 0
sd = 1

# %% [markdown]
# ###### Part 2: Use Linear Regression on Quadratic Features
# Use sklearn.preprocessing.PolynomialFeatures to expand the data set to include nonlinear elements, then perform linear regression again. Is this a better model comparing with the one you find in part 1?
#
# reference:https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html
